# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
dir = '/content/drive/MyDrive/ARIA'
sys.path.append(dir)

import os
os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'false'

import time
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import scipy
import random
import matplotlib.pyplot as plt

import jax
import optax
from flax import linen as nn
from jax import numpy as jnp
from flax.training import train_state  # Useful dataclass to keep train state
import flax

from functools import partial
import pickle

from numerical_methods import physics, ssim

# %% [markdown]
# ## Dataset

# %%
dx, dy = 0.5, 0.5
ny, nx = 26, 49
dt = 0.4
NSUBSTEPS = 4

# %%
with open(f'{dir}/dataset/dataset_v2.pickle', 'rb') as handle:
  dataset = pickle.load(handle)

train_set = [0, 2, 4, 5, 6, 7, 8, 10, 12, 13, 15, 17, 19, 21, 23, 11, 14, 16, 25, 37, 38, 41, 42, 43, 49, 50]

# (Ns,2) list containing the (y,x) source locations
INFLOW_LOCS = dataset['INFLOW_LOCS'][train_set,]

# FLOW_TIMES[ns] contains the flow times for which corresponding plane-slices exist
FLOW_TIMES = [jnp.concatenate((jnp.zeros((1,)),jnp.array(dataset['FLOW_TIMES'][i]))) for i in train_set]

# SMOKE_FIELD[ns][nt] contains the smoke field at the corresponding flow time
SMOKE_FIELD = [jnp.concatenate((jnp.zeros((1,ny,nx)), jnp.array(dataset['SMOKE_FIELD'][i])), axis=0) for i in train_set]

VELOCITY = dataset['VELOCITY']    # velocity field
REL_LOC = dataset['rel_loc']      # relative location with respect to (y,x) in INFLOW_LOCS for which inflow term is calculated for
TERRAIN = dataset['TERRAIN']      # mask of terrain

# legacy: use to compute values at 4 cells around source location
# by interpolating the values across time
SPLINE_TCK = [dataset['SPLINE_TCK'][i] for i in train_set]
INFLOW_VALS = []
for set_idx in range(len(SMOKE_FIELD)):
  y,x = INFLOW_LOCS[set_idx]
  inflow_for_set = []
  for i in range(len(REL_LOC)):
    rel_y, rel_x = REL_LOC[i]
    inflow_for_set_for_loc = []
    for nt in range(1, 6001):
      val = scipy.interpolate.splev(nt*dt, SPLINE_TCK[set_idx][i])
      inflow_for_set_for_loc.append(val)
    inflow_for_set.append(inflow_for_set_for_loc)
  INFLOW_VALS.append(inflow_for_set)
INFLOW_VALS = jnp.array(INFLOW_VALS)

# for saving files
FILENAME_PREFIX = f'{dir}/expt1_baseline'

# mask for which diffusivity values should be computed for
diff_x_mask = jnp.logical_and(TERRAIN[:,1:],TERRAIN[:,:-1])
diff_y_mask = jnp.logical_and(TERRAIN[1:,:],TERRAIN[:-1,:])
diff_x_mask = diff_x_mask.astype(jnp.float32)
diff_y_mask = diff_y_mask.astype(jnp.float32)

MAX_STEPS = int((60+1e-3)/dt)
# Out:
# /tmp/ipython-input-3-3803491049.py:7: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   dataset = pickle.load(handle)

# %% [markdown]
# ## Turbulent Diffusivity

# %%
import dataset.read_data_to_grid as rdtg

grid = rdtg.read_data(f"{dir}/dataset/turb_vis.txt")
turb_vis = rdtg.extract_xyz_to_array(grid, x_range=(0, 48), y_range=(0, 25), z_range=(1,1), yxz=True)
turb_diff = jnp.array(turb_vis/0.7)

turb_diff_x = ((turb_diff[:,1:] + turb_diff[:,:-1])/2).squeeze()
turb_diff_y = ((turb_diff[1:,:] + turb_diff[:-1,:])/2).squeeze()

turb_diff_x = jnp.where(diff_x_mask, turb_diff_x, 0)
turb_diff_y = jnp.where(diff_y_mask, turb_diff_y, 0)
# Out:
# 792 rows of data read
# 791 data points used for grid
# Checksum: 7.059849280200001

# %% [markdown]
# ## Neural Networks

# %%
# decoder and neural closure model
class ClosureNet(nn.Module):
    def setup(self):
        # for decoding the hidden state
        self.convTrans1 = nn.ConvTranspose(features=128, kernel_size=(3, 2), strides=(3, 2), padding='SAME')
        self.conv11 = nn.Conv(features=128, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.convTrans2 = nn.ConvTranspose(features=64, kernel_size=(2, 2), strides=(2, 2), padding='SAME')
        self.conv21 = nn.Conv(features=64, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.convTrans3 = nn.ConvTranspose(features=32, kernel_size=(2, 3), strides=(2, 3), padding='SAME')
        self.conv31 = nn.Conv(features=32, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.convTrans4 = nn.ConvTranspose(features=16, kernel_size=(2, 3), strides=(2, 3), padding='SAME')
        self.conv41 = nn.Conv(features=16, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())

        # for transforming the output
        self.conv1 = nn.Conv(features=32, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.conv2 = nn.Conv(features=32, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.conv3 = nn.Conv(features=1, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())


    def __call__(self, x, h):
        # h is a list of hidden states
        dec = jnp.concatenate((h[0],h[1],h[2],h[3]))
        dec = jnp.expand_dims(dec, axis=(0,1))

        dec = self.convTrans1(dec)                          # (3,2)
        dec = nn.leaky_relu(dec, negative_slope=0.01)       # (3,2)
        dec = nn.leaky_relu(self.conv11(dec), negative_slope=0.01)+dec       # (3,2)

        dec = self.convTrans2(dec)                          # (6,4)
        dec = nn.leaky_relu(dec, negative_slope=0.01)       # (6,4)
        dec = jnp.pad(dec, ((0, 0), (0, 1), (0, 0)), mode='edge')        # (6,5)
        dec = nn.leaky_relu(self.conv21(dec), negative_slope=0.01)+dec       # (6,5)

        dec = self.convTrans3(dec)                                       # (12,15)
        dec = nn.leaky_relu(dec, negative_slope=0.01)                    # (12,15)
        dec = jnp.pad(dec, ((0, 1), (1, 0), (0, 0)), mode='edge')        # (13,16)
        dec = nn.leaky_relu(self.conv31(dec), negative_slope=0.01)+dec   # (13,16)

        dec = self.convTrans4(dec)                                       # (26,48)
        dec = jnp.pad(dec, ((0, 0), (0, 1), (0, 0)), mode='edge')        # (26,49)
        dec = nn.leaky_relu(self.conv41(dec), negative_slope=0.01)+dec   # (26,49)

        output = jnp.concatenate((dec, x), axis=-1)
        output = nn.leaky_relu(self.conv1(output), negative_slope=0.01) + jnp.pad(output, ((0,0),(0,0),(6,0)))
        output = nn.leaky_relu(self.conv2(output), negative_slope=0.01) + output
        output = self.conv3(output)
        return output

# %%
# encoder and memory unit
class HiddenNet(nn.Module):
    def setup(self):
        # to encode the scalar field
        self.conv1 = nn.Conv(features=16, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.conv11 = nn.Conv(features=16, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.conv2 = nn.Conv(features=32, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.conv21 = nn.Conv(features=32, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.conv3 = nn.Conv(features=64, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.conv31 = nn.Conv(features=64, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.conv4 = nn.Conv(features=128, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.conv41 = nn.Conv(features=128, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())

        self.lstm1 = nn.OptimizedLSTMCell(features=128)
        self.lstm2 = nn.OptimizedLSTMCell(features=128)
        self.lstm3 = nn.OptimizedLSTMCell(features=128)
        self.lstm4 = nn.OptimizedLSTMCell(features=128)


    def __call__(self, x, h, c):
        x = self.conv1(x)
        x = nn.leaky_relu(x, negative_slope=0.01)
        x = self.conv11(x)
        x = nn.leaky_relu(x, negative_slope=0.01)
        x = nn.max_pool(x, window_shape=(2, 3), strides=(2, 3))

        x = self.conv2(x)
        x = nn.leaky_relu(x, negative_slope=0.01)
        x = self.conv21(x)
        x = nn.leaky_relu(x, negative_slope=0.01)
        x = nn.max_pool(x, window_shape=(2, 3), strides=(2, 3))

        x = self.conv3(x)
        x = nn.leaky_relu(x, negative_slope=0.01)
        x = self.conv31(x)
        x = nn.leaky_relu(x, negative_slope=0.01)
        x = nn.max_pool(x, window_shape=(2, 2), strides=(2, 2))

        x = self.conv4(x)
        x = nn.leaky_relu(x, negative_slope=0.01)
        x = self.conv41(x)
        x = nn.leaky_relu(x, negative_slope=0.01)
        x = nn.max_pool(x, window_shape=(2, 2), strides=(2, 2))
        # x now contains the encoded current smoke state (input)

        # correction: lstm takes (c,h)
        (c1, h1), x1 = self.lstm1((c[0], h[0]), x)
        (c2, h2), x2 = self.lstm2((c[1], h[1]), x1)
        (c3, h3), x3 = self.lstm3((c[2], h[2]), x2)
        (c4, h4), x4 = self.lstm4((c[3], h[3]), x3)

        return jnp.array([h1.squeeze(), h2.squeeze(), h3.squeeze(), h4.squeeze()]), \
               jnp.array([c1.squeeze(), c2.squeeze(), c3.squeeze(), c4.squeeze()])

# %%
class InflowNet(nn.Module):
    def setup(self):
        self.conv1 = nn.Conv(features=8, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.conv2 = nn.Conv(features=16, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.conv3 = nn.Conv(features=32, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())
        self.conv4 = nn.Conv(features=64, kernel_size=(3,3), strides=1, padding='SAME', kernel_init=nn.initializers.xavier_uniform())

        self.fc1 = nn.Dense(features=64, kernel_init=nn.initializers.xavier_uniform())
        self.fc2 = nn.Dense(features=64, kernel_init=nn.initializers.xavier_uniform())
        self.fc3 = nn.Dense(features=4, kernel_init=nn.initializers.xavier_uniform())

    def __call__(self, x):
        # # Encoder
        enc1 = self.conv1(x)                                  # (26,49)
        enc1 = nn.leaky_relu(enc1, negative_slope=0.01)       # (26,49)

        enc2 = nn.max_pool(enc1, (2, 3), strides=(2, 3))      # (13,16)
        enc2 = self.conv2(enc2)                               # (13,16)
        enc2 = nn.leaky_relu(enc2, negative_slope=0.01)       # (13,16)

        enc3 = nn.max_pool(enc2, (2, 3), strides=(2, 3))      # (6,5)
        enc3 = self.conv3(enc3)                               # (6,5)
        enc3 = nn.leaky_relu(enc3, negative_slope=0.01)       # (6,5)

        enc4 = nn.max_pool(enc3, (2, 2), strides=(2, 2))      # (3,2)
        enc4 = self.conv4(enc4)                               # (3,2)
        enc4 = nn.leaky_relu(enc4, negative_slope=0.01)       # (3,2)

        bottleneck = nn.max_pool(enc4, (3, 2), strides=(3, 2))            # (1,1)

        output = nn.leaky_relu(self.fc1(bottleneck.squeeze()))
        output = nn.leaky_relu(self.fc2(output))
        output = self.fc3(output)
        return 10**(-5+jnp.tanh(output))

# %%
x = jnp.zeros((ny, nx, 10))
y = [jnp.zeros((128,)), jnp.zeros((128,)), jnp.zeros((128,)), jnp.zeros((128,))]
tabulate_fn = nn.tabulate(ClosureNet(), jax.random.PRNGKey(0), console_kwargs={"width": 120})

print(tabulate_fn(x, y))
# Out:
#                                           ClosureNet Summary
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ path       ┃ module        ┃ inputs              ┃ outputs           ┃ params                       ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │            │ ClosureNet    │ - float64[26,49,10] │ float64[26,49,1]  │                              │
# │            │               │ - - float64[128]    │                   │                              │
# │            │               │   - float64[128]    │                   │                              │
# │            │               │   - float64[128]    │                   │                              │
# │            │               │   - float64[128]    │                   │                              │
# ├────────────┼───────────────┼─────────────────────┼───────────────────┼──────────────────────────────┤
# │ convTrans1 │ ConvTranspose │ float64[1,1,512]    │ float64[3,2,128]  │ bias: float32[128]           │
# │            │               │                     │                   │ kernel: float32[3,2,512,128] │
# │            │               │                     │                   │                              │
# │            │               │                     │                   │ 393,344 (1.6 MB)             │
# ├────────────┼───────────────┼─────────────────────┼───────────────────┼──────────────────────────────┤
# │ conv11     │ Conv          │ float64[3,2,128]    │ float64[3,2,128]  │ bias: float32[128]           │
# │            │               │                     │                   │ kernel: float32[3,3,128,128] │
# │            │               │                     │                   │                              │
# │            │               │                     │                   │ 147,584 (590.3 KB)           │
# ├────────────┼───────────────┼─────────────────────┼───────────────────┼──────────────────────────────┤
# │ convTrans2 │ ConvTranspose │ float64[3,2,128]    │ float64[6,4,64]   │ bias: float32[64]            │
# │            │               │                     │                   │ kernel: float32[2,2,128,64]  │
# │            │               │                     │                   │                              │
# │            │               │                     │                   │ 32,832 (131.3 KB)            │
# ├────────────┼───────────────┼─────────────────────┼───────────────────┼──────────────────────────────┤
# │ conv21     │ Conv          │ float64[6,5,64]     │ float64[6,5,64]   │ bias: float32[64]            │
# │            │               │                     │                   │ kernel: float32[3,3,64,64]   │
# │            │               │                     │                   │                              │
# │            │               │                     │                   │ 36,928 (147.7 KB)            │
# ├────────────┼───────────────┼─────────────────────┼───────────────────┼──────────────────────────────┤
# │ convTrans3 │ ConvTranspose │ float64[6,5,64]     │ float64[12,15,32] │ bias: float32[32]            │
# │            │               │                     │                   │ kernel: float32[2,3,64,32]   │
# │            │               │                     │                   │                              │
# │            │               │                     │                   │ 12,320 (49.3 KB)             │
# ├────────────┼───────────────┼─────────────────────┼───────────────────┼──────────────────────────────┤
# │ conv31     │ Conv          │ float64[13,16,32]   │ float64[13,16,32] │ bias: float32[32]            │
# │            │               │                     │                   │ kernel: float32[3,3,32,32]   │
# │            │               │                     │                   │                              │
# │            │               │                     │                   │ 9,248 (37.0 KB)              │
# ├────────────┼───────────────┼─────────────────────┼───────────────────┼──────────────────────────────┤
# │ convTrans4 │ ConvTranspose │ float64[13,16,32]   │ float64[26,48,16] │ bias: float32[16]            │
# │            │               │                     │                   │ kernel: float32[2,3,32,16]   │
# │            │               │                     │                   │                              │
# │            │               │                     │                   │ 3,088 (12.4 KB)              │
# ├────────────┼───────────────┼─────────────────────┼───────────────────┼──────────────────────────────┤
# │ conv41     │ Conv          │ float64[26,49,16]   │ float64[26,49,16] │ bias: float32[16]            │
# │            │               │                     │                   │ kernel: float32[3,3,16,16]   │
# │            │               │                     │                   │                              │
# │            │               │                     │                   │ 2,320 (9.3 KB)               │
# ├────────────┼───────────────┼─────────────────────┼───────────────────┼──────────────────────────────┤
# │ conv1      │ Conv          │ float64[26,49,26]   │ float64[26,49,32] │ bias: float32[32]            │
# │            │               │                     │                   │ kernel: float32[3,3,26,32]   │
# │            │               │                     │                   │                              │
# │            │               │                     │                   │ 7,520 (30.1 KB)              │
# ├────────────┼───────────────┼─────────────────────┼───────────────────┼──────────────────────────────┤
# │ conv2      │ Conv          │ float64[26,49,32]   │ float64[26,49,32] │ bias: float32[32]            │
# │            │               │                     │                   │ kernel: float32[3,3,32,32]   │
# │            │               │                     │                   │                              │
# │            │               │                     │                   │ 9,248 (37.0 KB)              │
# ├────────────┼───────────────┼─────────────────────┼───────────────────┼──────────────────────────────┤
# │ conv3      │ Conv          │ float64[26,49,32]   │ float64[26,49,1]  │ bias: float32[1]             │
# │            │               │                     │                   │ kernel: float32[3,3,32,1]    │
# │            │               │                     │                   │                              │
# │            │               │                     │                   │ 289 (1.2 KB)                 │
# ├────────────┼───────────────┼─────────────────────┼───────────────────┼──────────────────────────────┤
# │            │               │                     │             Total │ 654,721 (2.6 MB)             │
# └────────────┴───────────────┴─────────────────────┴───────────────────┴──────────────────────────────┘
#
#                                   Total Parameters: 654,721 (2.6 MB)

# %%
x = jnp.zeros((ny, nx, 3))
h = [jnp.zeros((128,)), jnp.zeros((128,)), jnp.zeros((128,)), jnp.zeros((128,))]
c = [jnp.zeros((128,)), jnp.zeros((128,)), jnp.zeros((128,)), jnp.zeros((128,))]

tabulate_fn = nn.tabulate(HiddenNet(), jax.random.PRNGKey(0), console_kwargs={"width": 120})

print(tabulate_fn(x, h, c))
# Out:
#                                              HiddenNet Summary
# ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ path     ┃ module            ┃ inputs             ┃ outputs              ┃ params                       ┃
# ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          │ HiddenNet         │ - float64[26,49,3] │ - float64[4,128]     │                              │
# │          │                   │ - - float64[128]   │ - float64[4,128]     │                              │
# │          │                   │   - float64[128]   │                      │                              │
# │          │                   │   - float64[128]   │                      │                              │
# │          │                   │   - float64[128]   │                      │                              │
# │          │                   │ - - float64[128]   │                      │                              │
# │          │                   │   - float64[128]   │                      │                              │
# │          │                   │   - float64[128]   │                      │                              │
# │          │                   │   - float64[128]   │                      │                              │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ conv1    │ Conv              │ float64[26,49,3]   │ float64[26,49,16]    │ bias: float32[16]            │
# │          │                   │                    │                      │ kernel: float32[3,3,3,16]    │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 448 (1.8 KB)                 │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ conv11   │ Conv              │ float64[26,49,16]  │ float64[26,49,16]    │ bias: float32[16]            │
# │          │                   │                    │                      │ kernel: float32[3,3,16,16]   │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 2,320 (9.3 KB)               │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ conv2    │ Conv              │ float64[13,16,16]  │ float64[13,16,32]    │ bias: float32[32]            │
# │          │                   │                    │                      │ kernel: float32[3,3,16,32]   │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 4,640 (18.6 KB)              │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ conv21   │ Conv              │ float64[13,16,32]  │ float64[13,16,32]    │ bias: float32[32]            │
# │          │                   │                    │                      │ kernel: float32[3,3,32,32]   │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 9,248 (37.0 KB)              │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ conv3    │ Conv              │ float64[6,5,32]    │ float64[6,5,64]      │ bias: float32[64]            │
# │          │                   │                    │                      │ kernel: float32[3,3,32,64]   │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 18,496 (74.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ conv31   │ Conv              │ float64[6,5,64]    │ float64[6,5,64]      │ bias: float32[64]            │
# │          │                   │                    │                      │ kernel: float32[3,3,64,64]   │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 36,928 (147.7 KB)            │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ conv4    │ Conv              │ float64[3,2,64]    │ float64[3,2,128]     │ bias: float32[128]           │
# │          │                   │                    │                      │ kernel: float32[3,3,64,128]  │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 73,856 (295.4 KB)            │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ conv41   │ Conv              │ float64[3,2,128]   │ float64[3,2,128]     │ bias: float32[128]           │
# │          │                   │                    │                      │ kernel: float32[3,3,128,128] │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 147,584 (590.3 KB)           │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm1    │ OptimizedLSTMCell │ - - float64[128]   │ - - float64[1,1,128] │                              │
# │          │                   │   - float64[128]   │   - float64[1,1,128] │                              │
# │          │                   │ - float64[1,1,128] │ - float64[1,1,128]   │                              │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm1/ii │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm1/hi │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm1/if │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm1/hf │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm1/ig │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm1/hg │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm1/io │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm1/ho │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm2    │ OptimizedLSTMCell │ - - float64[128]   │ - - float64[1,1,128] │                              │
# │          │                   │   - float64[128]   │   - float64[1,1,128] │                              │
# │          │                   │ - float64[1,1,128] │ - float64[1,1,128]   │                              │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm2/ii │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm2/hi │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm2/if │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm2/hf │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm2/ig │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm2/hg │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm2/io │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm2/ho │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm3    │ OptimizedLSTMCell │ - - float64[128]   │ - - float64[1,1,128] │                              │
# │          │                   │   - float64[128]   │   - float64[1,1,128] │                              │
# │          │                   │ - float64[1,1,128] │ - float64[1,1,128]   │                              │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm3/ii │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm3/hi │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm3/if │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm3/hf │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm3/ig │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm3/hg │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm3/io │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm3/ho │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm4    │ OptimizedLSTMCell │ - - float64[128]   │ - - float64[1,1,128] │                              │
# │          │                   │   - float64[128]   │   - float64[1,1,128] │                              │
# │          │                   │ - float64[1,1,128] │ - float64[1,1,128]   │                              │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm4/ii │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm4/hi │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm4/if │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm4/hf │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm4/ig │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm4/hg │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm4/io │ DenseParams       │ float64[1,1,128]   │ - float32[128,128]   │ kernel: float32[128,128]     │
# │          │                   │                    │ - None               │                              │
# │          │                   │                    │                      │ 16,384 (65.5 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │ lstm4/ho │ DenseParams       │ float64[128]       │ - float32[128,128]   │ bias: float32[128]           │
# │          │                   │                    │ - float32[128]       │ kernel: float32[128,128]     │
# │          │                   │                    │                      │                              │
# │          │                   │                    │                      │ 16,512 (66.0 KB)             │
# ├──────────┼───────────────────┼────────────────────┼──────────────────────┼──────────────────────────────┤
# │          │                   │                    │                Total │ 819,856 (3.3 MB)             │
# └──────────┴───────────────────┴────────────────────┴──────────────────────┴──────────────────────────────┘
#
#                                     Total Parameters: 819,856 (3.3 MB)

# %% [markdown]
# ## Phase 1

# %%
hidden_net = HiddenNet()
closure_net = ClosureNet()
inflow_net = InflowNet()

# %% [markdown]
# ### Simulation Function

# %%
@jax.jit
def conv_diff_single_step(params,
                          smoke_initial: jnp.array,
                          hidden_state: jnp.array,
                          cell_state: jnp.array,
                          velocity: jnp.array,
                          time_curr: float,
                          inflow_loc: jnp.array,
                          inflow_vals: jnp.array,
                          terrain: jnp.array,
                          dt: float):
    y,x = inflow_loc
    inflow_marker = jnp.zeros((26,49))
    for i in range(len(REL_LOC)):
        rel_y, rel_x = REL_LOC[i]

        # set smoke at inflow locations
        inflow_marker = inflow_marker.at[y+rel_y, x+rel_x].set(1.0)

    # compute inflow term
    input = jnp.stack((terrain,
                       velocity[0,:,:],
                       velocity[1,:,:],
                       velocity[2,:,:],
                       jnp.pad(params['diffusivity_x'], ((0, 0), (1, 0))),
                       jnp.pad(params['diffusivity_y'], ((1, 0), (0, 0))),
                       inflow_marker), axis=-1) #(4,)
    inflow = inflow_net.apply({'params': params['inflow']}, input)
    inflow_term = jnp.zeros((26,49))
    for i in range(len(REL_LOC)):
        rel_y, rel_x = REL_LOC[i]
        inflow_term = inflow_term.at[y+rel_y, x+rel_x].set(inflow[i])

    smoke_pred = smoke_initial
    for _ in range(NSUBSTEPS):
      advection_step = physics.advect_fvm(field=smoke_pred,
                                              velocity=velocity,
                                              dx=dx,
                                              dy=dy) * dt/NSUBSTEPS

      diffusion_step = physics.diffuse_2d_fvm(field=smoke_pred,
                                              diffusivity_x=params['diffusivity_x'],
                                              diffusivity_y=params['diffusivity_y'],
                                              dx=dx,
                                              dy=dy) * dt/NSUBSTEPS

      inflow_step = inflow_term * dt/NSUBSTEPS
      smoke_pred = smoke_pred + advection_step + diffusion_step + inflow_step

    # compute closure term
    smoke_mean = jnp.mean(smoke_initial)
    eps = 1e-8
    smoke_std = jnp.std(smoke_initial)
    smoke_std_safe = jnp.where(smoke_std > eps, smoke_std, eps)
    input = jnp.stack(((smoke_initial-smoke_mean)/smoke_std_safe,
                        terrain * smoke_mean,
                        terrain * smoke_std,
                        velocity[0,:,:],
                        velocity[1,:,:],
                        velocity[2,:,:],
                        jnp.pad(params['diffusivity_x'], ((0, 0), (1, 0))),
                        jnp.pad(params['diffusivity_y'], ((1, 0), (0, 0))),
                        inflow_term,
                        terrain), axis=-1)  # (26,49,8)

    # (26,49,1)
    output = closure_net.apply({'params': params['closure']}, input, hidden_state)
    # print(jnp.mean(output), jnp.std(output))
    closure_term = output * 1e-10        # a denormalization value, from previous tests
    smoke_pred = (smoke_pred\
                    + closure_term.squeeze()) * terrain

    time_next = time_curr + dt

    # smoke_pred = jnp.maximum(smoke_pred, 0.0)

    # update hidden states
    mean = jnp.mean(smoke_pred)
    std = jnp.std(smoke_pred)
    input = jnp.stack(((smoke_pred-mean)/std,
                        TERRAIN * mean,
                        TERRAIN * std), axis=-1)  # (26,49,4)
    hidden_pred, cell_pred = hidden_net.apply({'params': params['hidden']}, input, hidden_state, cell_state)   # (128,)

    return (smoke_pred, hidden_pred, cell_pred, time_next, params, inflow_loc, inflow_vals), smoke_pred

# %% [markdown]
# ### Training Function

# %%
def scan_body(carry, _):
    (smoke, hidden, cell, time, params, inflow_loc, inflow_vals, step_idx, nsteps) = carry

    do_step = step_idx < nsteps
    (smoke_next, hidden_next, cell_next, time_next, _, _, _), _ = conv_diff_single_step(
        params, smoke, hidden, cell, VELOCITY, time, inflow_loc, inflow_vals, TERRAIN, dt
    )

    # Select updated state only if we're still under nsteps
    smoke = jax.lax.select(do_step, smoke_next, smoke)
    hidden = jax.lax.select(do_step, hidden_next, hidden)
    cell = jax.lax.select(do_step, cell_next, cell)
    time = jax.lax.select(do_step, time_next, time)

    # smoke_to_chain = jax.lax.select(do_step, smoke_next, jnp.zeros((ny,nx)))

    return (smoke, hidden, cell, time, params, inflow_loc, inflow_vals, step_idx + 1, nsteps), smoke

@jax.jit
def conv_diff_nsteps(params, smoke_initial, hidden_initial, cell_initial, time_initial,
                     inflow_loc, inflow_vals, nsteps):
    carry = (smoke_initial, hidden_initial, cell_initial, time_initial,
             params, inflow_loc, inflow_vals, 0, nsteps)
    (smoke_final, hidden_final, cell_final, _, _, _, _, _, _), smoke_pred_chain = \
        jax.lax.scan(scan_body, carry, xs=None, length=MAX_STEPS)
    return smoke_final, hidden_final, cell_final, smoke_pred_chain

# %%
conv_diff_nstep_vmap = jax.vmap(conv_diff_nsteps, in_axes=(None, 0, 0, 0, 0, 0, 0, 0), out_axes=(0, 0, 0, 0))
stagger_gradient_vmap = jax.vmap(physics.stagger_gradient, in_axes=(0, None, None), out_axes=(0, 0))

# %%
@jax.jit
def l2_loss(x, alpha):
  return alpha * (x ** 2).sum()

@jax.jit
def loss_fn(params,
            smoke_initial_all,
            hidden_initial_all,
            cell_initial_all,
            time_initial_all,
            nsteps_all,
            inflow_loc_all,
            inflow_vals_all,
            smoke_target_all,
            mask_target_all,
            thresh):
    smoke_pred_all, hidden_final_all, cell_final_all, smoke_pred_chain = conv_diff_nstep_vmap(params,
                                                                                              smoke_initial_all,
                                                                                              hidden_initial_all,
                                                                                              cell_initial_all,
                                                                                              time_initial_all,
                                                                                              inflow_loc_all,
                                                                                              inflow_vals_all,
                                                                                              nsteps_all)
    loss1 = (optax.l2_loss(smoke_pred_chain, smoke_target_all)/(smoke_target_all+1e-9)**2)*mask_target_all[:, :, None, None]
    loss1 = jnp.sum(jnp.mean(loss1, axis=(2,3)))

    loss2 = sum(
                l2_loss(w, alpha=1e-6)
                for w in jax.tree_util.tree_leaves(params['closure'])
            )
    loss3 = jnp.sum((smoke_pred_chain[:,1:] - smoke_pred_chain[:,:-1])**2)*1e4

    loss = loss1+loss2+loss3
    return loss, (smoke_pred_all, hidden_final_all, cell_final_all, loss1, loss2, loss3)

def train_step(state,
              batch_size:int,
              smoke_initial_set:list,
              hidden_initial_set:list,
              cell_initial_set:list,
              time_initial_set:list,
              dt:float,
              thresh:float=1e-9):

    grads_batch = None
    loss_batch = 0.0
    loss1_batch = 0.0

    batch_count = 0

    grad_fn = jax.value_and_grad(loss_fn, has_aux=True)
    jit_grad_fn = jax.jit(grad_fn)

    grads_all = None

    nsim = []
    while batch_count < batch_size:
      # list of indices that has not yet reached the final timestep
      valid_sets = [i for i in range(len(SMOKE_FIELD)) if time_initial_set[i]<len(FLOW_TIMES[i])-1]

      # indices of smoke states that should be propagated
      to_sample = min(len(valid_sets), batch_size-batch_count)
      nsim.append(to_sample)
      set_indices = random.sample(valid_sets, min(len(valid_sets), to_sample))
      batch_count += len(set_indices)

      # suppose s = len(set_indices)
      smoke_initial_all = jnp.array([smoke_initial_set[set_idx] for set_idx in set_indices])    # (s,ny,nx)
      hidden_initial_all = jnp.array([hidden_initial_set[set_idx] for set_idx in set_indices])  # (s,256)
      cell_initial_all = jnp.array([cell_initial_set[set_idx] for set_idx in set_indices])      # (s,256)
      time_initial_all = jnp.array([FLOW_TIMES[set_idx][time_initial_set[set_idx]] for set_idx in set_indices]) # (s,)
      inflow_loc_all = jnp.array([INFLOW_LOCS[set_idx] for set_idx in set_indices])
      inflow_vals_all = jnp.array([INFLOW_VALS[set_idx] for set_idx in set_indices])

      # simulate to the next 60s
      time_final_all = jnp.array([int((FLOW_TIMES[set_idx][time_initial_set[set_idx]]+60.0)/60.0)*60.0 for set_idx in set_indices])  # (s,)
      time_final_idx = [list(FLOW_TIMES[set_idx]).index(time_final_all[i]) for i,set_idx in enumerate(set_indices)]

      nsteps_all = ((time_final_all - time_initial_all + 1e-3)/dt).astype(int)  # (s,)

      smoke_target_all = jnp.zeros((len(set_indices), MAX_STEPS, ny, nx))   # (s, MAX_STEPS, ny, nx)
      mask_target_all = jnp.zeros((len(set_indices), MAX_STEPS))            # (s, MAX_STEPS)
      for i, set_idx in enumerate(set_indices):     # i from 0 to s-1
        for j in range(time_initial_set[set_idx]+1, time_final_idx[i]+1):   # look at all the indices which has a desired SMOKE_FIELD
          t_shifted_idx = int((FLOW_TIMES[set_idx][j]-FLOW_TIMES[set_idx][time_initial_set[set_idx]]+1e-3)/dt)
          smoke_target_all = smoke_target_all.at[i,t_shifted_idx].set(SMOKE_FIELD[set_idx][j])
          mask_target_all = mask_target_all.at[i,t_shifted_idx].set(1.0)

      (loss, (smoke_pred_all, hidden_pred_all, cell_final_all, loss1, loss2, loss3)), grads = grad_fn(state.params,
                                                                                smoke_initial_all,
                                                                                hidden_initial_all,
                                                                                cell_initial_all,
                                                                                time_initial_all,
                                                                                nsteps_all,
                                                                                inflow_loc_all,
                                                                                inflow_vals_all,
                                                                                smoke_target_all,
                                                                                mask_target_all,
                                                                                thresh)

      if grads_all == None:
        grads_all = grads
      else:
        grads_all = jax.tree_util.tree_map(lambda x, y: x + y, grads_all, grads)

      # update the set of initial values with the predicted values
      for i,set_idx in enumerate(set_indices):
        smoke_initial_set[set_idx] = smoke_pred_all[i]
        hidden_initial_set[set_idx] = hidden_pred_all[i]
        cell_initial_set[set_idx] = cell_final_all[i]
        time_initial_set[set_idx] = time_final_idx[i]

    grads_all = jax.tree_util.tree_map(lambda x: x/batch_size, grads_all)

    ## gradient clipping
    clipper = optax.clip_by_global_norm(0.1)
    clip_state = clipper.init(grads_all)
    new_grads, clip_state = clipper.update(grads_all, clip_state)

    state = state.apply_gradients(grads=new_grads)

    state.params['diffusivity_x'] = state.params['diffusivity_x'] * diff_x_mask
    state.params['diffusivity_y'] = state.params['diffusivity_y'] * diff_y_mask
    state.params['diffusivity_x'] = jnp.maximum(state.params['diffusivity_x'], 0.0)
    state.params['diffusivity_y'] = jnp.maximum(state.params['diffusivity_y'], 0.0)

    return state, loss, smoke_initial_set, hidden_initial_set, cell_initial_set, time_initial_set, loss1, loss2, loss3, nsim

# %%
def create_train_state(params_nn, params_physics, learning_rate):
    params = {}
    params['closure'] = params_nn['closure']
    params['hidden'] = params_nn['hidden']
    params['inflow'] = params_nn['inflow']
    params['diffusivity_x'] = params_physics['diffusivity_x']
    params['diffusivity_y'] = params_physics['diffusivity_y']

    tx = optax.adam(learning_rate)
    return train_state.TrainState.create(apply_fn=conv_diff_nsteps,
                                         params=params,
                                         tx=tx)

# %% [markdown]
# ### Phase 1.1 Training

# %%
# 500 epochs
first_larger_index = [jnp.searchsorted(dataset['FLOW_TIMES'][i], 60.0, side='right') for i in range(len(dataset['FLOW_TIMES']))]
FLOW_TIMES = [jnp.array(dataset['FLOW_TIMES'][i][:first_larger_index[i]]) for i in train_set]
SMOKE_FIELD = [jnp.array(dataset['SMOKE_FIELD'][i][:first_larger_index[i]]) for i in train_set]

params_nn = {}
params_nn['closure'] = closure_net.init(jax.random.PRNGKey(0), jnp.zeros((ny, nx, 10)), [jnp.zeros((128,)), jnp.zeros((128,)), jnp.zeros((128,)), jnp.zeros((128,))])['params']
params_nn['hidden'] = hidden_net.init(jax.random.PRNGKey(0), jnp.zeros((ny, nx, 3)), [jnp.zeros((128,)), jnp.zeros((128,)), jnp.zeros((128,)), jnp.zeros((128,))], [jnp.zeros((128,)), jnp.zeros((128,)), jnp.zeros((128,)), jnp.zeros((128,))])['params']
params_nn['inflow'] = inflow_net.init(jax.random.PRNGKey(0), jnp.zeros((1, ny, nx, 7)))['params']
params_physics = {}
params_physics['diffusivity_x'] = turb_diff_x
params_physics['diffusivity_y'] = turb_diff_y

# %%
state = create_train_state(params_nn=params_nn, params_physics=params_physics,learning_rate=1e-5)

# %%
BATCH_SIZE = 5
ITR_PER_EPOCH = len(FLOW_TIMES)*1

losses = []
min_loss = np.inf
for epoch in range(0,500):
    epoch_loss = 0.0
    data_loss = 0.0

    start = time.time()
    hidden_curr_set = []
    cell_curr_set = []
    smoke_curr_set = []
    for set_idx in range(len(SMOKE_FIELD)):
        smoke_curr_set.append(jnp.zeros((ny,nx)))
        hidden_curr_set.append(jnp.zeros((4,128)))
        cell_curr_set.append(jnp.zeros((4,128)))

    time_curr_set = [0 for _ in range(len(SMOKE_FIELD))]

    itr = 0
    while itr < ITR_PER_EPOCH:
        itr_batch_size = min(BATCH_SIZE, ITR_PER_EPOCH-itr)
        state, loss, smoke_curr_set, hidden_curr_set, cell_curr_set, time_curr_set, loss1, loss2, loss3, nsim = \
            train_step(state,
                        batch_size=itr_batch_size,
                        smoke_initial_set=smoke_curr_set,
                        hidden_initial_set=hidden_curr_set,
                        cell_initial_set=cell_curr_set,
                        time_initial_set=time_curr_set,
                        dt=dt,
                        thresh=1e-8)

        itr += BATCH_SIZE
        print(f"EPOCH {epoch}, batch size: {itr_batch_size}, nsim={nsim} loss={loss:.4f}, rel loss={loss1:.4f}, reg loss={loss2}, smooth loss={loss3}")
        epoch_loss += loss
        data_loss += loss1
    # saving every 100 epochs
    if epoch%100==99:
        state_dict = flax.serialization.to_state_dict(state)
        with open(f'{FILENAME_PREFIX}_epoch_{epoch}.pickle', 'wb') as handle:
            pickle.dump(state_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

    if epoch_loss < min_loss:
        state_dict = flax.serialization.to_state_dict(state)
        with open(f'{FILENAME_PREFIX}_min.pickle', 'wb') as handle:
            pickle.dump(state_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
        min_loss = epoch_loss
        print("New minimum achieved")

    losses.append(epoch_loss)
    end = time.time()
    print(f"EPOCH {epoch} (time={(end-start):.1f}): loss={epoch_loss:.4f}, data_loss={data_loss:.4f}")

jax.clear_caches()
# Out:
# EPOCH 0, batch size: 5, nsim=[5] loss=4262.2526, rel loss=4262.2520, reg loss=0.0005409484729170799, smooth loss=6.021694976830143e-05
# EPOCH 0, batch size: 5, nsim=[5] loss=56172.3226, rel loss=56172.3220, reg loss=0.0005409487057477236, smooth loss=5.144614838722714e-05
# EPOCH 0, batch size: 5, nsim=[5] loss=57758.2740, rel loss=57758.2734, reg loss=0.0005409488221630454, smooth loss=5.3205329872100856e-05
# EPOCH 0, batch size: 5, nsim=[5] loss=15332.0764, rel loss=15332.0758, reg loss=0.0005409489967860281, smooth loss=6.113223134410942e-05
# EPOCH 0, batch size: 5, nsim=[5] loss=122040.6246, rel loss=122040.6239, reg loss=0.00054094911320135, smooth loss=0.00011092825817432176
# EPOCH 0, batch size: 1, nsim=[1] loss=36562.6195, rel loss=36562.6190, reg loss=0.0005409491714090109, smooth loss=1.0360127493226526e-05
# New minimum achieved
# EPOCH 0 (time=71.0): loss=292128.1696, data_loss=292128.1660
# EPOCH 1, batch size: 5, nsim=[5] loss=12230.9337, rel loss=12230.9331, reg loss=0.0005409492296166718, smooth loss=6.384152732896787e-05
# EPOCH 1, batch size: 5, nsim=[5] loss=55141.9725, rel loss=55141.9719, reg loss=0.0005409492296166718, smooth loss=5.810022635495443e-05
# EPOCH 1, batch size: 5, nsim=[5] loss=45312.9763, rel loss=45312.9757, reg loss=0.0005409493460319936, smooth loss=5.205939175678585e-05
# EPOCH 1, batch size: 5, nsim=[5] loss=21433.4479, rel loss=21433.4473, reg loss=0.0005409493460319936, smooth loss=4.7810978361645806e-05
# EPOCH 1, batch size: 5, nsim=[5] loss=151609.3662, rel loss=151609.3655, reg loss=0.0005409495206549764, smooth loss=0.00011049716719990564
# EPOCH 1, batch size: 1, nsim=[1] loss=513.7647, rel loss=513.7641, reg loss=0.0005409495788626373, smooth loss=1.151331644110915e-05
# New minimum achieved
# EPOCH 1 (time=13.7): loss=286242.4613, data_loss=286242.4577
# EPOCH 2, batch size: 5, nsim=[5] loss=87537.2132, rel loss=87537.2126, reg loss=0.0005409496370702982, smooth loss=5.22696107315274e-05
# EPOCH 2, batch size: 5, nsim=[5] loss=14661.1091, rel loss=14661.1085, reg loss=0.0005409496952779591, smooth loss=5.0074240819279444e-05
# EPOCH 2, batch size: 5, nsim=[5] loss=124785.9719, rel loss=124785.9713, reg loss=0.00054094975348562, smooth loss=0.00011293468472920212
# EPOCH 2, batch size: 5, nsim=[5] loss=20477.1145, rel loss=20477.1139, reg loss=0.0005409498116932809, smooth loss=6.030777953889637e-05
# EPOCH 2, batch size: 5, nsim=[5] loss=32850.7223, rel loss=32850.7217, reg loss=0.0005409498699009418, smooth loss=5.819944413341697e-05
# EPOCH 2, batch size: 1, nsim=[1] loss=1515.8036, rel loss=1515.8031, reg loss=0.0005409499863162637, smooth loss=7.039113830793143e-06
# New minimum achieved
# EPOCH 2 (time=13.3): loss=281827.9346, data_loss=281827.9310
# EPOCH 3, batch size: 5, nsim=[5] loss=5560.7578, rel loss=5560.7572, reg loss=0.0005409500445239246, smooth loss=5.9483045728369075e-05
# EPOCH 3, batch size: 5, nsim=[5] loss=63583.3838, rel loss=63583.3832, reg loss=0.0005409503355622292, smooth loss=5.072272770162354e-05
# EPOCH 3, batch size: 5, nsim=[5] loss=53987.1533, rel loss=53987.1527, reg loss=0.000540950451977551, smooth loss=6.248225783654804e-05
# EPOCH 3, batch size: 5, nsim=[5] loss=27881.9152, rel loss=27881.9146, reg loss=0.0005409505683928728, smooth loss=5.147754871263275e-05
# EPOCH 3, batch size: 5, nsim=[5] loss=120317.1362, rel loss=120317.1356, reg loss=0.0005409506266005337, smooth loss=0.00010430002935110088
# EPOCH 3, batch size: 1, nsim=[1] loss=3939.8729, rel loss=3939.8724, reg loss=0.0005409507430158556, smooth loss=9.224864778105321e-06
# New minimum achieved
# EPOCH 3 (time=13.4): loss=275270.2193, data_loss=275270.2157
# EPOCH 4, batch size: 5, nsim=[5] loss=75888.8240, rel loss=75888.8235, reg loss=0.0005409508012235165, smooth loss=5.121676646359034e-05
# EPOCH 4, batch size: 5, nsim=[5] loss=113512.8826, rel loss=113512.8820, reg loss=0.0005409508594311774, smooth loss=0.00010608320396863686
# EPOCH 4, batch size: 5, nsim=[5] loss=44632.0106, rel loss=44632.0100, reg loss=0.0005409510340541601, smooth loss=5.3806411444571975e-05
# EPOCH 4, batch size: 5, nsim=[5] loss=21340.1559, rel loss=21340.1553, reg loss=0.000540951092261821, smooth loss=5.552895525950424e-05
# EPOCH 4, batch size: 5, nsim=[5] loss=12391.6623, rel loss=12391.6617, reg loss=0.0005409512086771429, smooth loss=5.902620404371014e-05
# EPOCH 4, batch size: 1, nsim=[1] loss=3891.3085, rel loss=3891.3079, reg loss=0.0005409512668848038, smooth loss=9.141020621075336e-06
# New minimum achieved
# EPOCH 4 (time=13.4): loss=271656.8439, data_loss=271656.8403
# EPOCH 5, batch size: 5, nsim=[5] loss=56077.4405, rel loss=56077.4399, reg loss=0.0005409513250924647, smooth loss=6.200514477369415e-05
# EPOCH 5, batch size: 5, nsim=[5] loss=54909.7554, rel loss=54909.7549, reg loss=0.0005409514415077865, smooth loss=5.18627561244331e-05
# EPOCH 5, batch size: 5, nsim=[5] loss=111461.4714, rel loss=111461.4708, reg loss=0.0005409515579231083, smooth loss=0.00010143836452227147
# EPOCH 5, batch size: 5, nsim=[5] loss=28637.0897, rel loss=28637.0891, reg loss=0.0005409516743384302, smooth loss=4.82488002245277e-05
# EPOCH 5, batch size: 5, nsim=[5] loss=13267.4003, rel loss=13267.3997, reg loss=0.000540951790753752, smooth loss=5.695612704067289e-05
# EPOCH 5, batch size: 1, nsim=[1] loss=1468.9212, rel loss=1468.9206, reg loss=0.0005409519071690738, smooth loss=1.1268769361488412e-05
# New minimum achieved
# EPOCH 5 (time=13.3): loss=265822.0785, data_loss=265822.0749
# EPOCH 6, batch size: 5, nsim=[5] loss=54233.7594, rel loss=54233.7588, reg loss=0.0005409519653767347, smooth loss=4.9820182946620466e-05
# EPOCH 6, batch size: 5, nsim=[5] loss=18303.5997, rel loss=18303.5991, reg loss=0.0005409521399997175, smooth loss=5.805786794151147e-05
# EPOCH 6, batch size: 5, nsim=[5] loss=103319.6872, rel loss=103319.6866, reg loss=0.0005409522564150393, smooth loss=0.00011106616087158703
# EPOCH 6, batch size: 5, nsim=[5] loss=36464.6347, rel loss=36464.6341, reg loss=0.0005409523146227002, smooth loss=4.584376129142335e-05
# EPOCH 6, batch size: 5, nsim=[5] loss=37418.5439, rel loss=37418.5433, reg loss=0.0005409523728303611, smooth loss=5.467421587595227e-05
# EPOCH 6, batch size: 1, nsim=[1] loss=10890.0882, rel loss=10890.0876, reg loss=0.000540952431038022, smooth loss=9.363051773595141e-06
# New minimum achieved
# EPOCH 6 (time=13.7): loss=260630.3131, data_loss=260630.3095
# EPOCH 7, batch size: 5, nsim=[5] loss=40873.8694, rel loss=40873.8688, reg loss=0.0005409526056610048, smooth loss=5.055033420425335e-05
# EPOCH 7, batch size: 5, nsim=[5] loss=31998.8238, rel loss=31998.8232, reg loss=0.0005409527220763266, smooth loss=5.08610332376445e-05
# EPOCH 7, batch size: 5, nsim=[5] loss=31996.7520, rel loss=31996.7514, reg loss=0.0005409528384916484, smooth loss=5.9551594322469615e-05
# EPOCH 7, batch size: 5, nsim=[5] loss=96131.8126, rel loss=96131.8119, reg loss=0.0005409529549069703, smooth loss=0.0001052698376654231
# EPOCH 7, batch size: 5, nsim=[5] loss=9896.6449, rel loss=9896.6443, reg loss=0.0005409530713222921, smooth loss=4.912461620978707e-05
# EPOCH 7, batch size: 1, nsim=[1] loss=44293.1646, rel loss=44293.1640, reg loss=0.0005409531877376139, smooth loss=1.0124520200161725e-05
# New minimum achieved
# EPOCH 7 (time=13.6): loss=255191.0672, data_loss=255191.0636
# EPOCH 8, batch size: 5, nsim=[5] loss=48729.3399, rel loss=48729.3393, reg loss=0.0005409533623605967, smooth loss=4.926919540923244e-05
# EPOCH 8, batch size: 5, nsim=[5] loss=58092.3006, rel loss=58092.3000, reg loss=0.0005409534787759185, smooth loss=4.546092147782822e-05
# EPOCH 8, batch size: 5, nsim=[5] loss=10532.7533, rel loss=10532.7527, reg loss=0.0005409535951912403, smooth loss=5.9141076013702916e-05
# EPOCH 8, batch size: 5, nsim=[5] loss=119027.5677, rel loss=119027.5670, reg loss=0.0005409537116065621, smooth loss=0.00010052815839766675
# EPOCH 8, batch size: 5, nsim=[5] loss=13553.2872, rel loss=13553.2866, reg loss=0.000540953828021884, smooth loss=5.433452812163744e-05
# EPOCH 8, batch size: 1, nsim=[1] loss=474.3780, rel loss=474.3775, reg loss=0.0005409539444372058, smooth loss=1.3437120427924975e-05
# New minimum achieved
# EPOCH 8 (time=13.4): loss=250409.6267, data_loss=250409.6231
# EPOCH 9, batch size: 5, nsim=[5] loss=112401.5827, rel loss=112401.5820, reg loss=0.0005409541190601885, smooth loss=9.890611976589916e-05
# EPOCH 9, batch size: 5, nsim=[5] loss=14593.1464, rel loss=14593.1458, reg loss=0.0005409542354755104, smooth loss=5.654400753488615e-05
# EPOCH 9, batch size: 5, nsim=[5] loss=11641.6732, rel loss=11641.6727, reg loss=0.0005409543518908322, smooth loss=5.176313515140208e-05
# EPOCH 9, batch size: 5, nsim=[5] loss=4432.0356, rel loss=4432.0350, reg loss=0.0005409545265138149, smooth loss=5.3439295681402066e-05
# EPOCH 9, batch size: 5, nsim=[5] loss=78937.1751, rel loss=78937.1745, reg loss=0.0005409547011367977, smooth loss=5.027018389577197e-05
# EPOCH 9, batch size: 1, nsim=[1] loss=24643.3431, rel loss=24643.3425, reg loss=0.0005409548175521195, smooth loss=8.65587312897628e-06
# New minimum achieved
# EPOCH 9 (time=13.5): loss=246648.9561, data_loss=246648.9525
# EPOCH 10, batch size: 5, nsim=[5] loss=27699.0111, rel loss=27699.0105, reg loss=0.0005409550503827631, smooth loss=5.1479642107400975e-05
# EPOCH 10, batch size: 5, nsim=[5] loss=139667.8444, rel loss=139667.8438, reg loss=0.000540955166798085, smooth loss=0.00010068653365949628
# EPOCH 10, batch size: 5, nsim=[5] loss=48906.8235, rel loss=48906.8229, reg loss=0.0005409553414210677, smooth loss=4.963123869086289e-05
# EPOCH 10, batch size: 5, nsim=[5] loss=11321.2355, rel loss=11321.2349, reg loss=0.0005409554578363895, smooth loss=4.871912311658785e-05
# EPOCH 10, batch size: 5, nsim=[5] loss=13842.6790, rel loss=13842.6784, reg loss=0.0005409556324593723, smooth loss=5.368467693715623e-05
# EPOCH 10, batch size: 1, nsim=[1] loss=702.2571, rel loss=702.2565, reg loss=0.000540955807082355, smooth loss=1.2731141032510695e-05
# New minimum achieved
# EPOCH 10 (time=13.3): loss=242139.8506, data_loss=242139.8470
# EPOCH 11, batch size: 5, nsim=[5] loss=17208.9239, rel loss=17208.9233, reg loss=0.0005409559234976768, smooth loss=4.915108228378707e-05
# EPOCH 11, batch size: 5, nsim=[5] loss=130118.9005, rel loss=130118.8998, reg loss=0.0005409560399129987, smooth loss=0.00010133896685565081
# EPOCH 11, batch size: 5, nsim=[5] loss=11598.4291, rel loss=11598.4285, reg loss=0.0005409562145359814, smooth loss=4.977061638146536e-05
# EPOCH 11, batch size: 5, nsim=[5] loss=43673.2281, rel loss=43673.2275, reg loss=0.0005409563309513032, smooth loss=5.2023470689754927e-05
# EPOCH 11, batch size: 5, nsim=[5] loss=32156.0647, rel loss=32156.0641, reg loss=0.000540956505574286, smooth loss=5.440559064950638e-05
# EPOCH 11, batch size: 1, nsim=[1] loss=3147.7529, rel loss=3147.7524, reg loss=0.0005409566801972687, smooth loss=8.010852908257619e-06
# New minimum achieved
# EPOCH 11 (time=14.0): loss=237903.2992, data_loss=237903.2957
# EPOCH 12, batch size: 5, nsim=[5] loss=16534.4764, rel loss=16534.4758, reg loss=0.0005409568548202515, smooth loss=5.104914518844505e-05
# EPOCH 12, batch size: 5, nsim=[5] loss=10900.9131, rel loss=10900.9125, reg loss=0.0005409570294432342, smooth loss=4.139074720082712e-05
# EPOCH 12, batch size: 5, nsim=[5] loss=13212.9721, rel loss=13212.9715, reg loss=0.0005409572040662169, smooth loss=5.58002771617877e-05
# EPOCH 12, batch size: 5, nsim=[5] loss=32123.3061, rel loss=32123.3055, reg loss=0.0005409573786891997, smooth loss=5.05439141095736e-05
# EPOCH 12, batch size: 5, nsim=[5] loss=159996.3559, rel loss=159996.3552, reg loss=0.0005409574951045215, smooth loss=9.65209851659883e-05
# EPOCH 12, batch size: 1, nsim=[1] loss=233.4727, rel loss=233.4722, reg loss=0.0005409576697275043, smooth loss=1.71079522964846e-05
# New minimum achieved
# EPOCH 12 (time=13.6): loss=233001.4963, data_loss=233001.4927
# EPOCH 13, batch size: 5, nsim=[5] loss=30959.5049, rel loss=30959.5043, reg loss=0.0005409579025581479, smooth loss=4.877223955394264e-05
# EPOCH 13, batch size: 5, nsim=[5] loss=14850.6357, rel loss=14850.6351, reg loss=0.0005409580189734697, smooth loss=5.2850891830764115e-05
# EPOCH 13, batch size: 5, nsim=[5] loss=93285.4052, rel loss=93285.4046, reg loss=0.0005409581935964525, smooth loss=0.00010803812928949561
# EPOCH 13, batch size: 5, nsim=[5] loss=36991.3051, rel loss=36991.3045, reg loss=0.0005409583682194352, smooth loss=5.331075192679474e-05
# EPOCH 13, batch size: 5, nsim=[5] loss=50848.5057, rel loss=50848.5052, reg loss=0.000540958542842418, smooth loss=3.944296502635863e-05
# EPOCH 13, batch size: 1, nsim=[1] loss=3555.5032, rel loss=3555.5026, reg loss=0.0005409587174654007, smooth loss=8.485891095029428e-06
# New minimum achieved
# EPOCH 13 (time=13.4): loss=230490.8599, data_loss=230490.8564
# EPOCH 14, batch size: 5, nsim=[5] loss=37436.1832, rel loss=37436.1826, reg loss=0.0005409588920883834, smooth loss=4.4626973034349975e-05
# EPOCH 14, batch size: 5, nsim=[5] loss=113809.8535, rel loss=113809.8529, reg loss=0.0005409590667113662, smooth loss=0.0001009770463844506
# EPOCH 14, batch size: 5, nsim=[5] loss=7562.1323, rel loss=7562.1317, reg loss=0.0005409592995420098, smooth loss=4.801193278747376e-05
# EPOCH 14, batch size: 5, nsim=[5] loss=12462.2136, rel loss=12462.2130, reg loss=0.0005409594159573317, smooth loss=4.4020550048958186e-05
# EPOCH 14, batch size: 5, nsim=[5] loss=55930.4884, rel loss=55930.4878, reg loss=0.0005409597069956362, smooth loss=5.7947802191887244e-05
# EPOCH 14, batch size: 1, nsim=[1] loss=228.4591, rel loss=228.4586, reg loss=0.000540959823410958, smooth loss=1.3766686762514355e-05
# New minimum achieved
# EPOCH 14 (time=13.7): loss=227429.3300, data_loss=227429.3265
# EPOCH 15, batch size: 5, nsim=[5] loss=112627.1333, rel loss=112627.1327, reg loss=0.0005409600562416017, smooth loss=0.00010687213254813848
# EPOCH 15, batch size: 5, nsim=[5] loss=8183.9218, rel loss=8183.9212, reg loss=0.0005409602308645844, smooth loss=4.886595731080826e-05
# EPOCH 15, batch size: 5, nsim=[5] loss=12782.8122, rel loss=12782.8116, reg loss=0.0005409604054875672, smooth loss=5.140146062802115e-05
# EPOCH 15, batch size: 5, nsim=[5] loss=46441.4813, rel loss=46441.4807, reg loss=0.0005409606383182108, smooth loss=4.313897231562466e-05
# EPOCH 15, batch size: 5, nsim=[5] loss=37563.3171, rel loss=37563.3165, reg loss=0.0005409608711488545, smooth loss=4.919971462586994e-05
# EPOCH 15, batch size: 1, nsim=[1] loss=6586.5653, rel loss=6586.5647, reg loss=0.0005409611039794981, smooth loss=8.548490143707302e-06
# New minimum achieved
# EPOCH 15 (time=13.5): loss=224185.2310, data_loss=224185.2274
# EPOCH 16, batch size: 5, nsim=[5] loss=14189.6645, rel loss=14189.6639, reg loss=0.00054096122039482, smooth loss=6.271164174401745e-05
# EPOCH 16, batch size: 5, nsim=[5] loss=5558.9036, rel loss=5558.9030, reg loss=0.0005409613950178027, smooth loss=4.957883833423458e-05
# EPOCH 16, batch size: 5, nsim=[5] loss=137328.9187, rel loss=137328.9180, reg loss=0.0005409616860561073, smooth loss=9.213643168137633e-05
# EPOCH 16, batch size: 5, nsim=[5] loss=50909.8280, rel loss=50909.8274, reg loss=0.00054096186067909, smooth loss=5.351951226908335e-05
# EPOCH 16, batch size: 5, nsim=[5] loss=11276.7373, rel loss=11276.7368, reg loss=0.0005409621517173946, smooth loss=4.248695930963769e-05
# EPOCH 16, batch size: 1, nsim=[1] loss=1303.4366, rel loss=1303.4360, reg loss=0.0005409623845480382, smooth loss=6.325166749168337e-06
# New minimum achieved
# EPOCH 16 (time=13.6): loss=220567.4887, data_loss=220567.4851
# EPOCH 17, batch size: 5, nsim=[5] loss=33135.6807, rel loss=33135.6801, reg loss=0.0005409626755863428, smooth loss=4.7350425318452785e-05
# EPOCH 17, batch size: 5, nsim=[5] loss=25966.5141, rel loss=25966.5135, reg loss=0.0005409629666246474, smooth loss=4.336785393854297e-05
# EPOCH 17, batch size: 5, nsim=[5] loss=4572.0324, rel loss=4572.0318, reg loss=0.0005409633158706129, smooth loss=5.953799157579926e-05
# EPOCH 17, batch size: 5, nsim=[5] loss=117613.6373, rel loss=117613.6367, reg loss=0.0005409636069089174, smooth loss=9.604970440450115e-05
# EPOCH 17, batch size: 5, nsim=[5] loss=35391.9814, rel loss=35391.9808, reg loss=0.0005409639561548829, smooth loss=4.677049096160294e-05
# EPOCH 17, batch size: 1, nsim=[1] loss=668.6775, rel loss=668.6769, reg loss=0.0005409641889855266, smooth loss=1.2199885984158381e-05
# New minimum achieved
# EPOCH 17 (time=13.3): loss=217348.5233, data_loss=217348.5197
# EPOCH 18, batch size: 5, nsim=[5] loss=8622.4475, rel loss=8622.4470, reg loss=0.0005409644218161702, smooth loss=4.4009272081115164e-05
# EPOCH 18, batch size: 5, nsim=[5] loss=10253.1498, rel loss=10253.1492, reg loss=0.0005409646546468139, smooth loss=4.62748067152754e-05
# EPOCH 18, batch size: 5, nsim=[5] loss=121422.3779, rel loss=121422.3773, reg loss=0.0005409650038927794, smooth loss=9.250810949889743e-05
# EPOCH 18, batch size: 5, nsim=[5] loss=44685.9980, rel loss=44685.9974, reg loss=0.0005409652949310839, smooth loss=6.16622281978468e-05
# EPOCH 18, batch size: 5, nsim=[5] loss=27454.2592, rel loss=27454.2586, reg loss=0.0005409655277617276, smooth loss=4.749818327875192e-05
# EPOCH 18, batch size: 1, nsim=[1] loss=1949.5151, rel loss=1949.5145, reg loss=0.0005409657605923712, smooth loss=1.1709327363092667e-05
# New minimum achieved
# EPOCH 18 (time=13.4): loss=214387.7476, data_loss=214387.7440
# EPOCH 19, batch size: 5, nsim=[5] loss=66710.7098, rel loss=66710.7092, reg loss=0.0005409660516306758, smooth loss=5.2462338089712754e-05
# EPOCH 19, batch size: 5, nsim=[5] loss=6248.6110, rel loss=6248.6104, reg loss=0.0005409662262536585, smooth loss=5.0549063334495804e-05
# EPOCH 19, batch size: 5, nsim=[5] loss=21899.4022, rel loss=21899.4016, reg loss=0.0005409664590843022, smooth loss=4.798601584547757e-05
# EPOCH 19, batch size: 5, nsim=[5] loss=106812.9117, rel loss=106812.9111, reg loss=0.0005409667501226068, smooth loss=9.645902719198175e-05
# EPOCH 19, batch size: 5, nsim=[5] loss=9162.1130, rel loss=9162.1124, reg loss=0.0005409669829532504, smooth loss=4.642797331296277e-05
# EPOCH 19, batch size: 1, nsim=[1] loss=473.4945, rel loss=473.4940, reg loss=0.000540967273991555, smooth loss=8.341705273308581e-06
# New minimum achieved
# EPOCH 19 (time=13.5): loss=211307.2423, data_loss=211307.2387
# EPOCH 20, batch size: 5, nsim=[5] loss=9280.1932, rel loss=9280.1926, reg loss=0.0005409675068221986, smooth loss=5.005987342306891e-05
# EPOCH 20, batch size: 5, nsim=[5] loss=35436.4898, rel loss=35436.4893, reg loss=0.0005409678560681641, smooth loss=5.247617834177747e-05
# EPOCH 20, batch size: 5, nsim=[5] loss=18011.8813, rel loss=18011.8807, reg loss=0.0005409681471064687, smooth loss=4.8129508558372944e-05
# EPOCH 20, batch size: 5, nsim=[5] loss=90380.2008, rel loss=90380.2001, reg loss=0.0005409685545600951, smooth loss=9.514797847028005e-05
# EPOCH 20, batch size: 5, nsim=[5] loss=54897.2953, rel loss=54897.2947, reg loss=0.0005409687873907387, smooth loss=4.162949622110545e-05
# EPOCH 20, batch size: 1, nsim=[1] loss=203.4191, rel loss=203.4185, reg loss=0.0005409691366367042, smooth loss=1.334527994714525e-05
# New minimum achieved
# EPOCH 20 (time=13.6): loss=208209.4794, data_loss=208209.4759
# EPOCH 21, batch size: 5, nsim=[5] loss=33451.7717, rel loss=33451.7711, reg loss=0.0005409694276750088, smooth loss=4.5120380378978974e-05
# EPOCH 21, batch size: 5, nsim=[5] loss=14860.9824, rel loss=14860.9819, reg loss=0.0005409696605056524, smooth loss=4.0518255466149293e-05
# EPOCH 21, batch size: 5, nsim=[5] loss=76173.3266, rel loss=76173.3259, reg loss=0.000540969951543957, smooth loss=9.253843309788313e-05
# EPOCH 21, batch size: 5, nsim=[5] loss=46726.8639, rel loss=46726.8633, reg loss=0.0005409701261669397, smooth loss=5.738008599681765e-05
# EPOCH 21, batch size: 5, nsim=[5] loss=27546.6975, rel loss=27546.6969, reg loss=0.0005409704172052443, smooth loss=5.332051001556821e-05
# EPOCH 21, batch size: 1, nsim=[1] loss=6789.5307, rel loss=6789.5302, reg loss=0.000540970591828227, smooth loss=1.0485803353895746e-05
# New minimum achieved
# EPOCH 21 (time=13.5): loss=205549.1729, data_loss=205549.1694
# EPOCH 22, batch size: 5, nsim=[5] loss=10480.2976, rel loss=10480.2970, reg loss=0.0005409708828665316, smooth loss=4.94587387381754e-05
# EPOCH 22, batch size: 5, nsim=[5] loss=30293.2702, rel loss=30293.2696, reg loss=0.0005409711739048362, smooth loss=5.895754905609734e-05
# EPOCH 22, batch size: 5, nsim=[5] loss=9886.2256, rel loss=9886.2250, reg loss=0.0005409715231508017, smooth loss=4.4813130889264284e-05
# EPOCH 22, batch size: 5, nsim=[5] loss=8145.3820, rel loss=8145.3814, reg loss=0.0005409718141891062, smooth loss=4.68211409950574e-05
# EPOCH 22, batch size: 5, nsim=[5] loss=133851.8618, rel loss=133851.8612, reg loss=0.000540971988812089, smooth loss=8.954552915768574e-05
# EPOCH 22, batch size: 1, nsim=[1] loss=9571.2269, rel loss=9571.2264, reg loss=0.0005409722216427326, smooth loss=8.456045664762234e-06
# New minimum achieved
# EPOCH 22 (time=13.4): loss=202228.2642, data_loss=202228.2606
# EPOCH 23, batch size: 5, nsim=[5] loss=65591.7345, rel loss=65591.7339, reg loss=0.0005409725126810372, smooth loss=9.765155093215574e-05
# EPOCH 23, batch size: 5, nsim=[5] loss=77438.7063, rel loss=77438.7057, reg loss=0.0005409727455116808, smooth loss=5.3507688633090724e-05
# EPOCH 23, batch size: 5, nsim=[5] loss=10628.4865, rel loss=10628.4859, reg loss=0.0005409729783423245, smooth loss=5.9030367514544224e-05
# EPOCH 23, batch size: 5, nsim=[5] loss=33283.8684, rel loss=33283.8678, reg loss=0.0005409732693806291, smooth loss=4.427993475611359e-05
# EPOCH 23, batch size: 5, nsim=[5] loss=7966.3019, rel loss=7966.3013, reg loss=0.0005409735022112727, smooth loss=3.430429890648973e-05
# EPOCH 23, batch size: 1, nsim=[1] loss=5743.6714, rel loss=5743.6708, reg loss=0.0005409737932495773, smooth loss=8.167814217049875e-06
# New minimum achieved
# EPOCH 23 (time=13.6): loss=200652.7690, data_loss=200652.7654
# EPOCH 24, batch size: 5, nsim=[5] loss=52319.2306, rel loss=52319.2301, reg loss=0.0005409740260802209, smooth loss=4.023995999126422e-05
# EPOCH 24, batch size: 5, nsim=[5] loss=69638.4886, rel loss=69638.4880, reg loss=0.0005409744917415082, smooth loss=9.766947488717207e-05
# EPOCH 24, batch size: 5, nsim=[5] loss=38315.7761, rel loss=38315.7755, reg loss=0.0005409747245721519, smooth loss=4.4913161501526564e-05
# EPOCH 24, batch size: 5, nsim=[5] loss=26464.8662, rel loss=26464.8656, reg loss=0.0005409750156104565, smooth loss=5.139739217366799e-05
# EPOCH 24, batch size: 5, nsim=[5] loss=10504.5407, rel loss=10504.5401, reg loss=0.000540975364856422, smooth loss=4.821814545171931e-05
# EPOCH 24, batch size: 1, nsim=[1] loss=190.1759, rel loss=190.1754, reg loss=0.0005409756558947265, smooth loss=1.3084642513158861e-05
# New minimum achieved
# EPOCH 24 (time=13.5): loss=197433.0781, data_loss=197433.0746
# EPOCH 25, batch size: 5, nsim=[5] loss=13361.2517, rel loss=13361.2511, reg loss=0.0005409759469330311, smooth loss=5.372184079649364e-05
# EPOCH 25, batch size: 5, nsim=[5] loss=6918.9317, rel loss=6918.9311, reg loss=0.0005409761797636747, smooth loss=4.468656028485177e-05
# EPOCH 25, batch size: 5, nsim=[5] loss=62392.6354, rel loss=62392.6348, reg loss=0.0005409764708019793, smooth loss=4.0903462552330054e-05
# EPOCH 25, batch size: 5, nsim=[5] loss=65357.2548, rel loss=65357.2541, reg loss=0.0005409767618402839, smooth loss=9.585617668078826e-05
# EPOCH 25, batch size: 5, nsim=[5] loss=44915.5455, rel loss=44915.5449, reg loss=0.0005409770528785884, smooth loss=4.690442587987269e-05
# EPOCH 25, batch size: 1, nsim=[1] loss=1119.0604, rel loss=1119.0599, reg loss=0.0005409772857092321, smooth loss=1.2002796464018349e-05
# New minimum achieved
# EPOCH 25 (time=13.4): loss=194064.6794, data_loss=194064.6759
# EPOCH 26, batch size: 5, nsim=[5] loss=8836.6413, rel loss=8836.6407, reg loss=0.0005409776349551976, smooth loss=4.810733751061631e-05
# EPOCH 26, batch size: 5, nsim=[5] loss=36463.6103, rel loss=36463.6098, reg loss=0.0005409778095781803, smooth loss=4.3953004084104546e-05
# EPOCH 26, batch size: 5, nsim=[5] loss=35152.1936, rel loss=35152.1930, reg loss=0.0005409781588241458, smooth loss=4.3918290078332376e-05
# EPOCH 26, batch size: 5, nsim=[5] loss=41229.9806, rel loss=41229.9800, reg loss=0.0005409784498624504, smooth loss=5.2397662600053926e-05
# EPOCH 26, batch size: 5, nsim=[5] loss=69639.5635, rel loss=69639.5628, reg loss=0.000540978682693094, smooth loss=9.642814561471727e-05
# EPOCH 26, batch size: 1, nsim=[1] loss=52.4000, rel loss=52.3994, reg loss=0.0005409789737313986, smooth loss=7.84383206556923e-06
# New minimum achieved
# EPOCH 26 (time=13.6): loss=191374.3893, data_loss=191374.3858
# EPOCH 27, batch size: 5, nsim=[5] loss=6164.9758, rel loss=6164.9752, reg loss=0.0005409791483543813, smooth loss=4.880539574798899e-05
# EPOCH 27, batch size: 5, nsim=[5] loss=61928.4908, rel loss=61928.4902, reg loss=0.000540979381185025, smooth loss=4.1873824372996296e-05
# EPOCH 27, batch size: 5, nsim=[5] loss=16017.1662, rel loss=16017.1656, reg loss=0.0005409796722233295, smooth loss=4.695388357662983e-05
# EPOCH 27, batch size: 5, nsim=[5] loss=59121.2851, rel loss=59121.2845, reg loss=0.0005409799050539732, smooth loss=0.00010509774369055253
# EPOCH 27, batch size: 5, nsim=[5] loss=45295.3194, rel loss=45295.3188, reg loss=0.0005409801378846169, smooth loss=4.0574942170981114e-05
# EPOCH 27, batch size: 1, nsim=[1] loss=435.6041, rel loss=435.6035, reg loss=0.0005409804289229214, smooth loss=7.99350951540839e-06
# New minimum achieved
# EPOCH 27 (time=13.5): loss=188962.8415, data_loss=188962.8379
# EPOCH 28, batch size: 5, nsim=[5] loss=64103.1440, rel loss=64103.1433, reg loss=0.0005409808363765478, smooth loss=0.00010048708227472801
# EPOCH 28, batch size: 5, nsim=[5] loss=40252.5104, rel loss=40252.5098, reg loss=0.0005409810692071915, smooth loss=5.7009126833250495e-05
# EPOCH 28, batch size: 5, nsim=[5] loss=51606.2566, rel loss=51606.2561, reg loss=0.000540981360245496, smooth loss=4.0869724631548984e-05
# EPOCH 28, batch size: 5, nsim=[5] loss=18706.2294, rel loss=18706.2289, reg loss=0.0005409817094914615, smooth loss=3.9793921238760715e-05
# EPOCH 28, batch size: 5, nsim=[5] loss=11190.9097, rel loss=11190.9091, reg loss=0.0005409820005297661, smooth loss=4.591328324905985e-05
# EPOCH 28, batch size: 1, nsim=[1] loss=1174.0000, rel loss=1173.9995, reg loss=0.0005409823497757316, smooth loss=5.933943877684049e-06
# New minimum achieved
# EPOCH 28 (time=13.5): loss=187033.0501, data_loss=187033.0466
# EPOCH 29, batch size: 5, nsim=[5] loss=36295.3139, rel loss=36295.3133, reg loss=0.000540982757229358, smooth loss=5.1418997942945085e-05
# EPOCH 29, batch size: 5, nsim=[5] loss=29506.4013, rel loss=29506.4007, reg loss=0.0005409832228906453, smooth loss=3.879050243898972e-05
# EPOCH 29, batch size: 5, nsim=[5] loss=56604.7198, rel loss=56604.7192, reg loss=0.0005409838049672544, smooth loss=4.420282023721798e-05
# EPOCH 29, batch size: 5, nsim=[5] loss=3156.7173, rel loss=3156.7168, reg loss=0.0005409842124208808, smooth loss=5.5262943350236374e-05
# EPOCH 29, batch size: 5, nsim=[5] loss=57641.9968, rel loss=57641.9962, reg loss=0.0005409846780821681, smooth loss=9.225473430713028e-05
# EPOCH 29, batch size: 1, nsim=[1] loss=237.8685, rel loss=237.8680, reg loss=0.0005409850273281336, smooth loss=6.351940397580407e-06
# New minimum achieved
# EPOCH 29 (time=13.5): loss=183443.0177, data_loss=183443.0141
# EPOCH 30, batch size: 5, nsim=[5] loss=44058.4916, rel loss=44058.4910, reg loss=0.0005409855511970818, smooth loss=4.36515397554769e-05
# EPOCH 30, batch size: 5, nsim=[5] loss=4269.7400, rel loss=4269.7394, reg loss=0.0005409859586507082, smooth loss=5.150268666505359e-05
# EPOCH 30, batch size: 5, nsim=[5] loss=11399.0158, rel loss=11399.0152, reg loss=0.0005409865407273173, smooth loss=5.042829053204038e-05
# EPOCH 30, batch size: 5, nsim=[5] loss=4738.5623, rel loss=4738.5617, reg loss=0.0005409870063886046, smooth loss=4.491025089333497e-05
# EPOCH 30, batch size: 5, nsim=[5] loss=65345.7580, rel loss=65345.7574, reg loss=0.000540987472049892, smooth loss=3.983412767673012e-05
# EPOCH 30, batch size: 1, nsim=[1] loss=50669.5760, rel loss=50669.5754, reg loss=0.0005409879377111793, smooth loss=5.6279007311911785e-05
# New minimum achieved
# EPOCH 30 (time=13.4): loss=180481.1436, data_loss=180481.1401
# EPOCH 31, batch size: 5, nsim=[5] loss=88429.8205, rel loss=88429.8199, reg loss=0.0005409884033724666, smooth loss=8.784115103630773e-05
# EPOCH 31, batch size: 5, nsim=[5] loss=7026.9428, rel loss=7026.9422, reg loss=0.000540988810826093, smooth loss=4.215623985952063e-05
# EPOCH 31, batch size: 5, nsim=[5] loss=43571.2136, rel loss=43571.2130, reg loss=0.0005409891600720584, smooth loss=5.7195590007275347e-05
# EPOCH 31, batch size: 5, nsim=[5] loss=27613.7561, rel loss=27613.7555, reg loss=0.0005409895675256848, smooth loss=3.840076421116676e-05
# EPOCH 31, batch size: 5, nsim=[5] loss=12192.5274, rel loss=12192.5269, reg loss=0.0005409898003563285, smooth loss=4.778518118786162e-05
# EPOCH 31, batch size: 1, nsim=[1] loss=367.2476, rel loss=367.2470, reg loss=0.000540990149602294, smooth loss=1.1874924041527324e-05
# New minimum achieved
# EPOCH 31 (time=13.4): loss=179201.5081, data_loss=179201.5045
# EPOCH 32, batch size: 5, nsim=[5] loss=59945.1069, rel loss=59945.1063, reg loss=0.0005409906152635813, smooth loss=4.449620737326368e-05
# EPOCH 32, batch size: 5, nsim=[5] loss=82727.6806, rel loss=82727.6800, reg loss=0.0005409908480942249, smooth loss=8.50789599143568e-05
# EPOCH 32, batch size: 5, nsim=[5] loss=11064.8376, rel loss=11064.8370, reg loss=0.0005409912555478513, smooth loss=4.5921425912097965e-05
# EPOCH 32, batch size: 5, nsim=[5] loss=17353.5311, rel loss=17353.5305, reg loss=0.0005409916047938168, smooth loss=4.296845944835168e-05
# EPOCH 32, batch size: 5, nsim=[5] loss=5170.0793, rel loss=5170.0787, reg loss=0.0005409920122474432, smooth loss=5.9417106539053496e-05
# EPOCH 32, batch size: 1, nsim=[1] loss=231.2889, rel loss=231.2884, reg loss=0.0005409923032857478, smooth loss=6.271345799669948e-06
# New minimum achieved
# EPOCH 32 (time=13.4): loss=176492.5244, data_loss=176492.5209
# EPOCH 33, batch size: 5, nsim=[5] loss=6309.9518, rel loss=6309.9512, reg loss=0.000540992827154696, smooth loss=5.036099850243486e-05
# EPOCH 33, batch size: 5, nsim=[5] loss=17453.8558, rel loss=17453.8552, reg loss=0.0005409934092313051, smooth loss=4.7969208756382746e-05
# EPOCH 33, batch size: 5, nsim=[5] loss=76832.2983, rel loss=76832.2977, reg loss=0.0005409938748925924, smooth loss=9.147176441941903e-05
# EPOCH 33, batch size: 5, nsim=[5] loss=32889.8615, rel loss=32889.8609, reg loss=0.0005409943405538797, smooth loss=4.233652417430709e-05
# EPOCH 33, batch size: 5, nsim=[5] loss=39644.1151, rel loss=39644.1145, reg loss=0.000540994864422828, smooth loss=4.244109834358232e-05
# EPOCH 33, batch size: 1, nsim=[1] loss=607.4670, rel loss=607.4664, reg loss=0.0005409952718764544, smooth loss=8.412917826165359e-06
# New minimum achieved
# EPOCH 33 (time=13.6): loss=173737.5495, data_loss=173737.5459
# EPOCH 34, batch size: 5, nsim=[5] loss=44339.0146, rel loss=44339.0140, reg loss=0.0005409956793300807, smooth loss=5.323357228759788e-05
# EPOCH 34, batch size: 5, nsim=[5] loss=77489.9783, rel loss=77489.9777, reg loss=0.0005409960285760462, smooth loss=8.804555527845588e-05
# EPOCH 34, batch size: 5, nsim=[5] loss=23936.5284, rel loss=23936.5278, reg loss=0.0005409964942373335, smooth loss=4.569717899711475e-05
# EPOCH 34, batch size: 5, nsim=[5] loss=8492.5992, rel loss=8492.5986, reg loss=0.000540996843483299, smooth loss=4.739256245896522e-05
# EPOCH 34, batch size: 5, nsim=[5] loss=17273.7115, rel loss=17273.7109, reg loss=0.0005409971927292645, smooth loss=4.172669988407409e-05
# EPOCH 34, batch size: 1, nsim=[1] loss=236.2845, rel loss=236.2840, reg loss=0.00054099754197523, smooth loss=5.665891914634249e-06
# New minimum achieved
# EPOCH 34 (time=13.4): loss=171768.1166, data_loss=171768.1131
# EPOCH 35, batch size: 5, nsim=[5] loss=33666.1029, rel loss=33666.1023, reg loss=0.0005409979494288564, smooth loss=4.7773855348614716e-05
# EPOCH 35, batch size: 5, nsim=[5] loss=3960.3936, rel loss=3960.3931, reg loss=0.0005409984150901437, smooth loss=4.019791136085096e-05
# EPOCH 35, batch size: 5, nsim=[5] loss=54532.9609, rel loss=54532.9603, reg loss=0.0005409988225437701, smooth loss=4.6508785051378494e-05
# EPOCH 35, batch size: 5, nsim=[5] loss=10454.9718, rel loss=10454.9712, reg loss=0.0005409992299973965, smooth loss=4.3489649225494237e-05
# EPOCH 35, batch size: 5, nsim=[5] loss=22307.4362, rel loss=22307.4356, reg loss=0.0005409996956586838, smooth loss=4.671893365170743e-05
# EPOCH 35, batch size: 1, nsim=[1] loss=43877.5075, rel loss=43877.5069, reg loss=0.0005410000449046493, smooth loss=5.574894171208644e-05
# New minimum achieved
# EPOCH 35 (time=13.4): loss=168799.3729, data_loss=168799.3694
# EPOCH 36, batch size: 5, nsim=[5] loss=14102.6451, rel loss=14102.6445, reg loss=0.0005410004523582757, smooth loss=4.851491072209481e-05
# EPOCH 36, batch size: 5, nsim=[5] loss=92506.7086, rel loss=92506.7079, reg loss=0.000541000859811902, smooth loss=8.79731046630346e-05
# EPOCH 36, batch size: 5, nsim=[5] loss=50185.7254, rel loss=50185.7248, reg loss=0.0005410012672655284, smooth loss=4.027369853638559e-05
# EPOCH 36, batch size: 5, nsim=[5] loss=2874.8853, rel loss=2874.8847, reg loss=0.0005410016165114939, smooth loss=4.8925940498091675e-05
# EPOCH 36, batch size: 5, nsim=[5] loss=3130.9939, rel loss=3130.9933, reg loss=0.0005410020821727812, smooth loss=4.593067294595841e-05
# EPOCH 36, batch size: 1, nsim=[1] loss=4568.1937, rel loss=4568.1932, reg loss=0.0005410024314187467, smooth loss=7.6030198173353565e-06
# New minimum achieved
# EPOCH 36 (time=13.4): loss=167369.1519, data_loss=167369.1484
# EPOCH 37, batch size: 5, nsim=[5] loss=9477.6943, rel loss=9477.6937, reg loss=0.0005410027806647122, smooth loss=4.5950563377589445e-05
# EPOCH 37, batch size: 5, nsim=[5] loss=31540.3651, rel loss=31540.3645, reg loss=0.0005410031299106777, smooth loss=4.212651242542571e-05
# EPOCH 37, batch size: 5, nsim=[5] loss=81556.6488, rel loss=81556.6482, reg loss=0.0005410035373643041, smooth loss=8.400921726471566e-05
# EPOCH 37, batch size: 5, nsim=[5] loss=5656.3374, rel loss=5656.3368, reg loss=0.0005410038866102695, smooth loss=4.918432568704094e-05
# EPOCH 37, batch size: 5, nsim=[5] loss=9129.6907, rel loss=9129.6901, reg loss=0.000541004235856235, smooth loss=4.8777358162129164e-05
# EPOCH 37, batch size: 1, nsim=[1] loss=27506.8563, rel loss=27506.8557, reg loss=0.0005410046433098614, smooth loss=8.045032529940923e-06
# New minimum achieved
# EPOCH 37 (time=13.4): loss=164867.5925, data_loss=164867.5889
# EPOCH 38, batch size: 5, nsim=[5] loss=71261.8578, rel loss=71261.8572, reg loss=0.0005410049925558269, smooth loss=9.147266382190793e-05
# EPOCH 38, batch size: 5, nsim=[5] loss=19543.5579, rel loss=19543.5573, reg loss=0.0005410053418017924, smooth loss=4.00503085345685e-05
# EPOCH 38, batch size: 5, nsim=[5] loss=25621.1990, rel loss=25621.1985, reg loss=0.0005410058656707406, smooth loss=4.03206971099239e-05
# EPOCH 38, batch size: 5, nsim=[5] loss=6849.5127, rel loss=6849.5121, reg loss=0.0005410063313320279, smooth loss=4.886749026311097e-05
# EPOCH 38, batch size: 5, nsim=[5] loss=38813.3759, rel loss=38813.3753, reg loss=0.0005410066805779934, smooth loss=4.4945884767915946e-05
# EPOCH 38, batch size: 1, nsim=[1] loss=1008.0248, rel loss=1008.0243, reg loss=0.0005410071462392807, smooth loss=1.1230310287159227e-05
# New minimum achieved
# EPOCH 38 (time=13.7): loss=163097.5282, data_loss=163097.5246
# EPOCH 39, batch size: 5, nsim=[5] loss=12558.1223, rel loss=12558.1218, reg loss=0.0005410075536929071, smooth loss=4.3038988386530475e-05
# EPOCH 39, batch size: 5, nsim=[5] loss=27906.1977, rel loss=27906.1972, reg loss=0.0005410080193541944, smooth loss=5.082530215868816e-05
# EPOCH 39, batch size: 5, nsim=[5] loss=31967.9680, rel loss=31967.9674, reg loss=0.0005410084850154817, smooth loss=4.30739674783343e-05
# EPOCH 39, batch size: 5, nsim=[5] loss=44947.0766, rel loss=44947.0759, reg loss=0.0005410088924691081, smooth loss=9.415601839534621e-05
# EPOCH 39, batch size: 5, nsim=[5] loss=6765.8455, rel loss=6765.8449, reg loss=0.0005410092999227345, smooth loss=3.588371608402392e-05
# EPOCH 39, batch size: 1, nsim=[1] loss=35977.4647, rel loss=35977.4641, reg loss=0.0005410098819993436, smooth loss=8.325872555398519e-06
# New minimum achieved
# EPOCH 39 (time=13.4): loss=160122.6748, data_loss=160122.6713
# EPOCH 40, batch size: 5, nsim=[5] loss=38582.3450, rel loss=38582.3444, reg loss=0.0005410103476606309, smooth loss=4.4759693323991456e-05
# EPOCH 40, batch size: 5, nsim=[5] loss=44414.5248, rel loss=44414.5241, reg loss=0.0005410107551142573, smooth loss=8.75216272291668e-05
# EPOCH 40, batch size: 5, nsim=[5] loss=15485.0011, rel loss=15485.0005, reg loss=0.0005410111625678837, smooth loss=4.529387971600489e-05
# EPOCH 40, batch size: 5, nsim=[5] loss=32841.6156, rel loss=32841.6150, reg loss=0.000541011686436832, smooth loss=4.85373970383778e-05
# EPOCH 40, batch size: 5, nsim=[5] loss=26809.3722, rel loss=26809.3716, reg loss=0.0005410122685134411, smooth loss=4.014054272435983e-05
# EPOCH 40, batch size: 1, nsim=[1] loss=46.3304, rel loss=46.3298, reg loss=0.0005410127341747284, smooth loss=7.263469239848807e-06
# New minimum achieved
# EPOCH 40 (time=13.4): loss=158179.1889, data_loss=158179.1854
# EPOCH 41, batch size: 5, nsim=[5] loss=12125.5320, rel loss=12125.5314, reg loss=0.0005410130834206939, smooth loss=4.336120275184398e-05
# EPOCH 41, batch size: 5, nsim=[5] loss=78491.4613, rel loss=78491.4606, reg loss=0.0005410134326666594, smooth loss=8.351155646514849e-05
# EPOCH 41, batch size: 5, nsim=[5] loss=26846.0579, rel loss=26846.0573, reg loss=0.0005410137237049639, smooth loss=4.9466493507169284e-05
# EPOCH 41, batch size: 5, nsim=[5] loss=2050.2902, rel loss=2050.2896, reg loss=0.0005410141311585903, smooth loss=4.261434278139732e-05
# EPOCH 41, batch size: 5, nsim=[5] loss=33690.4781, rel loss=33690.4775, reg loss=0.0005410144804045558, smooth loss=4.5924225020629486e-05
# EPOCH 41, batch size: 1, nsim=[1] loss=2585.6803, rel loss=2585.6797, reg loss=0.0005410147714428604, smooth loss=6.7914168637006e-06
# New minimum achieved
# EPOCH 41 (time=13.6): loss=155789.4997, data_loss=155789.4962
# EPOCH 42, batch size: 5, nsim=[5] loss=47818.8291, rel loss=47818.8285, reg loss=0.0005410152371041477, smooth loss=4.214246318040755e-05
# EPOCH 42, batch size: 5, nsim=[5] loss=28968.7461, rel loss=28968.7455, reg loss=0.0005410156445577741, smooth loss=3.885836617866234e-05
# EPOCH 42, batch size: 5, nsim=[5] loss=30237.9865, rel loss=30237.9859, reg loss=0.0005410161102190614, smooth loss=4.655586652794206e-05
# EPOCH 42, batch size: 5, nsim=[5] loss=7673.6865, rel loss=7673.6859, reg loss=0.0005410164012573659, smooth loss=4.355762816797429e-05
# EPOCH 42, batch size: 5, nsim=[5] loss=38461.2477, rel loss=38461.2471, reg loss=0.0005410168087109923, smooth loss=9.344532055537757e-05
# EPOCH 42, batch size: 1, nsim=[1] loss=211.2067, rel loss=211.2061, reg loss=0.0005410173325799406, smooth loss=5.387281548682327e-06
# New minimum achieved
# EPOCH 42 (time=13.5): loss=153371.7026, data_loss=153371.6991
# EPOCH 43, batch size: 5, nsim=[5] loss=45020.6244, rel loss=45020.6237, reg loss=0.000541017740033567, smooth loss=9.139866966520912e-05
# EPOCH 43, batch size: 5, nsim=[5] loss=10108.8439, rel loss=10108.8433, reg loss=0.0005410182056948543, smooth loss=4.192196173433999e-05
# EPOCH 43, batch size: 5, nsim=[5] loss=44566.8642, rel loss=44566.8636, reg loss=0.0005410187295638025, smooth loss=4.2172172045054136e-05
# EPOCH 43, batch size: 5, nsim=[5] loss=40805.9693, rel loss=40805.9687, reg loss=0.000541019078809768, smooth loss=4.422949789471705e-05
# EPOCH 43, batch size: 5, nsim=[5] loss=10307.5412, rel loss=10307.5406, reg loss=0.0005410196026787162, smooth loss=3.793530398275515e-05
# EPOCH 43, batch size: 1, nsim=[1] loss=957.3640, rel loss=957.3635, reg loss=0.0005410200683400035, smooth loss=1.0882387979744959e-05
# New minimum achieved
# EPOCH 43 (time=13.3): loss=151767.2070, data_loss=151767.2035
# EPOCH 44, batch size: 5, nsim=[5] loss=40656.9738, rel loss=40656.9732, reg loss=0.0005410206504166126, smooth loss=8.603901878635365e-05
# EPOCH 44, batch size: 5, nsim=[5] loss=57782.1086, rel loss=57782.1080, reg loss=0.0005410211160778999, smooth loss=3.779661439025609e-05
# EPOCH 44, batch size: 5, nsim=[5] loss=2828.6480, rel loss=2828.6474, reg loss=0.0005410215817391872, smooth loss=4.622647136224455e-05
# EPOCH 44, batch size: 5, nsim=[5] loss=8208.4912, rel loss=8208.4906, reg loss=0.0005410219309851527, smooth loss=4.3451235185569554e-05
# EPOCH 44, batch size: 5, nsim=[5] loss=37718.0873, rel loss=37718.0867, reg loss=0.0005410223384387791, smooth loss=4.7043047090541485e-05
# EPOCH 44, batch size: 1, nsim=[1] loss=2521.1553, rel loss=2521.1547, reg loss=0.0005410228623077273, smooth loss=6.670743610785917e-06
# New minimum achieved
# EPOCH 44 (time=13.8): loss=149715.4641, data_loss=149715.4606
# EPOCH 45, batch size: 5, nsim=[5] loss=33892.1535, rel loss=33892.1529, reg loss=0.0005410233861766756, smooth loss=4.1079277076503584e-05
# EPOCH 45, batch size: 5, nsim=[5] loss=8654.4870, rel loss=8654.4864, reg loss=0.0005410239682532847, smooth loss=4.538702414881394e-05
# EPOCH 45, batch size: 5, nsim=[5] loss=38627.7251, rel loss=38627.7245, reg loss=0.000541024433914572, smooth loss=8.987506193167542e-05
# EPOCH 45, batch size: 5, nsim=[5] loss=45688.6105, rel loss=45688.6099, reg loss=0.0005410249577835202, smooth loss=4.5336630553082866e-05
# EPOCH 45, batch size: 5, nsim=[5] loss=19504.4178, rel loss=19504.4173, reg loss=0.0005410254234448075, smooth loss=3.515595303867763e-05
# EPOCH 45, batch size: 1, nsim=[1] loss=1050.3576, rel loss=1050.3570, reg loss=0.0005410260055214167, smooth loss=8.934988433967234e-06
# New minimum achieved
# EPOCH 45 (time=13.5): loss=147417.7515, data_loss=147417.7480
# EPOCH 46, batch size: 5, nsim=[5] loss=5238.2409, rel loss=5238.2403, reg loss=0.0005410264129750431, smooth loss=3.938840220923916e-05
# EPOCH 46, batch size: 5, nsim=[5] loss=15382.3036, rel loss=15382.3030, reg loss=0.0005410268786363304, smooth loss=4.2012415396315575e-05
# EPOCH 46, batch size: 5, nsim=[5] loss=28172.6389, rel loss=28172.6384, reg loss=0.0005410274607129395, smooth loss=4.2988397049687964e-05
# EPOCH 46, batch size: 5, nsim=[5] loss=46819.3855, rel loss=46819.3850, reg loss=0.0005410279845818877, smooth loss=3.751467071313856e-05
# EPOCH 46, batch size: 5, nsim=[5] loss=49443.4735, rel loss=49443.4729, reg loss=0.000541028450243175, smooth loss=8.826508368938075e-05
# EPOCH 46, batch size: 1, nsim=[1] loss=170.1502, rel loss=170.1496, reg loss=0.0005410289159044623, smooth loss=1.4077093174713924e-05
# New minimum achieved
# EPOCH 46 (time=13.4): loss=145226.1926, data_loss=145226.1891
# EPOCH 47, batch size: 5, nsim=[5] loss=33778.7635, rel loss=33778.7629, reg loss=0.0005410294397734106, smooth loss=4.7062733860308104e-05
# EPOCH 47, batch size: 5, nsim=[5] loss=36935.0593, rel loss=36935.0588, reg loss=0.0005410299054346979, smooth loss=3.5940833355559424e-05
# EPOCH 47, batch size: 5, nsim=[5] loss=4451.9071, rel loss=4451.9065, reg loss=0.0005410304293036461, smooth loss=4.320504767960767e-05
# EPOCH 47, batch size: 5, nsim=[5] loss=40196.5922, rel loss=40196.5916, reg loss=0.0005410309531725943, smooth loss=8.622806019539479e-05
# EPOCH 47, batch size: 5, nsim=[5] loss=24436.3739, rel loss=24436.3733, reg loss=0.0005410313024185598, smooth loss=4.326699892579555e-05
# EPOCH 47, batch size: 1, nsim=[1] loss=3809.9381, rel loss=3809.9375, reg loss=0.000541031826287508, smooth loss=7.145991250983444e-06
# New minimum achieved
# EPOCH 47 (time=13.4): loss=143608.6342, data_loss=143608.6307
# EPOCH 48, batch size: 5, nsim=[5] loss=60490.1892, rel loss=60490.1886, reg loss=0.0005410322337411344, smooth loss=8.871619618190001e-05
# EPOCH 48, batch size: 5, nsim=[5] loss=25204.5036, rel loss=25204.5030, reg loss=0.0005410326411947608, smooth loss=3.715679467863084e-05
# EPOCH 48, batch size: 5, nsim=[5] loss=36094.7433, rel loss=36094.7427, reg loss=0.0005410329904407263, smooth loss=4.447736349697051e-05
# EPOCH 48, batch size: 5, nsim=[5] loss=11766.3173, rel loss=11766.3167, reg loss=0.0005410333978943527, smooth loss=4.322735464551012e-05
# EPOCH 48, batch size: 5, nsim=[5] loss=8336.5379, rel loss=8336.5373, reg loss=0.00054103386355564, smooth loss=3.9647049621085996e-05
# EPOCH 48, batch size: 1, nsim=[1] loss=350.2804, rel loss=350.2799, reg loss=0.0005410343292169273, smooth loss=8.473464693950842e-06
# New minimum achieved
# EPOCH 48 (time=13.6): loss=142242.5717, data_loss=142242.5682
# EPOCH 49, batch size: 5, nsim=[5] loss=35689.3895, rel loss=35689.3888, reg loss=0.0005410347948782146, smooth loss=7.995348142813711e-05
# EPOCH 49, batch size: 5, nsim=[5] loss=35041.3386, rel loss=35041.3380, reg loss=0.000541035202331841, smooth loss=4.807303518254727e-05
# EPOCH 49, batch size: 5, nsim=[5] loss=28490.5937, rel loss=28490.5931, reg loss=0.0005410356097854674, smooth loss=4.0984638058817505e-05
# EPOCH 49, batch size: 5, nsim=[5] loss=33407.0170, rel loss=33407.0164, reg loss=0.0005410360172390938, smooth loss=3.927132840432202e-05
# EPOCH 49, batch size: 5, nsim=[5] loss=7410.8176, rel loss=7410.8170, reg loss=0.000541036541108042, smooth loss=4.389209747453425e-05
# EPOCH 49, batch size: 1, nsim=[1] loss=346.1581, rel loss=346.1575, reg loss=0.0005410370649769902, smooth loss=8.42977401125768e-06
# New minimum achieved
# EPOCH 49 (time=13.3): loss=140385.3144, data_loss=140385.3109
# EPOCH 50, batch size: 5, nsim=[5] loss=10944.7811, rel loss=10944.7805, reg loss=0.0005410374724306166, smooth loss=4.599949575595684e-05
# EPOCH 50, batch size: 5, nsim=[5] loss=68307.1346, rel loss=68307.1340, reg loss=0.0005410380545072258, smooth loss=3.579957746028792e-05
# EPOCH 50, batch size: 5, nsim=[5] loss=33208.1154, rel loss=33208.1148, reg loss=0.0005410386365838349, smooth loss=9.247801965830601e-05
# EPOCH 50, batch size: 5, nsim=[5] loss=18706.2358, rel loss=18706.2352, reg loss=0.0005410391604527831, smooth loss=3.61589866399688e-05
# EPOCH 50, batch size: 5, nsim=[5] loss=6914.8917, rel loss=6914.8912, reg loss=0.0005410396843217313, smooth loss=4.052506767676576e-05
# EPOCH 50, batch size: 1, nsim=[1] loss=341.3020, rel loss=341.3015, reg loss=0.0005410401499830186, smooth loss=8.382575120174265e-06
# New minimum achieved
# EPOCH 50 (time=13.6): loss=138422.4607, data_loss=138422.4571
# EPOCH 51, batch size: 5, nsim=[5] loss=9311.5409, rel loss=9311.5403, reg loss=0.0005410406738519669, smooth loss=4.90987255539705e-05
# EPOCH 51, batch size: 5, nsim=[5] loss=56357.7429, rel loss=56357.7423, reg loss=0.0005410411977209151, smooth loss=8.102210475044131e-05
# EPOCH 51, batch size: 5, nsim=[5] loss=27840.6408, rel loss=27840.6402, reg loss=0.0005410417215898633, smooth loss=3.691298221490213e-05
# EPOCH 51, batch size: 5, nsim=[5] loss=2763.4999, rel loss=2763.4993, reg loss=0.0005410422454588115, smooth loss=4.774379158781928e-05
# EPOCH 51, batch size: 5, nsim=[5] loss=36939.6318, rel loss=36939.6312, reg loss=0.0005410427111200988, smooth loss=3.640887899681426e-05
# EPOCH 51, batch size: 1, nsim=[1] loss=3586.7707, rel loss=3586.7702, reg loss=0.0005410431767813861, smooth loss=7.005205118516534e-06
# New minimum achieved
# EPOCH 51 (time=13.4): loss=136799.8270, data_loss=136799.8235
# EPOCH 52, batch size: 5, nsim=[5] loss=12606.7725, rel loss=12606.7719, reg loss=0.0005410437006503344, smooth loss=4.357788310111931e-05
# EPOCH 52, batch size: 5, nsim=[5] loss=63098.7229, rel loss=63098.7224, reg loss=0.0005410442827269435, smooth loss=3.678398139561736e-05
# EPOCH 52, batch size: 5, nsim=[5] loss=4223.1868, rel loss=4223.1862, reg loss=0.0005410447483882308, smooth loss=4.020430841926036e-05
# EPOCH 52, batch size: 5, nsim=[5] loss=29854.0985, rel loss=29854.0978, reg loss=0.0005410453886725008, smooth loss=8.742114106762037e-05
# EPOCH 52, batch size: 5, nsim=[5] loss=24754.9332, rel loss=24754.9326, reg loss=0.0005410457961261272, smooth loss=3.9016895863965694e-05
# EPOCH 52, batch size: 1, nsim=[1] loss=517.6081, rel loss=517.6075, reg loss=0.0005410463782027364, smooth loss=9.963006245314859e-06
# New minimum achieved
# ...
# EPOCH 481, batch size: 1, nsim=[1] loss=3.0206, rel loss=3.0200, reg loss=0.0005527105531655252, smooth loss=1.565325282329555e-07
# New minimum achieved
# EPOCH 481 (time=13.6): loss=404.2084, data_loss=404.2051
# EPOCH 482, batch size: 5, nsim=[5] loss=51.3279, rel loss=51.3274, reg loss=0.0005527185276150703, smooth loss=1.1115863172669857e-06
# EPOCH 482, batch size: 5, nsim=[5] loss=55.1706, rel loss=55.1700, reg loss=0.0005527257453650236, smooth loss=4.534474571347013e-07
# EPOCH 482, batch size: 5, nsim=[5] loss=24.0737, rel loss=24.0732, reg loss=0.0005527324974536896, smooth loss=4.667814780259843e-07
# EPOCH 482, batch size: 5, nsim=[5] loss=155.5204, rel loss=155.5198, reg loss=0.0005527391331270337, smooth loss=5.669054401665313e-07
# EPOCH 482, batch size: 5, nsim=[5] loss=110.4055, rel loss=110.4049, reg loss=0.0005527454195544124, smooth loss=3.952491703243966e-07
# EPOCH 482, batch size: 1, nsim=[1] loss=5.9304, rel loss=5.9299, reg loss=0.000552755780518055, smooth loss=7.64513632578007e-08
# New minimum achieved
# EPOCH 482 (time=13.4): loss=402.4285, data_loss=402.4252
# EPOCH 483, batch size: 5, nsim=[5] loss=84.8125, rel loss=84.8119, reg loss=0.000552766548935324, smooth loss=1.0621152903644342e-06
# EPOCH 483, batch size: 5, nsim=[5] loss=15.5943, rel loss=15.5937, reg loss=0.0005527765606530011, smooth loss=4.946229015691147e-07
# EPOCH 483, batch size: 5, nsim=[5] loss=173.6829, rel loss=173.6823, reg loss=0.0005527858156710863, smooth loss=4.2597877534148473e-07
# EPOCH 483, batch size: 5, nsim=[5] loss=100.0225, rel loss=100.0219, reg loss=0.0005527947214432061, smooth loss=4.311030486807627e-07
# EPOCH 483, batch size: 5, nsim=[5] loss=22.8248, rel loss=22.8242, reg loss=0.0005528070614673197, smooth loss=5.754970313160562e-07
# EPOCH 483, batch size: 1, nsim=[1] loss=4.8041, rel loss=4.8036, reg loss=0.0005528194596990943, smooth loss=7.998629602857844e-08
# New minimum achieved
# EPOCH 483 (time=13.4): loss=401.7410, data_loss=401.7376
# EPOCH 484, batch size: 5, nsim=[5] loss=116.8616, rel loss=116.8611, reg loss=0.0005528306355699897, smooth loss=5.278316335901612e-07
# EPOCH 484, batch size: 5, nsim=[5] loss=158.8750, rel loss=158.8744, reg loss=0.0005528455367311835, smooth loss=5.604388853185245e-07
# EPOCH 484, batch size: 5, nsim=[5] loss=63.0744, rel loss=63.0738, reg loss=0.0005528590991161764, smooth loss=1.033656298072847e-06
# EPOCH 484, batch size: 5, nsim=[5] loss=40.7920, rel loss=40.7915, reg loss=0.0005528713809326291, smooth loss=4.12111641213547e-07
# EPOCH 484, batch size: 5, nsim=[5] loss=17.5206, rel loss=17.5200, reg loss=0.0005528825568035245, smooth loss=3.7702167427795906e-07
# EPOCH 484, batch size: 1, nsim=[1] loss=3.0148, rel loss=3.0142, reg loss=0.0005528931505978107, smooth loss=1.5603428513723798e-07
# New minimum achieved
# EPOCH 484 (time=13.5): loss=400.1384, data_loss=400.1351
# EPOCH 485, batch size: 5, nsim=[5] loss=21.8976, rel loss=21.8971, reg loss=0.0005529032205231488, smooth loss=4.2436895290701547e-07
# EPOCH 485, batch size: 5, nsim=[5] loss=159.0120, rel loss=159.0115, reg loss=0.0005529127083718777, smooth loss=5.043014206501155e-07
# EPOCH 485, batch size: 5, nsim=[5] loss=17.0094, rel loss=17.0089, reg loss=0.0005529215559363365, smooth loss=5.333476300732225e-07
# EPOCH 485, batch size: 5, nsim=[5] loss=52.3380, rel loss=52.3374, reg loss=0.0005529303452931345, smooth loss=4.249193106966055e-07
# EPOCH 485, batch size: 5, nsim=[5] loss=146.5393, rel loss=146.5387, reg loss=0.0005529381451196969, smooth loss=1.090903146028362e-06
# EPOCH 485, batch size: 1, nsim=[1] loss=1.4075, rel loss=1.4070, reg loss=0.0005529456539079547, smooth loss=8.660852165521358e-08
# New minimum achieved
# EPOCH 485 (time=13.6): loss=398.2038, data_loss=398.2005
# EPOCH 486, batch size: 5, nsim=[5] loss=63.0240, rel loss=63.0235, reg loss=0.0005529524059966207, smooth loss=1.0331734691080212e-06
# EPOCH 486, batch size: 5, nsim=[5] loss=23.6553, rel loss=23.6548, reg loss=0.0005529585760086775, smooth loss=3.7486444001432817e-07
# EPOCH 486, batch size: 5, nsim=[5] loss=46.7544, rel loss=46.7539, reg loss=0.0005529646878130734, smooth loss=5.867524728592491e-07
# EPOCH 486, batch size: 5, nsim=[5] loss=13.8640, rel loss=13.8634, reg loss=0.0005529702757485211, smooth loss=5.62263951536988e-07
# EPOCH 486, batch size: 5, nsim=[5] loss=246.9082, rel loss=246.9076, reg loss=0.000552975048776716, smooth loss=3.5269210889080167e-07
# EPOCH 486, batch size: 1, nsim=[1] loss=3.3555, rel loss=3.3549, reg loss=0.0005529805785045028, smooth loss=1.537343164640348e-07
# New minimum achieved
# EPOCH 486 (time=13.4): loss=397.5614, data_loss=397.5581
# EPOCH 487, batch size: 5, nsim=[5] loss=58.6998, rel loss=58.6992, reg loss=0.0005529855261556804, smooth loss=1.1117718990536459e-06
# EPOCH 487, batch size: 5, nsim=[5] loss=154.6914, rel loss=154.6908, reg loss=0.0005529898917302489, smooth loss=5.051032726586331e-07
# EPOCH 487, batch size: 5, nsim=[5] loss=22.8105, rel loss=22.8099, reg loss=0.0005529939662665129, smooth loss=4.87841493680854e-07
# EPOCH 487, batch size: 5, nsim=[5] loss=29.1031, rel loss=29.1025, reg loss=0.0005529969348572195, smooth loss=3.967323781429456e-07
# EPOCH 487, batch size: 5, nsim=[5] loss=127.4920, rel loss=127.4914, reg loss=0.0005530006601475179, smooth loss=4.2524055837476446e-07
# EPOCH 487, batch size: 1, nsim=[1] loss=4.4617, rel loss=4.4612, reg loss=0.0005530050257220864, smooth loss=1.3656552797433857e-07
# New minimum achieved
# EPOCH 487 (time=13.5): loss=397.2584, data_loss=397.2550
# EPOCH 488, batch size: 5, nsim=[5] loss=52.9534, rel loss=52.9529, reg loss=0.0005530088674277067, smooth loss=1.099786758304905e-06
# EPOCH 488, batch size: 5, nsim=[5] loss=172.8660, rel loss=172.8655, reg loss=0.0005530123016797006, smooth loss=4.4056559543313563e-07
# EPOCH 488, batch size: 5, nsim=[5] loss=46.1554, rel loss=46.1548, reg loss=0.0005530157359316945, smooth loss=4.382470007213795e-07
# EPOCH 488, batch size: 5, nsim=[5] loss=109.0685, rel loss=109.0680, reg loss=0.0005530189955607057, smooth loss=4.329223546249615e-07
# EPOCH 488, batch size: 5, nsim=[5] loss=13.2798, rel loss=13.2792, reg loss=0.0005530263297259808, smooth loss=5.874650893555134e-07
# EPOCH 488, batch size: 1, nsim=[1] loss=1.5230, rel loss=1.5225, reg loss=0.0005530333146452904, smooth loss=6.407351501722789e-08
# New minimum achieved
# EPOCH 488 (time=13.4): loss=395.8461, data_loss=395.8428
# EPOCH 489, batch size: 5, nsim=[5] loss=48.6839, rel loss=48.6834, reg loss=0.0005530401831492782, smooth loss=1.0916582389456591e-06
# EPOCH 489, batch size: 5, nsim=[5] loss=128.4766, rel loss=128.4761, reg loss=0.0005530464113689959, smooth loss=4.2175760436503163e-07
# EPOCH 489, batch size: 5, nsim=[5] loss=20.7844, rel loss=20.7839, reg loss=0.000553053105250001, smooth loss=5.490634822872076e-07
# EPOCH 489, batch size: 5, nsim=[5] loss=31.5641, rel loss=31.5635, reg loss=0.0005530596827156842, smooth loss=4.08165211158892e-07
# EPOCH 489, batch size: 5, nsim=[5] loss=162.2104, rel loss=162.2099, reg loss=0.0005530682974494994, smooth loss=4.383847114593527e-07
# EPOCH 489, batch size: 1, nsim=[1] loss=3.3234, rel loss=3.3229, reg loss=0.0005530763883143663, smooth loss=1.5363499981837812e-07
# New minimum achieved
# EPOCH 489 (time=13.4): loss=395.0429, data_loss=395.0396
# EPOCH 490, batch size: 5, nsim=[5] loss=135.3464, rel loss=135.3458, reg loss=0.0005530836642719805, smooth loss=4.961272163848611e-07
# EPOCH 490, batch size: 5, nsim=[5] loss=28.1348, rel loss=28.1342, reg loss=0.000553091405890882, smooth loss=4.4086799395614517e-07
# EPOCH 490, batch size: 5, nsim=[5] loss=14.8052, rel loss=14.8046, reg loss=0.0005530984490178525, smooth loss=4.512973534174076e-07
# EPOCH 490, batch size: 5, nsim=[5] loss=49.9122, rel loss=49.9117, reg loss=0.0005531038041226566, smooth loss=1.01405993628479e-06
# EPOCH 490, batch size: 5, nsim=[5] loss=160.8604, rel loss=160.8598, reg loss=0.0005531086353585124, smooth loss=5.224060573941581e-07
# EPOCH 490, batch size: 1, nsim=[1] loss=4.4481, rel loss=4.4476, reg loss=0.0005531133501790464, smooth loss=1.3665934014747995e-07
# New minimum achieved
# EPOCH 490 (time=13.4): loss=393.5071, data_loss=393.5038
# EPOCH 491, batch size: 5, nsim=[5] loss=59.9302, rel loss=59.9296, reg loss=0.0005531174829229712, smooth loss=1.0712869730607908e-06
# EPOCH 491, batch size: 5, nsim=[5] loss=52.0729, rel loss=52.0724, reg loss=0.0005531212664209306, smooth loss=5.175585538379956e-07
# EPOCH 491, batch size: 5, nsim=[5] loss=11.3980, rel loss=11.3974, reg loss=0.0005531247588805854, smooth loss=5.157962792499369e-07
# EPOCH 491, batch size: 5, nsim=[5] loss=11.4242, rel loss=11.4237, reg loss=0.0005531280767172575, smooth loss=4.1410429555176605e-07
# EPOCH 491, batch size: 5, nsim=[5] loss=113.5452, rel loss=113.5447, reg loss=0.0005531313363462687, smooth loss=4.5344023968655396e-07
# EPOCH 491, batch size: 1, nsim=[1] loss=145.4256, rel loss=145.4251, reg loss=0.0005531384376809001, smooth loss=8.90452402991444e-08
# EPOCH 491 (time=13.4): loss=393.7962, data_loss=393.7928
# EPOCH 492, batch size: 5, nsim=[5] loss=17.5500, rel loss=17.5495, reg loss=0.000553145247977227, smooth loss=4.2105365522542067e-07
# EPOCH 492, batch size: 5, nsim=[5] loss=20.6030, rel loss=20.6024, reg loss=0.0005531495553441346, smooth loss=4.4602690532777515e-07
# EPOCH 492, batch size: 5, nsim=[5] loss=204.3103, rel loss=204.3097, reg loss=0.0005531543865799904, smooth loss=1.1434841146834816e-06
# EPOCH 492, batch size: 5, nsim=[5] loss=16.3913, rel loss=16.3907, reg loss=0.0005531589849852026, smooth loss=4.968764980946583e-07
# EPOCH 492, batch size: 5, nsim=[5] loss=130.2924, rel loss=130.2919, reg loss=0.0005531638162210584, smooth loss=4.4879476552376103e-07
# EPOCH 492, batch size: 1, nsim=[1] loss=2.4168, rel loss=2.4162, reg loss=0.0005531691131182015, smooth loss=1.0375937437185439e-07
# New minimum achieved
# EPOCH 492 (time=13.4): loss=391.5638, data_loss=391.5604
# EPOCH 493, batch size: 5, nsim=[5] loss=96.6895, rel loss=96.6889, reg loss=0.0005531740607693791, smooth loss=5.089133343100943e-07
# EPOCH 493, batch size: 5, nsim=[5] loss=152.8197, rel loss=152.8192, reg loss=0.0005531826172955334, smooth loss=5.013442967424852e-07
# EPOCH 493, batch size: 5, nsim=[5] loss=20.7528, rel loss=20.7523, reg loss=0.0005531905917450786, smooth loss=4.638189184962139e-07
# EPOCH 493, batch size: 5, nsim=[5] loss=59.7156, rel loss=59.7150, reg loss=0.0005532001960091293, smooth loss=1.0413424196538371e-06
# EPOCH 493, batch size: 5, nsim=[5] loss=57.5098, rel loss=57.5092, reg loss=0.0005532088689506054, smooth loss=4.0743051873382897e-07
# EPOCH 493, batch size: 1, nsim=[1] loss=4.4323, rel loss=4.4318, reg loss=0.0005532164941541851, smooth loss=1.3658621697400318e-07
# EPOCH 493 (time=13.3): loss=391.9197, data_loss=391.9164
# EPOCH 494, batch size: 5, nsim=[5] loss=14.3705, rel loss=14.3699, reg loss=0.0005532233044505119, smooth loss=3.843559854080213e-07
# EPOCH 494, batch size: 5, nsim=[5] loss=116.9539, rel loss=116.9533, reg loss=0.0005532294744625688, smooth loss=4.2242280642260116e-07
# EPOCH 494, batch size: 5, nsim=[5] loss=42.9003, rel loss=42.8998, reg loss=0.0005532377981580794, smooth loss=4.637510825471144e-07
# EPOCH 494, batch size: 5, nsim=[5] loss=18.0488, rel loss=18.0483, reg loss=0.0005532455397769809, smooth loss=5.758579683262383e-07
# EPOCH 494, batch size: 5, nsim=[5] loss=192.0864, rel loss=192.0858, reg loss=0.0005532527575269341, smooth loss=1.135823419019893e-06
# EPOCH 494, batch size: 1, nsim=[1] loss=6.0439, rel loss=6.0434, reg loss=0.0005532593932002783, smooth loss=7.517680486360139e-08
# New minimum achieved
# EPOCH 494 (time=13.5): loss=390.4037, data_loss=390.4004
# EPOCH 495, batch size: 5, nsim=[5] loss=256.6626, rel loss=256.6621, reg loss=0.0005532657378353179, smooth loss=4.139048482552676e-07
# EPOCH 495, batch size: 5, nsim=[5] loss=12.8267, rel loss=12.8261, reg loss=0.000553272373508662, smooth loss=5.873598472525037e-07
# EPOCH 495, batch size: 5, nsim=[5] loss=82.7387, rel loss=82.7382, reg loss=0.0005532781360670924, smooth loss=1.0408380648798712e-06
# EPOCH 495, batch size: 5, nsim=[5] loss=19.6291, rel loss=19.6285, reg loss=0.0005532833165489137, smooth loss=4.2511906931394365e-07
# EPOCH 495, batch size: 5, nsim=[5] loss=15.1922, rel loss=15.1917, reg loss=0.0005532890791073442, smooth loss=5.375620345438591e-07
# EPOCH 495, batch size: 1, nsim=[1] loss=1.2413, rel loss=1.2407, reg loss=0.0005532942013815045, smooth loss=5.2008281087406936e-08
# New minimum achieved
# EPOCH 495 (time=13.6): loss=388.2906, data_loss=388.2873
# EPOCH 496, batch size: 5, nsim=[5] loss=15.2348, rel loss=15.2343, reg loss=0.0005533000221475959, smooth loss=4.485203622873876e-07
# EPOCH 496, batch size: 5, nsim=[5] loss=76.3725, rel loss=76.3719, reg loss=0.0005533059011213481, smooth loss=1.1355833850134208e-06
# EPOCH 496, batch size: 5, nsim=[5] loss=25.3217, rel loss=25.3212, reg loss=0.0005533112562261522, smooth loss=5.066921341189909e-07
# EPOCH 496, batch size: 5, nsim=[5] loss=104.7147, rel loss=104.7141, reg loss=0.0005533175426535308, smooth loss=4.6800985461666123e-07
# EPOCH 496, batch size: 5, nsim=[5] loss=157.5745, rel loss=157.5739, reg loss=0.0005533266230486333, smooth loss=4.294696378923267e-07
# EPOCH 496, batch size: 1, nsim=[1] loss=8.3815, rel loss=8.3810, reg loss=0.000553334946744144, smooth loss=6.726938507755669e-08
# New minimum achieved
# EPOCH 496 (time=13.5): loss=387.5998, data_loss=387.5964
# EPOCH 497, batch size: 5, nsim=[5] loss=26.3922, rel loss=26.3917, reg loss=0.0005533436196856201, smooth loss=4.6365278781858407e-07
# EPOCH 497, batch size: 5, nsim=[5] loss=46.3212, rel loss=46.3206, reg loss=0.0005533501389436424, smooth loss=1.1382365411284962e-06
# EPOCH 497, batch size: 5, nsim=[5] loss=22.0970, rel loss=22.0964, reg loss=0.0005533559597097337, smooth loss=3.8940589295374096e-07
# EPOCH 497, batch size: 5, nsim=[5] loss=47.6461, rel loss=47.6455, reg loss=0.0005533592775464058, smooth loss=5.359723001950581e-07
# EPOCH 497, batch size: 5, nsim=[5] loss=100.7684, rel loss=100.7679, reg loss=0.0005533623043447733, smooth loss=4.374888093967493e-07
# EPOCH 497, batch size: 1, nsim=[1] loss=143.7437, rel loss=143.7432, reg loss=0.000553369231056422, smooth loss=8.885869953710089e-08
# New minimum achieved
# EPOCH 497 (time=13.4): loss=386.9686, data_loss=386.9653
# EPOCH 498, batch size: 5, nsim=[5] loss=137.7012, rel loss=137.7006, reg loss=0.0005533757503144443, smooth loss=1.0953168589717711e-06
# EPOCH 498, batch size: 5, nsim=[5] loss=22.7392, rel loss=22.7387, reg loss=0.000553382036741823, smooth loss=4.3308369338626345e-07
# EPOCH 498, batch size: 5, nsim=[5] loss=158.1070, rel loss=158.1064, reg loss=0.0005533893709070981, smooth loss=3.6207839378116403e-07
# EPOCH 498, batch size: 5, nsim=[5] loss=17.3104, rel loss=17.3099, reg loss=0.0005533961812034249, smooth loss=5.691250371994698e-07
# EPOCH 498, batch size: 5, nsim=[5] loss=22.0691, rel loss=22.0686, reg loss=0.0005534025258384645, smooth loss=5.105720086500004e-07
# EPOCH 498, batch size: 1, nsim=[1] loss=29.4595, rel loss=29.4590, reg loss=0.0005534111987799406, smooth loss=8.406089717731784e-08
# EPOCH 498 (time=13.4): loss=387.3865, data_loss=387.3831
# EPOCH 499, batch size: 5, nsim=[5] loss=104.7992, rel loss=104.7987, reg loss=0.0005534191150218248, smooth loss=3.6816604873702555e-07
# EPOCH 499, batch size: 5, nsim=[5] loss=15.1329, rel loss=15.1324, reg loss=0.0005534305819310248, smooth loss=4.945687436321661e-07
# EPOCH 499, batch size: 5, nsim=[5] loss=188.5664, rel loss=188.5658, reg loss=0.0005534410593099892, smooth loss=1.0198520125174316e-06
# EPOCH 499, batch size: 5, nsim=[5] loss=44.4842, rel loss=44.4837, reg loss=0.0005534505471587181, smooth loss=5.507370874548551e-07
# EPOCH 499, batch size: 5, nsim=[5] loss=31.2848, rel loss=31.2842, reg loss=0.0005534591618925333, smooth loss=5.596021459288697e-07
# EPOCH 499, batch size: 1, nsim=[1] loss=2.3696, rel loss=2.3690, reg loss=0.0005534637020900846, smooth loss=5.8091802548523864e-08
# New minimum achieved
# EPOCH 499 (time=13.6): loss=386.6372, data_loss=386.6339

# %% [markdown]
# ### Phase 1.2 Training

# %%
# 500 epochs
first_larger_index = [jnp.searchsorted(dataset['FLOW_TIMES'][i], 120.0, side='right') for i in range(len(dataset['FLOW_TIMES']))]
FLOW_TIMES = [jnp.array(dataset['FLOW_TIMES'][i][:first_larger_index[i]]) for i in train_set]
SMOKE_FIELD = [jnp.array(dataset['SMOKE_FIELD'][i][:first_larger_index[i]]) for i in train_set]

# %%
with open(f'{FILENAME_PREFIX}_epoch_499.pickle', 'rb') as bunch:
  state_dict = pickle.load(bunch)
params_nn = {}
params_nn['closure'] = state_dict['params']['closure']
params_nn['hidden'] = state_dict['params']['hidden']
params_nn['inflow'] = state_dict['params']['inflow']
params_physics = {}
params_physics['diffusivity_x'] = state_dict['params']['diffusivity_x']
params_physics['diffusivity_y'] = state_dict['params']['diffusivity_y']
state = create_train_state(params_nn=params_nn, params_physics=params_physics,learning_rate=1e-5)

# %%
BATCH_SIZE = 5
ITR_PER_EPOCH = len(FLOW_TIMES)*2

losses = []
min_loss = np.inf
for epoch in range(500,1000):
    epoch_loss = 0.0
    data_loss = 0.0

    start = time.time()
    hidden_curr_set = []
    cell_curr_set = []
    smoke_curr_set = []
    for set_idx in range(len(SMOKE_FIELD)):
        smoke_curr_set.append(jnp.zeros((ny,nx)))
        hidden_curr_set.append(jnp.zeros((4,128)))
        cell_curr_set.append(jnp.zeros((4,128)))

    time_curr_set = [0 for _ in range(len(SMOKE_FIELD))]

    itr = 0
    while itr < ITR_PER_EPOCH:
        itr_batch_size = min(BATCH_SIZE, ITR_PER_EPOCH-itr)
        state, loss, smoke_curr_set, hidden_curr_set, cell_curr_set, time_curr_set, loss1, loss2, loss3, nsim = \
            train_step(state,
                        batch_size=itr_batch_size,
                        smoke_initial_set=smoke_curr_set,
                        hidden_initial_set=hidden_curr_set,
                        cell_initial_set=cell_curr_set,
                        time_initial_set=time_curr_set,
                        dt=dt,
                        thresh=1e-8)

        itr += BATCH_SIZE
        print(f"EPOCH {epoch}, batch size: {itr_batch_size}, nsim={nsim} loss={loss:.4f}, rel loss={loss1:.4f}, reg loss={loss2}, smooth loss={loss3}")
        epoch_loss += loss
        data_loss += loss1
    # saving every 100 epochs
    if epoch%100==99:
        state_dict = flax.serialization.to_state_dict(state)
        with open(f'{FILENAME_PREFIX}_epoch_{epoch}.pickle', 'wb') as handle:
            pickle.dump(state_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

    if epoch_loss < min_loss:
        state_dict = flax.serialization.to_state_dict(state)
        with open(f'{FILENAME_PREFIX}_min.pickle', 'wb') as handle:
            pickle.dump(state_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
        min_loss = epoch_loss
        print("New minimum achieved")

    losses.append(epoch_loss)
    end = time.time()
    print(f"EPOCH {epoch} (time={(end-start):.1f}): loss={epoch_loss:.4f}, data_loss={data_loss:.4f}")

jax.clear_caches()
# Out:
# Streaming output truncated to the last 5000 lines.
# EPOCH 583, batch size: 5, nsim=[5] loss=1.8208, rel loss=1.8202, reg loss=0.0005555852549150586, smooth loss=2.0787561950526116e-07
# EPOCH 583, batch size: 5, nsim=[5] loss=4.1520, rel loss=4.1515, reg loss=0.0005555885145440698, smooth loss=1.9763307048210857e-07
# EPOCH 583, batch size: 2, nsim=[2] loss=0.0006, rel loss=0.0000, reg loss=0.0005555909592658281, smooth loss=2.0677102457485575e-08
# EPOCH 583 (time=24.8): loss=324.9582, data_loss=324.9521
# EPOCH 584, batch size: 5, nsim=[5] loss=68.4553, rel loss=68.4547, reg loss=0.00055559171596542, smooth loss=4.627514397342633e-07
# EPOCH 584, batch size: 5, nsim=[5] loss=38.1055, rel loss=38.1049, reg loss=0.0005555942188948393, smooth loss=9.861096026366622e-07
# EPOCH 584, batch size: 5, nsim=[5] loss=9.6821, rel loss=9.6815, reg loss=0.0005555966054089367, smooth loss=6.666895120939936e-07
# EPOCH 584, batch size: 5, nsim=[5] loss=18.3472, rel loss=18.3466, reg loss=0.0005556002724915743, smooth loss=4.31882306693338e-07
# EPOCH 584, batch size: 5, nsim=[5] loss=127.2627, rel loss=127.2621, reg loss=0.0005556036485359073, smooth loss=4.372135083204368e-07
# EPOCH 584, batch size: 5, nsim=[5] loss=13.6617, rel loss=13.6611, reg loss=0.0005556068499572575, smooth loss=1.2085126470788924e-07
# EPOCH 584, batch size: 5, nsim=[5] loss=3.3497, rel loss=3.3491, reg loss=0.0005556095857173204, smooth loss=1.371665240043249e-07
# EPOCH 584, batch size: 5, nsim=[5] loss=7.3381, rel loss=7.3375, reg loss=0.0005556110409088433, smooth loss=3.054470061208464e-07
# EPOCH 584, batch size: 5, nsim=[5] loss=1.8220, rel loss=1.8214, reg loss=0.0005556120886467397, smooth loss=6.480589708320947e-08
# EPOCH 584, batch size: 5, nsim=[5] loss=33.3955, rel loss=33.3949, reg loss=0.0005556130781769753, smooth loss=1.9339543963967944e-07
# EPOCH 584, batch size: 2, nsim=[2] loss=1.5477, rel loss=1.5472, reg loss=0.0005556140094995499, smooth loss=1.4969550423905033e-08
# EPOCH 584 (time=24.6): loss=322.9675, data_loss=322.9613
# EPOCH 585, batch size: 5, nsim=[5] loss=75.8148, rel loss=75.8143, reg loss=0.0005556149990297854, smooth loss=5.599307841779627e-07
# EPOCH 585, batch size: 5, nsim=[5] loss=11.6310, rel loss=11.6304, reg loss=0.0005556175019592047, smooth loss=3.3913086164174625e-07
# EPOCH 585, batch size: 5, nsim=[5] loss=151.6829, rel loss=151.6823, reg loss=0.0005556197720579803, smooth loss=3.324682856325487e-07
# EPOCH 585, batch size: 5, nsim=[5] loss=4.6281, rel loss=4.6276, reg loss=0.0005556221003644168, smooth loss=2.76223437729639e-07
# EPOCH 585, batch size: 5, nsim=[5] loss=10.2115, rel loss=10.2109, reg loss=0.0005556239048019052, smooth loss=2.9901365095110157e-07
# EPOCH 585, batch size: 5, nsim=[5] loss=4.2000, rel loss=4.1994, reg loss=0.0005556251853704453, smooth loss=1.8633213715771592e-07
# EPOCH 585, batch size: 5, nsim=[5] loss=3.3694, rel loss=3.3688, reg loss=0.0005556262913160026, smooth loss=8.976346426674536e-08
# EPOCH 585, batch size: 5, nsim=[5] loss=43.8478, rel loss=43.8472, reg loss=0.000555627339053899, smooth loss=8.739160293302412e-07
# EPOCH 585, batch size: 5, nsim=[5] loss
-07
# EPOCH 614, batch size: 5, nsim=[5] loss=5.0475, rel loss=5.0469, reg loss=0.0005563769955188036, smooth loss=1.6755390179212187e-07
# EPOCH 614, batch size: 5, nsim=[5] loss=6.6379, rel loss=6.6373, reg loss=0.0005563797312788665, smooth loss=1.6504268068895556e-07
# EPOCH 614, batch size: 5, nsim=[5] loss=12.7403, rel loss=12.7397, reg loss=0.0005563822342082858, smooth loss=1.0192807989053932e-07
# EPOCH 614, batch size: 2, nsim=[2] loss=1.4527, rel loss=1.4522, reg loss=0.0005563849117606878, smooth loss=1.4043851328224854e-08
# EPOCH 614 (time=25.0): loss=306.8832, data_loss=306.8770
# EPOCH 615, batch size: 5, nsim=[5] loss=35.5004, rel loss=35.4998, reg loss=0.0005563875893130898, smooth loss=3.888341170295751e-07
# EPOCH 615, batch size: 5, nsim=[5] loss=101.7241, rel loss=101.7235, reg loss=0.0005563900922425091, smooth loss=9.672026749138492e-07
# EPOCH 615, batch size: 5, nsim=[5] loss=127.4092, rel loss=127.4087, reg loss=0.0005563925951719284, smooth loss=3.905894251229319e-07
# EPOCH 615, batch size: 5, nsim=[5] loss=8.5743, rel loss=8.5737, reg loss=0.0005563950398936868, smooth loss=6.580309272233135e-07
# ...
# EPOCH 989, batch size: 5, nsim=[5] loss=2.1680, rel loss=2.1675, reg loss=0.0005676453001797199, smooth loss=6.122613365754392e-07
# EPOCH 989, batch size: 5, nsim=[5] loss=3.0496, rel loss=3.0490, reg loss=0.0005676456494256854, smooth loss=1.6444622182724252e-07
# EPOCH 989, batch size: 5, nsim=[5] loss=93.6532, rel loss=93.6526, reg loss=0.0005676466389559209, smooth loss=2.0478100804117963e-07
# EPOCH 989, batch size: 5, nsim=[5] loss=20.5349, rel loss=20.5343, reg loss=0.0005676477449014783, smooth loss=2.1725332807694997e-07
# EPOCH 989, batch size: 5, nsim=[5] loss=1.8544, rel loss=1.8538, reg loss=0.0005676517030224204, smooth loss=5.068747304069193e-08
# EPOCH 989, batch size: 2, nsim=[2] loss=1.2020, rel loss=1.2014, reg loss=0.0005676554865203798, smooth loss=2.5118106388858732e-08
# EPOCH 989 (time=24.7): loss=201.4448, data_loss=201.4385
# EPOCH 990, batch size: 5, nsim=[5] loss=13.3703, rel loss=13.3697, reg loss=0.0005676589207723737, smooth loss=4.555162185358019e-07
# EPOCH 990, batch size: 5, nsim=[5] loss=104.6341, rel loss=104.6335, reg loss=0.0005676628788933158, smooth loss=1.1805630109508362e-07
# EPOCH 990, batch size: 5, nsim=[5] loss=51.3485, rel loss=51.3479, reg loss=0.0005676668952219188, smooth loss=1.0023800119835087e-06
# EPOCH 990, batch size: 5, nsim=[5] loss=3.2346, rel loss=3.2341, reg loss=0.0005676706205122173, smooth loss=1.673988271665356e-07
# EPOCH 990, batch size: 5, nsim=[5] loss=5.4851, rel loss=5.4845, reg loss=0.0005676735891029239, smooth loss=7.651077286998123e-07
# EPOCH 990, batch size: 5, nsim=[5] loss=9.3440, rel loss=9.3434, reg loss=0.000567676208447665, smooth loss=2.5349650618773587e-07
# EPOCH 990, batch size: 5, nsim=[5] loss=1.8277, rel loss=1.8272, reg loss=0.0005676783621311188, smooth loss=1.308243290087843e-07
# EPOCH 990, batch size: 5, nsim=[5] loss=4.4082, rel loss=4.4076, reg loss=0.0005676816217601299, smooth loss=4.1676048429426384e-07
# EPOCH 990, batch size: 5, nsim=[5] loss
-07
# EPOCH 997, batch size: 5, nsim=[5] loss=4.3722, rel loss=4.3716, reg loss=0.0005680021131411195, smooth loss=1.4313858712271065e-07
# EPOCH 997, batch size: 5, nsim=[5] loss=4.1866, rel loss=4.1861, reg loss=0.0005680061876773834, smooth loss=1.2721517827131056e-07
# EPOCH 997, batch size: 2, nsim=[2] loss=0.6914, rel loss=0.6908, reg loss=0.0005680103204213083, smooth loss=2.2498716746961256e-08
# EPOCH 997 (time=24.6): loss=197.0726, data_loss=197.0664
# EPOCH 998, batch size: 5, nsim=[5] loss=11.5825, rel loss=11.5819, reg loss=0.0005680142203345895, smooth loss=4.804100735815926e-07
# EPOCH 998, batch size: 5, nsim=[5] loss=95.0844, rel loss=95.0839, reg loss=0.0005680183530785143, smooth loss=3.982912132670975e-07
# EPOCH 998, batch size: 5, nsim=[5] loss=43.5600, rel loss=43.5595, reg loss=0.0005680223694071174, smooth loss=9.868825541386102e-07
# EPOCH 998, batch size: 5, nsim=[5] loss=12.9351, rel loss=12.9346, reg loss=0.0005680259200744331, smooth loss=3.95912825087554e-07
# EPOCH 998, batch size: 5, nsim=[5] loss=19.0270, rel loss=19.0264, reg loss=0.0005680300528183579, smooth loss=2.2955700217183623e-07
# EPOCH 998, batch size: 5, nsim=[5] loss=0.7181, rel loss=0.7175, reg loss=0.000568035407923162, smooth loss=5.605835908051622e-07
# EPOCH 998, batch size: 5, nsim=[5] loss=8.0639, rel loss=8.0634, reg loss=0.0005680422182194889, smooth loss=2.3169063015009732e-07
# EPOCH 998, batch size: 5, nsim=[5] loss=2.6079, rel loss=2.6073, reg loss=0.0005680485046468675, smooth loss=5.7213607759020694e-08
# EPOCH 998, batch size: 5, nsim=[5] loss=2.1296, rel loss=2.1291, reg loss=0.0005680544418282807, smooth loss=1.2443091862333399e-07
# EPOCH 998, batch size: 5, nsim=[5] loss=2.1215, rel loss=2.1209, reg loss=0.0005680593312717974, smooth loss=1.2902586594305021e-07
# EPOCH 998, batch size: 2, nsim=[2] loss=0.2486, rel loss=0.2481, reg loss=0.0005680635222233832, smooth loss=2.943191365978244e-08
# EPOCH 998 (time=24.6): loss=198.0788, data_loss=198.0725
# EPOCH 999, batch size: 5, nsim=[5] loss=114.1689, rel loss=114.1683, reg loss=0.0005680673639290035, smooth loss=4.5357169070949115e-07
# EPOCH 999, batch size: 5, nsim=[5] loss=6.8412, rel loss=6.8406, reg loss=0.0005680709145963192, smooth loss=4.394675136862017e-07
# EPOCH 999, batch size: 5, nsim=[5] loss=7.0513, rel loss=7.0508, reg loss=0.000568073766771704, smooth loss=2.9393004336646937e-07
# EPOCH 999, batch size: 5, nsim=[5] loss=4.5920, rel loss=4.5915, reg loss=0.0005680762697011232, smooth loss=3.1679940516463905e-07
# EPOCH 999, batch size: 5, nsim=[5] loss=4.5485, rel loss=4.5479, reg loss=0.0005680785980075598, smooth loss=1.953429351783519e-07
# EPOCH 999, batch size: 5, nsim=[5] loss=2.5930, rel loss=2.5924, reg loss=0.0005680805770680308, smooth loss=1.9671273423768627e-07
# EPOCH 999, batch size: 5, nsim=[5] loss=20.9973, rel loss=20.9967, reg loss=0.0005680823232978582, smooth loss=2.399043806620516e-07
# EPOCH 999, batch size: 5, nsim=[5] loss=21.5568, rel loss=21.5562, reg loss=0.0005680835456587374, smooth loss=7.066617552231033e-07
# EPOCH 999, batch size: 5, nsim=[5] loss=5.7364, rel loss=5.7358, reg loss=0.0005680847098119557, smooth loss=6.505933753346437e-07
# EPOCH 999, batch size: 5, nsim=[5] loss=1.0704, rel loss=1.0698, reg loss=0.0005680862232111394, smooth loss=6.732130121369343e-08
# EPOCH 999, batch size: 2, nsim=[1, 1] loss=0.4323, rel loss=0.4318, reg loss=0.0005680886097252369, smooth loss=1.9794947195847864e-09
# EPOCH 999 (time=25.6): loss=189.5880, data_loss=189.5817

# %% [markdown]
# ### Phase 1.3 Training

# %%
# 500 epochs
first_larger_index = [jnp.searchsorted(dataset['FLOW_TIMES'][i], 300.0, side='right') for i in range(len(dataset['FLOW_TIMES']))]
FLOW_TIMES = [jnp.array(dataset['FLOW_TIMES'][i][:first_larger_index[i]]) for i in train_set]
SMOKE_FIELD = [jnp.array(dataset['SMOKE_FIELD'][i][:first_larger_index[i]]) for i in train_set]

# %%
with open(f'{FILENAME_PREFIX}_epoch_999.pickle', 'rb') as bunch:
  state_dict = pickle.load(bunch)
params_nn = {}
params_nn['closure'] = state_dict['params']['closure']
params_nn['hidden'] = state_dict['params']['hidden']
params_nn['inflow'] = state_dict['params']['inflow']
params_physics = {}
params_physics['diffusivity_x'] = state_dict['params']['diffusivity_x']
params_physics['diffusivity_y'] = state_dict['params']['diffusivity_y']
state = create_train_state(params_nn=params_nn, params_physics=params_physics,learning_rate=1e-5)
state = flax.serialization.from_state_dict(state, state_dict)

# %%
BATCH_SIZE = 5
ITR_PER_EPOCH = len(FLOW_TIMES)*5

losses = []
min_loss = np.inf
for epoch in range(1000,1500):
    epoch_loss = 0.0
    data_loss = 0.0

    start = time.time()
    hidden_curr_set = []
    cell_curr_set = []
    smoke_curr_set = []
    for set_idx in range(len(SMOKE_FIELD)):
        smoke_curr_set.append(jnp.zeros((ny,nx)))
        hidden_curr_set.append(jnp.zeros((4,128)))
        cell_curr_set.append(jnp.zeros((4,128)))

    time_curr_set = [0 for _ in range(len(SMOKE_FIELD))]

    itr = 0
    while itr < ITR_PER_EPOCH:
        itr_batch_size = min(BATCH_SIZE, ITR_PER_EPOCH-itr)
        state, loss, smoke_curr_set, hidden_curr_set, cell_curr_set, time_curr_set, loss1, loss2, loss3, nsim = \
            train_step(state,
                        batch_size=itr_batch_size,
                        smoke_initial_set=smoke_curr_set,
                        hidden_initial_set=hidden_curr_set,
                        cell_initial_set=cell_curr_set,
                        time_initial_set=time_curr_set,
                        dt=dt,
                        thresh=1e-8)

        itr += BATCH_SIZE
        print(f"EPOCH {epoch}, batch size: {itr_batch_size}, nsim={nsim} loss={loss:.4f}, rel loss={loss1:.4f}, reg loss={loss2}, smooth loss={loss3}")
        epoch_loss += loss
        data_loss += loss1
    # saving every 100 epochs
    if epoch%100==99:
        state_dict = flax.serialization.to_state_dict(state)
        with open(f'{FILENAME_PREFIX}_epoch_{epoch}.pickle', 'wb') as handle:
            pickle.dump(state_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

    if epoch_loss < min_loss:
        state_dict = flax.serialization.to_state_dict(state)
        with open(f'{FILENAME_PREFIX}_min.pickle', 'wb') as handle:
            pickle.dump(state_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
        min_loss = epoch_loss
        print("New minimum achieved")

    losses.append(epoch_loss)
    end = time.time()
    print(f"EPOCH {epoch} (time={(end-start):.1f}): loss={epoch_loss:.4f}, data_loss={data_loss:.4f}")

jax.clear_caches()
# Out:
# EPOCH 1400, batch size: 5, nsim=[5] loss=53.7630, rel loss=53.7624, reg loss=0.0005927559686824679, smooth loss=3.455065955616075e-07
# EPOCH 1400, batch size: 5, nsim=[5] loss=21.5728, rel loss=21.5722, reg loss=0.0005927620804868639, smooth loss=3.540463297801277e-07
# EPOCH 1400, batch size: 5, nsim=[5] loss=8.2249, rel loss=8.2243, reg loss=0.0005927677266299725, smooth loss=2.099305758759413e-07
# EPOCH 1400, batch size: 5, nsim=[5] loss=5.7537, rel loss=5.7531, reg loss=0.0005927730817347765, smooth loss=2.346628732533173e-07
# EPOCH 1400, batch size: 5, nsim=[5] loss=0.8853, rel loss=0.8847, reg loss=0.0005927779129706323, smooth loss=1.7080802175163782e-07
# EPOCH 1400, batch size: 5, nsim=[5] loss=10.3227, rel loss=10.3221, reg loss=0.000592782162129879, smooth loss=1.8596319231615618e-07
# EPOCH 1400, batch size: 5, nsim=[5] loss=1.8240, rel loss=1.8235, reg loss=0.0005927886813879013, smooth loss=1.3897395520226025e-07
# EPOCH 1400, batch size: 5, nsim=[5] loss=0.1749, rel loss=0.1743, reg loss=0.0005927945021539927, smooth loss=1.5432848244917679e-07
# EPOCH 1400, batch size: 5, nsim=[5] loss
-07
# EPOCH 1499, batch size: 5, nsim=[5] loss=0.3119, rel loss=0.3113, reg loss=0.0005972771905362606, smooth loss=1.512232898234544e-07
# EPOCH 1499, batch size: 5, nsim=[5] loss=0.2002, rel loss=0.1996, reg loss=0.000597278296481818, smooth loss=1.8060520113397153e-07
# EPOCH 1499, batch size: 5, nsim=[5] loss=0.2564, rel loss=0.2558, reg loss=0.000597280275542289, smooth loss=1.4794340040060395e-07
# EPOCH 1499, batch size: 5, nsim=[5] loss=4.5934, rel loss=4.5928, reg loss=0.0005972831859253347, smooth loss=1.2204674475820005e-07
# EPOCH 1499, batch size: 5, nsim=[5] loss=0.1123, rel loss=0.1117, reg loss=0.0005972866201773286, smooth loss=1.2066004498625922e-07
# EPOCH 1499, batch size: 5, nsim=[5] loss=0.2546, rel loss=0.2540, reg loss=0.0005972892977297306, smooth loss=1.1522695450386113e-07
# EPOCH 1499, batch size: 5, nsim=[5] loss=0.4611, rel loss=0.4605, reg loss=0.0005972905200906098, smooth loss=2.41061779034326e-07
# EPOCH 1499, batch size: 5, nsim=[5] loss=0.1394, rel loss=0.1388, reg loss=0.0005972915096208453, smooth loss=1.8351053755235804e-07
# EPOCH 1499, batch size: 5, nsim=[5] loss=0.2350, rel loss=0.2344, reg loss=0.0005972924409434199, smooth loss=1.4573097211139142e-07
# EPOCH 1499, batch size: 5, nsim=[5] loss=0.2263, rel loss=0.2257, reg loss=0.0005972934304736555, smooth loss=8.771470485931455e-08
# EPOCH 1499, batch size: 5, nsim=[3, 1, 1] loss=0.0643, rel loss=0.0637, reg loss=0.0005972943617962301, smooth loss=1.708332684099255e-08
# New minimum achieved
# EPOCH 1499 (time=60.6): loss=109.7771, data_loss=109.7616

# %% [markdown]
# ### Phase 1.4 Training

# %%
# 500 epochs
# first_larger_index = [jnp.searchsorted(dataset['FLOW_TIMES'][i], 300.0, side='right') for i in range(len(dataset['FLOW_TIMES']))]
# FLOW_TIMES = [jnp.array(dataset['FLOW_TIMES'][i][:first_larger_index[i]]) for i in train_set]
# SMOKE_FIELD = [jnp.array(dataset['SMOKE_FIELD'][i][:first_larger_index[i]]) for i in train_set]
FLOW_TIMES = [jnp.array(dataset['FLOW_TIMES'][i]) for i in train_set]
SMOKE_FIELD = [jnp.array(dataset['SMOKE_FIELD'][i]) for i in train_set]

# %%
with open(f'{FILENAME_PREFIX}_epoch_1499.pickle', 'rb') as bunch:
  state_dict = pickle.load(bunch)
params_nn = {}
params_nn['closure'] = state_dict['params']['closure']
params_nn['hidden'] = state_dict['params']['hidden']
params_nn['inflow'] = state_dict['params']['inflow']
params_physics = {}
params_physics['diffusivity_x'] = state_dict['params']['diffusivity_x']
params_physics['diffusivity_y'] = state_dict['params']['diffusivity_y']
state = create_train_state(params_nn=params_nn, params_physics=params_physics,learning_rate=1e-5)

# %%
BATCH_SIZE = 5
ITR_PER_EPOCH = len(FLOW_TIMES)*10

losses = []
min_loss = np.inf
for epoch in range(1500,2000):
    epoch_loss = 0.0
    data_loss = 0.0

    start = time.time()
    hidden_curr_set = []
    cell_curr_set = []
    smoke_curr_set = []
    for set_idx in range(len(SMOKE_FIELD)):
        smoke_curr_set.append(jnp.zeros((ny,nx)))
        hidden_curr_set.append(jnp.zeros((4,128)))
        cell_curr_set.append(jnp.zeros((4,128)))

    time_curr_set = [0 for _ in range(len(SMOKE_FIELD))]

    itr = 0
    while itr < ITR_PER_EPOCH:
        itr_batch_size = min(BATCH_SIZE, ITR_PER_EPOCH-itr)
        state, loss, smoke_curr_set, hidden_curr_set, cell_curr_set, time_curr_set, loss1, loss2, loss3, nsim = \
            train_step(state,
                        batch_size=itr_batch_size,
                        smoke_initial_set=smoke_curr_set,
                        hidden_initial_set=hidden_curr_set,
                        cell_initial_set=cell_curr_set,
                        time_initial_set=time_curr_set,
                        dt=dt,
                        thresh=1e-8)

        itr += BATCH_SIZE
        print(f"EPOCH {epoch}, batch size: {itr_batch_size}, nsim={nsim} loss={loss:.4f}, rel loss={loss1:.4f}, reg loss={loss2}, smooth loss={loss3}")
        epoch_loss += loss
        data_loss += loss1
    # saving every 100 epochs
    if epoch%100==99:
        state_dict = flax.serialization.to_state_dict(state)
        with open(f'{FILENAME_PREFIX}_epoch_{epoch}.pickle', 'wb') as handle:
            pickle.dump(state_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

    if epoch_loss < min_loss:
        state_dict = flax.serialization.to_state_dict(state)
        with open(f'{FILENAME_PREFIX}_min.pickle', 'wb') as handle:
            pickle.dump(state_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
        min_loss = epoch_loss
        print("New minimum achieved")

    losses.append(epoch_loss)
    end = time.time()
    print(f"EPOCH {epoch} (time={(end-start):.1f}): loss={epoch_loss:.4f}, data_loss={data_loss:.4f}")

jax.clear_caches()
# Out:
# Streaming output truncated to the last 5000 lines.
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0904, rel loss=0.0897, reg loss=0.0006279305089265108, smooth loss=9.636869742571472e-08
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0843, rel loss=0.0837, reg loss=0.0006279316148720682, smooth loss=8.360326823996617e-08
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0648, rel loss=0.0641, reg loss=0.0006279323133639991, smooth loss=1.519752962138065e-07
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0802, rel loss=0.0795, reg loss=0.0006279335357248783, smooth loss=6.187462858565106e-08
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0744, rel loss=0.0738, reg loss=0.0006279349909164011, smooth loss=6.870385140523734e-08
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0601, rel loss=0.0595, reg loss=0.0006279366207309067, smooth loss=6.841760329743472e-08
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0597, rel loss=0.0591, reg loss=0.0006279386579990387, smooth loss=6.949157929296422e-08
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0473, rel loss=0.0467, reg loss=0.0006279413355514407, smooth loss=3.970820157632495e-08
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0712, rel loss=0.0706, reg loss=0.0006279446533881128, smooth loss=1.0555072416487272e-07
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0853, rel loss=0.0847, reg loss=0.0006279476801864803, smooth loss=1.6188874598116853e-07
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0557, rel loss=0.0550, reg loss=0.0006279510562308133, smooth loss=1.5439692337224815e-07
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0849, rel loss=0.0843, reg loss=0.0006279544322751462, smooth loss=1.7865564502025168e-07
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0780, rel loss=0.0773, reg loss=0.0006279573426581919, smooth loss=2.4317290841865174e-07
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0694, rel loss=0.0688, reg loss=0.0006279600784182549, smooth loss=1.5069124815710855e-07
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0599, rel loss=0.0593, reg loss=0.0006279617082327604, smooth loss=1.5590267988371534e-07
# EPOCH 1905, batch size: 5, nsim=[5] loss=0.0782, rel loss=0.0775, reg loss=0.0006279632798396051, smooth loss=1.3316030914847714e-07
# EPOCH 1905, batch size: 5, nsim=[3, 1, 1] loss=0.0209, rel loss=0.0203, reg loss=0.0006279660738073289, smooth loss=1.487568726810653e-08
# EPOCH 1905 (time=116.2): loss=366.3513, data_loss=366.3186
# EPOCH 1906, batch size: 5, nsim=[5] loss=272.9058, rel loss=272.9052, reg loss=0.000627968751359731, smooth loss=4.448663681433393e-07
# EPOCH 1906, batch size: 5, nsim=[5] loss=19.6576, rel loss=19.6570, reg loss=0.0006279712542891502, smooth loss=2.129590587756499e-07
# EPOCH 1906, batch size: 5, nsim=[5] loss=9.5334, rel loss=9.5327, reg loss=0.0006279743975028396, smooth loss=2.2717424374021407e-07
# EPOCH 1906, batch size: 5, nsim=[5] loss