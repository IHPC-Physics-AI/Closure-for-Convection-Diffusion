# %% [markdown]
# # Recurrent Closure
#
# $$\begin{align}
# c^{t+1} &= c^t + A(c^t) + D(c^t) + R(c^t) + F_1 (c^t, A(c^t), D(c^t), T, h^t)\\
# h^{t+1} &= F_2 (c^{t+1}, h^t)
# \end{align} $$

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

import jax
import optax
import jaxopt
from flax import linen as nn
from jax import numpy as jnp
from flax.training import train_state  # Useful dataclass to keep train state
import flax

from functools import partial
import pickle

from numerical_methods import physics

# %%
import os
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

# %%
dx, dy = 0.5, 0.5
ny, nx = 26, 49
dt=0.2

# %%
TIMES = jnp.load("dataset/times.npy")

TERRAIN = jnp.load("dataset/terrain.npy")

INFLOW_LOCS = jnp.load("dataset/inflow_locations.npy")

rel_loc = [(0, -1), (0, 0), (1, -1), (1, 0)]
INFLOW_COEFFS = jnp.load("dataset/inflow_poly_coeffs.npy")

TRAIN_SET = jnp.load("dataset/train_smoke_grid.npy")

VELOCITY = jnp.load("dataset/velocity_2d.npy")

# %%
with open('params_physics.pickle', 'rb') as handle:
    params_physics = pickle.load(handle)

# %% [markdown]
# ## Neural Networks

# %%
class UNet(nn.Module):
    features: int = 16

    def setup(self):
        self.encoder1 = self._conv_block(self.features)
        self.encoder2 = self._conv_block(self.features * 2)
        self.encoder3 = self._conv_block(self.features * 4)
        self.encoder4 = self._conv_block(self.features * 8)
        
        self.bottleneck = self._conv_block(self.features * 16)
        
        self.upconv4 = self._upconv_block(self.features * 8)
        self.upconv3 = self._upconv_block(self.features * 4)
        self.upconv2 = self._upconv_block(self.features * 2)
        self.upconv1 = self._upconv_block(self.features)

        self.final_conv = nn.Conv(
            features=1, kernel_size=(1, 1), kernel_init=nn.initializers.xavier_uniform(), use_bias=True
        )

    def _conv_block(self, features):
        return nn.Sequential([
            nn.Conv(features, kernel_size=(3, 3), padding='SAME', kernel_init=nn.initializers.xavier_uniform()),
            nn.relu,
            nn.Conv(features, kernel_size=(3, 3), padding='SAME', kernel_init=nn.initializers.xavier_uniform()),
            nn.relu
        ])
    
    def _upconv_block(self, features):
        return nn.Sequential([
            nn.ConvTranspose(features, kernel_size=(2, 2), strides=(2, 2), padding='VALID', kernel_init=nn.initializers.xavier_uniform()),
            nn.relu
        ])

    def __call__(self, x):
        # Encoder
        enc1 = self.encoder1(x)
        enc2 = self.encoder2(nn.max_pool(enc1, window_shape=(2, 3), strides=(2, 3)))
        enc3 = self.encoder3(nn.max_pool(enc2, window_shape=(2, 3), strides=(2, 3)))
        enc4 = self.encoder4(nn.max_pool(enc3, window_shape=(2, 2), strides=(2, 2)))
        
        # Bottleneck
        bottleneck = self.bottleneck(nn.max_pool(enc4, window_shape=(2, 2), strides=(2, 2)))
        # Decoder
        dec4 = self.upconv4(bottleneck)
        dec4 = jax.image.resize(dec4, shape=(1, enc4.shape[1], enc4.shape[2], dec4.shape[-1]), method='bilinear')
        dec4 = jnp.concatenate([dec4, enc4], axis=-1)

        dec3 = self.upconv3(dec4)
        dec3 = jax.image.resize(dec3, shape=(1, enc3.shape[1], enc3.shape[2], dec3.shape[-1]), method='bilinear')
        dec3 = jnp.concatenate([dec3, enc3], axis=-1)

        dec2 = self.upconv2(dec3)
        dec2 = jax.image.resize(dec2, shape=(1, enc2.shape[1], enc2.shape[2], dec2.shape[-1]), method='bilinear')
        dec2 = jnp.concatenate([dec2, enc2], axis=-1)

        dec1 = self.upconv1(dec2)
        dec1 = jax.image.resize(dec1, shape=(1, enc1.shape[1], enc1.shape[2], dec1.shape[-1]), method='bilinear')
        dec1 = jnp.concatenate([dec1, enc1], axis=-1)

        output = self.final_conv(dec1)

        return output

# %%
hidden_net = UNet(features=8)
closure_net = UNet(features=8)

# %% [markdown]
# ## Simulation Function

# %%
@jax.jit
def conv_diff_single_step(params_rcnn,
                          params_physics,
                          smoke_initial: jnp.array,
                          hidden_state: jnp.array,
                          velocity: jnp.array,
                          time_curr: float,
                          inflow_loc: jnp.array,
                          inflow_poly_coeffs: jnp.array,
                          terrain: jnp.array,
                          dt: float):
    
    # set smoke at inflow locations
    y,x = inflow_loc
    for i in range(len(rel_loc)):
        rel_y, rel_x = rel_loc[i]
        c = jnp.polyval(inflow_poly_coeffs[i], time_curr)
        smoke_initial = smoke_initial.at[y+rel_y, x+rel_x].set(c)
    
    advection_term = physics.advect_corr_fvm(field=smoke_initial, 
                                             velocity=velocity,
                                             u_corr=params_physics['u_corr'],
                                             v_corr=params_physics['v_corr'], 
                                             dx=dx, 
                                             dy=dy) * dt
    
    diffusion_term = physics.diffuse_2d_fvm(field=smoke_initial, 
                                            diffusivity_x=params_physics['diffusivity_x'],
                                            diffusivity_y=params_physics['diffusivity_y'],
                                            dx=dx, 
                                            dy=dy) * dt
    
    
    # compute closure term
    input = jnp.stack(((smoke_initial-jnp.mean(smoke_initial))/jnp.std(smoke_initial),
                        (advection_term-jnp.mean(advection_term))/jnp.std(advection_term),
                        (diffusion_term-jnp.mean(diffusion_term))/jnp.std(diffusion_term),
                        TERRAIN,
                        hidden_state), axis=-1)
    input = jnp.expand_dims(input, 0)
    
    output = closure_net.apply({'params': params_rcnn['closure']}, input)
    closure_term = output * 1e-9        # a denormalization value, from previous tests

    smoke_pred = smoke_initial\
                    + advection_term\
                    + diffusion_term\
                    + closure_term.squeeze()
    
    time_next = time_curr + dt
    for i in range(len(rel_loc)):
        rel_y, rel_x = rel_loc[i]
        c = jnp.polyval(inflow_poly_coeffs[i], time_next)
        smoke_pred = smoke_pred.at[y+rel_y, x+rel_x].set(c)
    
    smoke_pred = smoke_pred * terrain
    smoke_pred = jnp.maximum(smoke_pred, 0.0)

    # update hidden state
    mean = jnp.mean(smoke_pred)
    std = jnp.std(smoke_pred)
    input = jnp.stack(((smoke_pred-mean)/std, hidden_state), axis=-1)
    input = jnp.expand_dims(input, 0)
    output = hidden_net.apply({'params': params_rcnn['hidden']}, input)

    hidden_pred = output.squeeze()

    return (smoke_pred, hidden_pred, time_next, params_rcnn, inflow_loc, inflow_poly_coeffs), None


step_for_loop = lambda carry, x: conv_diff_single_step(params_rcnn=carry[3],
                                                       params_physics=params_physics,
                                                        smoke_initial=carry[0],
                                                        hidden_state=carry[1],
                                                        velocity=VELOCITY,
                                                        time_curr=carry[2],
                                                        inflow_loc=carry[4],
                                                        inflow_poly_coeffs=carry[5],
                                                        terrain=TERRAIN,
                                                        dt=dt)

@partial(jax.jit, static_argnames=['nsteps'])
def conv_diff_nsteps(params, 
                     smoke_initial: jnp.array, 
                     hidden_initial: jnp.array, 
                     time_initial, 
                     inflow_loc, 
                     inflow_poly_coeffs, 
                     nsteps):
    (smoke_pred, hidden_pred, _, params, _, _), _ = jax.lax.scan(step_for_loop, (smoke_initial, hidden_initial, time_initial, params, inflow_loc, inflow_poly_coeffs), xs=None, length=nsteps)
    return smoke_pred, hidden_pred

# %% [markdown]
# ## Training

# %%
def create_train_state(learning_rate):
    params = {}
    params['closure'] = closure_net.init(jax.random.PRNGKey(0), jnp.zeros((1, ny, nx, 5)))['params']
    params['hidden'] = hidden_net.init(jax.random.PRNGKey(0), jnp.zeros((1, ny, nx, 2)))['params']
  
    tx = optax.adam(learning_rate)
    return train_state.TrainState.create(apply_fn=conv_diff_nsteps,
                                         params=params,
                                         tx=tx)

# @partial(jax.jit, static_argnames=['nsteps'])
def train_step(state, 
                smoke_initial,
                hidden_initial,
                time_initial,
                inflow_loc,
                inflow_poly_coeffs,
                nsteps, 
                smoke_target):
  
    def loss_fn(params):
        smoke_pred, hidden_pred = state.apply_fn(params, 
                                         smoke_initial=smoke_initial, 
                                         time_initial=time_initial, 
                                         inflow_loc=inflow_loc, 
                                         inflow_poly_coeffs=inflow_poly_coeffs,
                                         nsteps=nsteps)
        
        # L2 loss
        # loss = jnp.sum(optax.l2_loss(smoke_predicted, smoke_target))
        # cosine loss
        # loss = 1 - jnp.sum(smoke_predicted * smoke_target)/jnp.sqrt(jnp.sum(smoke_predicted**2)*jnp.sum(smoke_target**2))
        # relative loss
        denom = smoke_target
        denom = jnp.where(denom<1e-8, 1.0, denom)
        loss = jnp.mean(optax.l2_loss(smoke_pred, smoke_target)/denom**2)
        return loss, (smoke_pred, hidden_pred)

    grad_fn = jax.value_and_grad(loss_fn, has_aux=True)
    (loss, (smoke_pred, hidden_pred)), grads = grad_fn(state.params)

    ## gradient clipping
    clipper = optax.clip_by_global_norm(1.)
    clip_state = clipper.init(grads)
    new_grads, clip_state = clipper.update(grads, clip_state)

    state = state.apply_gradients(grads=new_grads)
    return state, loss, smoke_pred, hidden_pred

# %%
####################
#Using LR scheduler#
####################

max_epoch = 1000
itr_per_epoch = len(TIMES)-1
max_iter = itr_per_epoch * max_epoch

# optimizer: ADAM learning rate scheduler
init_lr = 1e-4
peak_lr = 1e-3
lr_scheduler = optax.warmup_cosine_decay_schedule(init_value=init_lr, 
                                                  peak_value=peak_lr, 
                                                  warmup_steps=int(max_iter*.5),
                                                  decay_steps=max_iter, 
                                                  end_value=1e-5)
####################
#Using LR scheduler#
####################

state = create_train_state(learning_rate=1e-4)

# %%
EPOCHS = 1000

losses = []
min_loss = float('inf')

order = list(range(4))
np.random.seed(0)

for epoch in range(EPOCHS):
    random.shuffle(order)
    
    epoch_loss = 0.0
    for set_idx in order:
        hidden_curr = jnp.zeros((ny, nx))
        smoke_curr = TRAIN_SET[set_idx][0]
        for times_idx in range(len(TIMES)-1):
            nsteps = int((TIMES[times_idx+1]-TIMES[times_idx]+1e-3)/dt)
            state, loss, smoke_curr, hidden_curr = train_step(state, 
                                                smoke_initial=smoke_curr,
                                                hidden_initial=hidden_curr,
                                                time_initial=TIMES[times_idx],
                                                inflow_loc=INFLOW_LOCS[set_idx],
                                                inflow_poly_coeffs=INFLOW_COEFFS[set_idx],
                                                nsteps=nsteps, 
                                                smoke_target=TRAIN_SET[set_idx][times_idx+1])
        
            print(f"EPOCH {epoch}, starting from {set_idx, times_idx} loss={loss}")
            epoch_loss += loss
    
    if epoch_loss < min_loss:
        state_dict = flax.serialization.to_state_dict(state)
        with open('v1_1_phase2_rcnn_min.pickle', 'wb') as handle:
            pickle.dump(state_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
        np.save("v1_1_phase2_rcnn_min", losses)
        min_loss = epoch_loss
        print("New minimum achieved")
        
    losses.append(epoch_loss)
    print(f"EPOCH {epoch}: loss={epoch_loss}")
# Out:
# EPOCH 0, starting from (2, 0) loss=-11.32186878405473
# EPOCH 0, starting from (2, 1) loss=-11.161923180128047
# EPOCH 0, starting from (2, 2) loss=-11.516220463119117
# EPOCH 0, starting from (2, 3) loss=-12.27718618835444
# EPOCH 0, starting from (2, 4) loss=-10.53818932991176
# EPOCH 0, starting from (2, 5) loss=-10.121893576600588
# EPOCH 0, starting from (2, 6) loss=-9.893944107505618
# EPOCH 0, starting from (2, 7) loss=-9.69031223047551
# EPOCH 0, starting from (2, 8) loss=-9.528970373543684
# EPOCH 0, starting from (2, 9) loss=-9.399112913583167
# 2024-07-28 17:33:06.887728: W external/xla/xla/service/hlo_rematerialization.cc:3005] Can't reduce memory use below 2.46GiB (2643239374 bytes) by rematerialization; only reduced to 3.79GiB (4067553838 bytes), down from 3.79GiB (4067967480 bytes) originally
# EPOCH 0, starting from (2, 10) loss=-8.87038191721049
# EPOCH 0, starting from (2, 11) loss=-8.550583215285243
# EPOCH 0, starting from (2, 12) loss=-8.320788084347113
# EPOCH 0, starting from (2, 13) loss=-8.144486094850928
# EPOCH 0, starting from (2, 14) loss=-8.000772638151386
# EPOCH 0, starting from (2, 15) loss=-7.881430339233438
# EPOCH 0, starting from (2, 16) loss=-7.7787704982815775
# EPOCH 0, starting from (2, 17) loss=-7.690126992593431
# EPOCH 0, starting from (2, 18) loss=-7.611505573733784
# EPOCH 0, starting from (2, 19) loss=-7.542030192845465
# EPOCH 0, starting from (2, 20) loss=-7.479177842282074
# EPOCH 0, starting from (2, 21) loss=-7.42277978083916
# EPOCH 0, starting from (2, 22) loss=-7.371052314110673
# EPOCH 0, starting from (0, 0) loss=-11.129229682012825
# EPOCH 0, starting from (0, 1) loss=-11.015823407432858
# EPOCH 0, starting from (0, 2) loss=-11.325766276869981
# EPOCH 0, starting from (0, 3) loss=-11.484819086277207
# EPOCH 0, starting from (0, 4) loss=-10.060646303256274
# EPOCH 0, starting from (0, 5) loss=-9.781480158730378
# EPOCH 0, starting from (0, 6) loss=-9.592336895181601
# EPOCH 0, starting from (0, 7) loss=-9.422379130353963
# EPOCH 0, starting from (0, 8) loss=-9.289548921642703
# EPOCH 0, starting from (0, 9) loss=-9.183959836394326
# EPOCH 0, starting from (0, 10) loss=-8.758864523118548
# EPOCH 0, starting from (0, 11) loss=-8.485259403104882
# EPOCH 0, starting from (0, 12) loss=-8.279838983139143
# EPOCH 0, starting from (0, 13) loss=-8.116219769534064
# EPOCH 0, starting from (0, 14) loss=-7.98119571370834
# EPOCH 0, starting from (0, 15) loss=-7.867043953238122
# EPOCH 0, starting from (0, 16) loss=-7.768533798632667
# EPOCH 0, starting from (0, 17) loss=-7.682917508636969
# EPOCH 0, starting from (0, 18) loss=-7.606293867096547
# EPOCH 0, starting from (0, 19) loss=-7.544071349486769
# EPOCH 0, starting from (0, 20) loss=-7.477059687998978
# EPOCH 0, starting from (0, 21) loss=-7.469620550032721
# EPOCH 0, starting from (0, 22) loss=-7.371536582445971
# EPOCH 0, starting from (1, 0) loss=-11.273362730353911
# EPOCH 0, starting from (1, 1) loss=-11.243453569491122
# EPOCH 0, starting from (1, 2) loss=-11.701005763991347
# EPOCH 0, starting from (1, 3) loss=-12.861367040126986
# EPOCH 0, starting from (1, 4) loss=-9.949972337441096
# EPOCH 0, starting from (1, 5) loss=-9.594812946016065
# EPOCH 0, starting from (1, 6) loss=-9.374947934831004
# EPOCH 0, starting from (1, 7) loss=-9.211567691282415
# EPOCH 0, starting from (1, 8) loss=-9.087992495520078
# EPOCH 0, starting from (1, 9) loss=-8.99114591087462
# EPOCH 0, starting from (1, 10) loss=-8.634421258930914
# EPOCH 0, starting from (1, 11) loss=-8.410891263179
# EPOCH 0, starting from (1, 12) loss=-8.236066900485532
# EPOCH 0, starting from (1, 13) loss=-8.091323869721847
# EPOCH 0, starting from (1, 14) loss=-7.967919837326386
# EPOCH 0, starting from (1, 15) loss=-7.86179736257005
# EPOCH 0, starting from (1, 16) loss=-7.768576358608452
# EPOCH 0, starting from (1, 17) loss=-7.687210556965755
# EPOCH 0, starting from (1, 18) loss=-7.613433905917165
# EPOCH 0, starting from (1, 19) loss=-7.554852995176291
# EPOCH 0, starting from (1, 20) loss=-7.488718733928447
# EPOCH 0, starting from (1, 21) loss=-7.3867207257540715
# EPOCH 0, starting from (1, 22) loss=-7.3869871056386325
# EPOCH 0, starting from (3, 0) loss=-11.253845883796078
# EPOCH 0, starting from (3, 1) loss=-11.288538534094307
# EPOCH 0, starting from (3, 2) loss=-11.220801429678042
# EPOCH 0, starting from (3, 3) loss=-10.847463434585412
# EPOCH 0, starting from (3, 4) loss=-9.3164562362821
# EPOCH 0, starting from (3, 5) loss=-9.000634149372802
# EPOCH 0, starting from (3, 6) loss=-8.834601775815097
# EPOCH 0, starting from (3, 7) loss=-8.720092032714193
# EPOCH 0, starting from (3, 8) loss=-8.63699005493851
# EPOCH 0, starting from (3, 9) loss=-8.572408888525576
# EPOCH 0, starting from (3, 10) loss=-8.33011163701331
# EPOCH 0, starting from (3, 11) loss=-8.177755150821824
# EPOCH 0, starting from (3, 12) loss=-8.059136931958665
# EPOCH 0, starting from (3, 13) loss=-7.9608027516277975
# EPOCH 0, starting from (3, 14) loss=-7.87604733465211
# EPOCH 0, starting from (3, 15) loss=-7.803212935112622
# EPOCH 0, starting from (3, 16) loss=-7.737426535233473
# EPOCH 0, starting from (3, 17) loss=-7.681252762365018
# EPOCH 0, starting from (3, 18) loss=-7.626589228248326
# EPOCH 0, starting from (3, 19) loss=-7.59765879494521
# EPOCH 0, starting from (3, 20) loss=-7.537030845210991
# EPOCH 0, starting from (3, 21) loss=-7.643707290768663
# EPOCH 0, starting from (3, 22) loss=-7.637963280659882
# New minimum achieved
# EPOCH 0: loss=-817.5470292119187
# EPOCH 1, starting from (1, 0) loss=-11.27335795258943
# EPOCH 1, starting from (1, 1) loss=-11.243439866089084
# EPOCH 1, starting from (1, 2) loss=-11.700923696687441
# EPOCH 1, starting from (1, 3) loss=-12.863623409689087
# EPOCH 1, starting from (1, 4) loss=-9.954165226806264
# EPOCH 1, starting from (1, 5) loss=-9.60001708447404
# EPOCH 1, starting from (1, 6) loss=-9.380990488935762
# EPOCH 1, starting from (1, 7) loss=-9.218460861658786
# EPOCH 1, starting from (1, 8) loss=-9.095897466400915
# EPOCH 1, starting from (1, 9) loss=-9.000252939021115
# EPOCH 1, starting from (1, 10) loss=-8.649560439715527
# EPOCH 1, starting from (1, 11) loss=-8.432906118998455
# EPOCH 1, starting from (1, 12) loss=-8.260741988410784
# EPOCH 1, starting from (1, 13) loss=-8.120861872910202
# EPOCH 1, starting from (1, 14) loss=-7.997919867352158
# EPOCH 1, starting from (1, 15) loss=-7.895872723972796
# EPOCH 1, starting from (1, 16) loss=-7.802174631361107
# EPOCH 1, starting from (1, 17) loss=-7.724883384642707
# EPOCH 1, starting from (1, 18) loss=-7.650337094345621
# EPOCH 1, starting from (1, 19) loss=-7.596471989979634
# EPOCH 1, starting from (1, 20) loss=-7.528915089987341
# EPOCH 1, starting from (1, 21) loss=-7.416649061064052
# EPOCH 1, starting from (1, 22) loss=-7.420126016529752
# EPOCH 1, starting from (2, 0) loss=-11.32179597730185
# EPOCH 1, starting from (2, 1) loss=-11.161794207249281
# EPOCH 1, starting from (2, 2) loss=-11.5154311893115
# EPOCH 1, starting from (2, 3) loss=-12.266222283306002
# EPOCH 1, starting from (2, 4) loss=-10.591791548295923
# EPOCH 1, starting from (2, 5) loss=-10.230799680754703
# EPOCH 1, starting from (2, 6) loss=-10.051298902732302
# EPOCH 1, starting from (2, 7) loss=-9.875187308730759
# EPOCH 1, starting from (2, 8) loss=-9.73456087636833
# EPOCH 1, starting from (2, 9) loss=-9.623751480958362
# EPOCH 1, starting from (2, 10) loss=-9.091542172136787
# EPOCH 1, starting from (2, 11) loss=-8.736996190368961
# EPOCH 1, starting from (2, 12) loss=-8.479705168326216
# EPOCH 1, starting from (2, 13) loss=-8.272827944093061
# EPOCH 1, starting from (2, 14) loss=-8.111311345426966
# EPOCH 1, starting from (2, 15) loss=-7.975821962665168
# EPOCH 1, starting from (2, 16) loss=-7.866881033039899
# EPOCH 1, starting from (2, 17) loss=-7.776325299870561
# EPOCH 1, starting from (2, 18) loss=-7.695459037829048
# EPOCH 1, starting from (2, 19) loss=-7.627137430596773
# EPOCH 1, starting from (2, 20) loss=-7.562176699136474
# EPOCH 1, starting from (2, 21) loss=-7.5066823989606855
# EPOCH 1, starting from (2, 22) loss=-7.451854997412094
# EPOCH 1, starting from (0, 0) loss=-11.127156688675035
# EPOCH 1, starting from (0, 1) loss=-11.010226413811475
# EPOCH 1, starting from (0, 2) loss=-11.303093490083858
# EPOCH 1, starting from (0, 3) loss=-11.432999046494261
# EPOCH 1, starting from (0, 4) loss=-10.03889444060424
# EPOCH 1, starting from (0, 5) loss=-9.748724031228404
# EPOCH 1, starting from (0, 6) loss=-9.545326615391813
# EPOCH 1, starting from (0, 7) loss=-9.369448726999622
# EPOCH 1, starting from (0, 8) loss=-9.234617510608572
# EPOCH 1, starting from (0, 9) loss=-9.129674795322359
# EPOCH 1, starting from (0, 10) loss=-8.721270269560575
# EPOCH 1, starting from (0, 11) loss=-8.468730609978527
# EPOCH 1, starting from (0, 12) loss=-8.283509628372839
# EPOCH 1, starting from (0, 13) loss=-8.13268033928645
# EPOCH 1, starting from (0, 14) loss=-8.008696179643428
# EPOCH 1, starting from (0, 15) loss=-7.9014205660632895
# EPOCH 1, starting from (0, 16) loss=-7.806929925391648
# EPOCH 1, starting from (0, 17) loss=-7.7241461949230334
# EPOCH 1, starting from (0, 18) loss=-7.647471501259688
# EPOCH 1, starting from (0, 19) loss=-7.586206124789301
# EPOCH 1, starting from (0, 20) loss=-7.516914093772629
# EPOCH 1, starting from (0, 21) loss=-7.5104478938044545
# EPOCH 1, starting from (0, 22) loss=-7.406706344684053
# EPOCH 1, starting from (3, 0) loss=-11.253752203630743
# EPOCH 1, starting from (3, 1) loss=-11.289031585736433
# EPOCH 1, starting from (3, 2) loss=-11.222996315689977
# EPOCH 1, starting from (3, 3) loss=-10.849653899907372
# EPOCH 1, starting from (3, 4) loss=-9.31729663348791
# EPOCH 1, starting from (3, 5) loss=-9.001068980992812
# EPOCH 1, starting from (3, 6) loss=-8.834651874465282
# EPOCH 1, starting from (3, 7) loss=-8.719788640414112
# EPOCH 1, starting from (3, 8) loss=-8.636402255645903
# EPOCH 1, starting from (3, 9) loss=-8.57160767483216
# EPOCH 1, starting from (3, 10) loss=-8.329303260310326
# EPOCH 1, starting from (3, 11) loss=-8.178511114300962
# EPOCH 1, starting from (3, 12) loss=-8.062589287321002
# EPOCH 1, starting from (3, 13) loss=-7.967209993859983
# EPOCH 1, starting from (3, 14) loss=-7.88520399339517
# EPOCH 1, starting from (3, 15) loss=-7.8149951701802784
# EPOCH 1, starting from (3, 16) loss=-7.750845477734302
# EPOCH 1, starting from (3, 17) loss=-7.696613124470842
# EPOCH 1, starting from (3, 18) loss=-7.642490266892076
# EPOCH 1, starting from (3, 19) loss=-7.6153457995221885
# EPOCH 1, starting from (3, 20) loss=-7.553986850223375
# EPOCH 1, starting from (3, 21) loss=-7.658409319227316
# EPOCH 1, starting from (3, 22) loss=-7.651288053953385
# New minimum achieved
# EPOCH 1: loss=-820.514237613437
# EPOCH 2, starting from (1, 0) loss=-11.272948442602862
# EPOCH 2, starting from (1, 1) loss=-11.242023158872009
# EPOCH 2, starting from (1, 2) loss=-11.692419643649785
# EPOCH 2, starting from (1, 3) loss=-12.702343192797185
# EPOCH 2, starting from (1, 4) loss=-9.963004489047762
# EPOCH 2, starting from (1, 5) loss=-9.608295479176022
# EPOCH 2, starting from (1, 6) loss=-9.388557515272941
# EPOCH 2, starting from (1, 7) loss=-9.225792126256504
# EPOCH 2, starting from (1, 8) loss=-9.103331213545532
# EPOCH 2, starting from (1, 9) loss=-9.008069464378476
# EPOCH 2, starting from (1, 10) loss=-8.664143287577547
# EPOCH 2, starting from (1, 11) loss=-8.453597930879528
# EPOCH 2, starting from (1, 12) loss=-8.284043175260804
# EPOCH 2, starting from (1, 13) loss=-8.146014201602842
# EPOCH 2, starting from (1, 14) loss=-8.021975162488815
# EPOCH 2, starting from (1, 15) loss=-7.919051505111331
# EPOCH 2, starting from (1, 16) loss=-7.8228328613373055
# EPOCH 2, starting from (1, 17) loss=-7.7432115150599605
# EPOCH 2, starting from (1, 18) loss=-7.665754712959449
# EPOCH 2, starting from (1, 19) loss=-7.608727772380396
# EPOCH 2, starting from (1, 20) loss=-7.538158759084226
# EPOCH 2, starting from (1, 21) loss=-7.417196616943718
# EPOCH 2, starting from (1, 22) loss=-7.418637054255707
# EPOCH 2, starting from (3, 0) loss=-11.253832607757529
# EPOCH 2, starting from (3, 1) loss=-11.289318577649084
# EPOCH 2, starting from (3, 2) loss=-11.223500703320415
# EPOCH 2, starting from (3, 3) loss=-10.850025800407895
# EPOCH 2, starting from (3, 4) loss=-9.317477955789562
# EPOCH 2, starting from (3, 5) loss=-9.001305369254382
# EPOCH 2, starting from (3, 6) loss=-8.834926537527139
# EPOCH 2, starting from (3, 7) loss=-8.720073501904398
# EPOCH 2, starting from (3, 8) loss=-8.636677959679005
# EPOCH 2, starting from (3, 9) loss=-8.5718522958466
# EPOCH 2, starting from (3, 10) loss=-8.329077655032702
# EPOCH 2, starting from (3, 11) loss=-8.17791620915597
# EPOCH 2, starting from (3, 12) loss=-8.06187270298454
# EPOCH 2, starting from (3, 13) loss=-7.966492874880604
# EPOCH 2, starting from (3, 14) loss=-7.884615239821408
# EPOCH 2, starting from (3, 15) loss=-7.81457644967135
# EPOCH 2, starting from (3, 16) loss=-7.75058142330242
# EPOCH 2, starting from (3, 17) loss=-7.696554625278081
# EPOCH 2, starting from (3, 18) loss=-7.642522359141532
# EPOCH 2, starting from (3, 19) loss=-7.6155223176817906
# EPOCH 2, starting from (3, 20) loss=-7.554170397759822
# EPOCH 2, starting from (3, 21) loss=-7.65621239970961
# EPOCH 2, starting from (3, 22) loss=-7.64855438580646
# EPOCH 2, starting from (0, 0) loss=-11.129138497756719
# EPOCH 2, starting from (0, 1) loss=-11.015821511974028
# EPOCH 2, starting from (0, 2) loss=-11.32662390888741
# EPOCH 2, starting from (0, 3) loss=-11.488168166254706
# EPOCH 2, starting from (0, 4) loss=-10.071942310125637
# EPOCH 2, starting from (0, 5) loss=-9.80338064608727
# EPOCH 2, starting from (0, 6) loss=-9.619324065461699
# EPOCH 2, starting from (0, 7) loss=-9.451647828310499
# EPOCH 2, starting from (0, 8) loss=-9.321137218655789
# EPOCH 2, starting from (0, 9) loss=-9.218265289617525
# EPOCH 2, starting from (0, 10) loss=-8.807231001739716
# EPOCH 2, starting from (0, 11) loss=-8.541999279721123
# EPOCH 2, starting from (0, 12) loss=-8.341346023278003
# EPOCH 2, starting from (0, 13) loss=-8.180570204421066
# EPOCH 2, starting from (0, 14) loss=-8.046138346434503
# EPOCH 2, starting from (0, 15) loss=-7.933100860111665
# EPOCH 2, starting from (0, 16) loss=-7.8329050822828705
# EPOCH 2, starting from (0, 17) loss=-7.747897836448413
# EPOCH 2, starting from (0, 18) loss=-7.6687091069154905
# EPOCH 2, starting from (0, 19) loss=-7.607606050525513
# EPOCH 2, starting from (0, 20) loss=-7.537195619870474
# EPOCH 2, starting from (0, 21) loss=-7.533355372911391
# EPOCH 2, starting from (0, 22) loss=-7.427777858739961
# EPOCH 2, starting from (2, 0) loss=-11.321479228953311
# EPOCH 2, starting from (2, 1) loss=-11.161030836566495
# EPOCH 2, starting from (2, 2) loss=-11.511826995126846
# EPOCH 2, starting from (2, 3) loss=-12.232513176182144
# EPOCH 2, starting from (2, 4) loss=-10.602575691895971
# EPOCH 2, starting from (2, 5) loss=-10.255633588476632
# EPOCH 2, starting from (2, 6) loss=-10.079315105467856
# EPOCH 2, starting from (2, 7) loss=-9.899094644180167
# EPOCH 2, starting from (2, 8) loss=-9.753507239321968
# EPOCH 2, starting from (2, 9) loss=-9.637861075737373
# EPOCH 2, starting from (2, 10) loss=-9.104920504458573
# EPOCH 2, starting from (2, 11) loss=-8.761575361611468
# EPOCH 2, starting from (2, 12) loss=-8.510874627413209
# EPOCH 2, starting from (2, 13) loss=-8.31583201417924
# EPOCH 2, starting from (2, 14) loss=-8.156242393653855
# EPOCH 2, starting from (2, 15) loss=-8.02579176983763
# EPOCH 2, starting from (2, 16) loss=-7.911991985100846
# EPOCH 2, starting from (2, 17) loss=-7.81946627620232
# EPOCH 2, starting from (2, 18) loss=-7.732345054840498
# EPOCH 2, starting from (2, 19) loss=-7.661733242370323
# EPOCH 2, starting from (2, 20) loss=-7.59241681686639
# EPOCH 2, starting from (2, 21) loss=-7.535798219297146
# EPOCH 2, starting from (2, 22) loss=-7.478016390605864
# New minimum achieved
# EPOCH 2: loss=-822.1209139547806
# EPOCH 3, starting from (3, 0) loss=-11.25001230980047
# EPOCH 3, starting from (3, 1) loss=-11.275089082044696
# EPOCH 3, starting from (3, 2) loss=-11.199643416869266
# EPOCH 3, starting from (3, 3) loss=-10.833759472264877
# EPOCH 3, starting from (3, 4) loss=-9.305164158501746
# EPOCH 3, starting from (3, 5) loss=-8.979232412412331
# EPOCH 3, starting from (3, 6) loss=-8.802794380666931
# EPOCH 3, starting from (3, 7) loss=-8.67815630860362
# EPOCH 3, starting from (3, 8) loss=-8.585115943948919
# EPOCH 3, starting from (3, 9) loss=-8.511078138990912
# EPOCH 3, starting from (3, 10) loss=-8.215814499834385
# EPOCH 3, starting from (3, 11) loss=-8.02838139865801
# EPOCH 3, starting from (3, 12) loss=-7.899215677971534
# EPOCH 3, starting from (3, 13) loss=-7.797788560014712
# EPOCH 3, starting from (3, 14) loss=-7.722490998023547
# EPOCH 3, starting from (3, 15) loss=-7.658704675847207
# EPOCH 3, starting from (3, 16) loss=-7.607081353301091
# EPOCH 3, starting from (3, 17) loss=-7.562276132575353
# EPOCH 3, starting from (3, 18) loss=-7.520292343886709
# EPOCH 3, starting from (3, 19) loss=-7.497035812059916
# EPOCH 3, starting from (3, 20) loss=-7.448568423169266
# EPOCH 3, starting from (3, 21) loss=-7.513469144584943
# EPOCH 3, starting from (3, 22) loss=-7.502747993391414
# EPOCH 3, starting from (0, 0) loss=-11.128946727328936
# EPOCH 3, starting from (0, 1) loss=-11.015399115176125
# EPOCH 3, starting from (0, 2) loss=-11.32522674144203
# EPOCH 3, starting from (0, 3) loss=-11.485483017858334
# EPOCH 3, starting from (0, 4) loss=-10.07318278542708
# EPOCH 3, starting from (0, 5) loss=-9.805873470096287
# EPOCH 3, starting from (0, 6) loss=-9.621635171340774
# EPOCH 3, starting from (0, 7) loss=-9.453494196332976
# EPOCH 3, starting from (0, 8) loss=-9.322585412430362
# EPOCH 3, starting from (0, 9) loss=-9.219379822479658
# EPOCH 3, starting from (0, 10) loss=-8.807736943960583
# EPOCH 3, starting from (0, 11) loss=-8.541797361446427
# EPOCH 3, starting from (0, 12) loss=-8.340049299526871
# EPOCH 3, starting from (0, 13) loss=-8.178512274543856
# EPOCH 3, starting from (0, 14) loss=-8.04331147831572
# EPOCH 3, starting from (0, 15) loss=-7.929699754169532
# EPOCH 3, starting from (0, 16) loss=-7.829214825588904
# EPOCH 3, starting from (0, 17) loss=-7.743727998196377
# EPOCH 3, starting from (0, 18) loss=-7.664534613399604
# EPOCH 3, starting from (0, 19) loss=-7.602966813802348
# EPOCH 3, starting from (0, 20) loss=-7.532753308878535
# EPOCH 3, starting from (0, 21) loss=-7.52854206473021
# EPOCH 3, starting from (0, 22) loss=-7.423537907344775
# EPOCH 3, starting from (2, 0) loss=-11.321694513971998
# EPOCH 3, starting from (2, 1) loss=-11.16160588672451
# EPOCH 3, starting from (2, 2) loss=-11.51472441609198
# EPOCH 3, starting from (2, 3) loss=-12.26053404254293
# EPOCH 3, starting from (2, 4) loss=-10.599436651381966
# EPOCH 3, starting from (2, 5) loss=-10.239542952605586
# EPOCH 3, starting from (2, 6) loss=-10.053734905123711
# EPOCH 3, starting from (2, 7) loss=-9.870314257860791
# EPOCH 3, starting from (2, 8) loss=-9.723684178274999
# EPOCH 3, starting from (2, 9) loss=-9.608095035769216
# EPOCH 3, starting from (2, 10) loss=-9.086679022791074
# EPOCH 3, starting from (2, 11) loss=-8.756325481131688
# EPOCH 3, starting from (2, 12) loss=-8.510270631730206
# EPOCH 3, starting from (2, 13) loss=-8.328373718747226
# EPOCH 3, starting from (2, 14) loss=-8.170448517585111
# EPOCH 3, starting from (2, 15) loss=-8.048054875462547
# EPOCH 3, starting from (2, 16) loss=-7.932122501050732
# EPOCH 3, starting from (2, 17) loss=-7.8416959959024135
# EPOCH 3, starting from (2, 18) loss=-7.752307730998133
# EPOCH 3, starting from (2, 19) loss=-7.68280167161081
# EPOCH 3, starting from (2, 20) loss=-7.612181321993986
# EPOCH 3, starting from (2, 21) loss=-7.556858242140583
# EPOCH 3, starting from (2, 22) loss=-7.498336110505327
# EPOCH 3, starting from (1, 0) loss=-11.2640106968629
# EPOCH 3, starting from (1, 1) loss=-11.210118738369017
# EPOCH 3, starting from (1, 2) loss=-11.522243534216818
# EPOCH 3, starting from (1, 3) loss=-11.725623349022747
# EPOCH 3, starting from (1, 4) loss=-9.886582731054673
# EPOCH 3, starting from (1, 5) loss=-9.490116167225137
# EPOCH 3, starting from (1, 6) loss=-9.244149261683402
# EPOCH 3, starting from (1, 7) loss=-9.066672946927223
# EPOCH 3, starting from (1, 8) loss=-8.934430799075342
# EPOCH 3, starting from (1, 9) loss=-8.832408196814884
# EPOCH 3, starting from (1, 10) loss=-8.496564037319784
# EPOCH 3, starting from (1, 11) loss=-8.283768560868632
# EPOCH 3, starting from (1, 12) loss=-8.142182736031696
# EPOCH 3, starting from (1, 13) loss=-8.018831856382004
# EPOCH 3, starting from (1, 14) loss=-7.9204733328349635
# EPOCH 3, starting from (1, 15) loss=-7.831242440585158
# EPOCH 3, starting from (1, 16) loss=-7.753109663408755
# EPOCH 3, starting from (1, 17) loss=-7.682571403889112
# EPOCH 3, starting from (1, 18) loss=-7.615722661618919
# EPOCH 3, starting from (1, 19) loss=-7.562297652052059
# EPOCH 3, starting from (1, 20) loss=-7.49839220177252
# EPOCH 3, starting from (1, 21) loss=-7.37091200320945
# EPOCH 3, starting from (1, 22) loss=-7.370388431775521
# EPOCH 3: loss=-816.8641398062365
# EPOCH 4, starting from (3, 0) loss=-11.253793301829539
# EPOCH 4, starting from (3, 1) loss=-11.289498967964226
# EPOCH 4, starting from (3, 2) loss=-11.224255976442976
# EPOCH 4, starting from (3, 3) loss=-10.850734879440344
# EPOCH 4, starting from (3, 4) loss=-9.317833782938575
# EPOCH 4, starting from (3, 5) loss=-9.001804473983077
# EPOCH 4, starting from (3, 6) loss=-8.835630450799291
# EPOCH 4, starting from (3, 7) loss=-8.720985624519294
# EPOCH 4, starting from (3, 8) loss=-8.637804833264045
# EPOCH 4, starting from (3, 9) loss=-8.57320221342444
# EPOCH 4, starting from (3, 10) loss=-8.331940992249734
# EPOCH 4, starting from (3, 11) loss=-8.181832288994661
# EPOCH 4, starting from (3, 12) loss=-8.06611666462668
# EPOCH 4, starting from (3, 13) loss=-7.970836190432002
# EPOCH 4, starting from (3, 14) loss=-7.8886470485877975
# EPOCH 4, starting from (3, 15) loss=-7.818400965982879
# EPOCH 4, starting from (3, 16) loss=-7.754074446929064
# EPOCH 4, starting from (3, 17) loss=-7.699845626774983
# EPOCH 4, starting from (3, 18) loss=-7.6456638838052235
# EPOCH 4, starting from (3, 19) loss=-7.618758672569277
# EPOCH 4, starting from (3, 20) loss=-7.557331362863852
# EPOCH 4, starting from (3, 21) loss=-7.663976146429745
# EPOCH 4, starting from (3, 22) loss=-7.65823265444014
# EPOCH 4, starting from (1, 0) loss=-11.273051255376206
# EPOCH 4, starting from (1, 1) loss=-11.242414247396875
# EPOCH 4, starting from (1, 2) loss=-11.694859146718914
# EPOCH 4, starting from (1, 3) loss=-12.748416849559119
# EPOCH 4, starting from (1, 4) loss=-9.965270176256364
# EPOCH 4, starting from (1, 5) loss=-9.610932509873173
# EPOCH 4, starting from (1, 6) loss=-9.391368283196783
# EPOCH 4, starting from (1, 7) loss=-9.228709915963565
# EPOCH 4, starting from (1, 8) loss=-9.106246608283634
# EPOCH 4, starting from (1, 9) loss=-9.010959800303866
# EPOCH 4, starting from (1, 10) loss=-8.665646775215935
# EPOCH 4, starting from (1, 11) loss=-8.453622217358227
# EPOCH 4, starting from (1, 12) loss=-8.283398113562093
# EPOCH 4, starting from (1, 13) loss=-8.14427975798292
# EPOCH 4, starting from (1, 14) loss=-8.020311210745323
# EPOCH 4, starting from (1, 15) loss=-7.916644493273551
# EPOCH 4, starting from (1, 16) loss=-7.82086574281455
# EPOCH 4, starting from (1, 17) loss=-7.740702722229242
# EPOCH 4, starting from (1, 18) loss=-7.66386529326445
# EPOCH 4, starting from (1, 19) loss=-7.606415957994411
# EPOCH 4, starting from (1, 20) loss=-7.536576508312731
# EPOCH 4, starting from (1, 21) loss=-7.416882700618259
# EPOCH 4, starting from (1, 22) loss=-7.419152154906056
# EPOCH 4, starting from (2, 0) loss=-11.32176243272735
# EPOCH 4, starting from (2, 1) loss=-11.161785626234893
# EPOCH 4, starting from (2, 2) loss=-11.515615792458988
# EPOCH 4, starting from (2, 3) loss=-12.269270497565168
# EPOCH 4, starting from (2, 4) loss=-10.596262979676322
# EPOCH 4, starting from (2, 5) loss=-10.229965166539099
# EPOCH 4, starting from (2, 6) loss=-10.038301727654595
# EPOCH 4, starting from (2, 7) loss=-9.851220908298963
# EPOCH 4, starting from (2, 8) loss=-9.70163850899171
# EPOCH 4, starting from (2, 9) loss=-9.582824431429575
# EPOCH 4, starting from (2, 10) loss=-9.057552598136882
# EPOCH 4, starting from (2, 11) loss=-8.728400889334758
# EPOCH 4, starting from (2, 12) loss=-8.483519933725338
# EPOCH 4, starting from (2, 13) loss=-8.3032819054874
# EPOCH 4, starting from (2, 14) loss=-8.147059892245535
# EPOCH 4, starting from (2, 15) loss=-8.025868835587948
# EPOCH 4, starting from (2, 16) loss=-7.912201919634238
# EPOCH 4, starting from (2, 17) loss=-7.822432450420158
# EPOCH 4, starting from (2, 18) loss=-7.735351833784659
# EPOCH 4, starting from (2, 19) loss=-7.665916089816829
# EPOCH 4, starting from (2, 20) loss=-7.596849774709654
# EPOCH 4, starting from (2, 21) loss=-7.541433478856558
# EPOCH 4, starting from (2, 22) loss=-7.4846163394350835
# EPOCH 4, starting from (0, 0) loss=-11.128704661267795
# EPOCH 4, starting from (0, 1) loss=-11.014697674028778
# EPOCH 4, starting from (0, 2) loss=-11.322191962300629
# EPOCH 4, starting from (0, 3) loss=-11.477932413769302
# EPOCH 4, starting from (0, 4) loss=-10.073220496709785
# EPOCH 4, starting from (0, 5) loss=-9.809192892343473
# EPOCH 4, starting from (0, 6) loss=-9.62411983137676
# EPOCH 4, starting from (0, 7) loss=-9.454315675800878
# EPOCH 4, starting from (0, 8) loss=-9.321750138505186
# EPOCH 4, starting from (0, 9) loss=-9.217003724154536
# EPOCH 4, starting from (0, 10) loss=-8.795678810770365
# EPOCH 4, starting from (0, 11) loss=-8.528390522607458
# EPOCH 4, starting from (0, 12) loss=-8.327807014769
# EPOCH 4, starting from (0, 13) loss=-8.166058240092966
# EPOCH 4, starting from (0, 14) loss=-8.032892233228315
# EPOCH 4, starting from (0, 15) loss=-7.919111884966038
# EPOCH 4, starting from (0, 16) loss=-7.8199474859299425
# EPOCH 4, starting from (0, 17) loss=-7.734105488969798
# EPOCH 4, starting from (0, 18) loss=-7.65527950188078
# EPOCH 4, starting from (0, 19) loss=-7.5928853802904355
# EPOCH 4, starting from (0, 20) loss=-7.52260606128817
# EPOCH 4, starting from (0, 21) loss=-7.512853927277124
# EPOCH 4, starting from (0, 22) loss=-7.410317018119424
# EPOCH 4: loss=-821.7559909436965
# EPOCH 5, starting from (2, 0) loss=-11.319797060638814
# EPOCH 5, starting from (2, 1) loss=-11.15668578516787
# EPOCH 5, starting from (2, 2) loss=-11.491145707161586
# EPOCH 5, starting from (2, 3) loss=-12.07270242700893
# EPOCH 5, starting from (2, 4) loss=-10.577339210200943
# EPOCH 5, starting from (2, 5) loss=-10.249833000404406
# EPOCH 5, starting from (2, 6) loss=-10.06838996057216
# EPOCH 5, starting from (2, 7) loss=-9.883889120392558
# EPOCH 5, starting from (2, 8) loss=-9.73567112242616
# EPOCH 5, starting from (2, 9) loss=-9.617488889545193
# EPOCH 5, starting from (2, 10) loss=-9.099846542482343
# EPOCH 5, starting from (2, 11) loss=-8.763513064551605
# EPOCH 5, starting from (2, 12) loss=-8.517782699556397
# EPOCH 5, starting from (2, 13) loss=-8.327691008817308
# EPOCH 5, starting from (2, 14) loss=-8.170007242909277
# EPOCH 5, starting from (2, 15) loss=-8.043142136716467
# EPOCH 5, starting from (2, 16) loss=-7.928533539448159
# EPOCH 5, starting from (2, 17) loss=-7.835628290090226
# EPOCH 5, starting from (2, 18) loss=-7.746726551233176
# EPOCH 5, starting from (2, 19) loss=-7.674098939837266
# EPOCH 5, starting from (2, 20) loss=-7.602964336814951
# EPOCH 5, starting from (2, 21) loss=-7.544273225589216
# EPOCH 5, starting from (2, 22) loss=-7.485465600404946
# EPOCH 5, starting from (0, 0) loss=-11.128811346498601
# EPOCH 5, starting from (0, 1) loss=-11.015060972236826
# EPOCH 5, starting from (0, 2) loss=-11.323975742000421
# EPOCH 5, starting from (0, 3) loss=-11.482721810904918
# EPOCH 5, starting from (0, 4) loss=-10.075467427607474
# EPOCH 5, starting from (0, 5) loss=-9.811925394083318
# EPOCH 5, starting from (0, 6) loss=-9.628540202956842
# EPOCH 5, starting from (0, 7) loss=-9.460175858155331
# EPOCH 5, starting from (0, 8) loss=-9.329043403557428
# EPOCH 5, starting from (0, 9) loss=-9.225742126867859
# EPOCH 5, starting from (0, 10) loss=-8.813595454773356
# EPOCH 5, starting from (0, 11) loss=-8.548836401947703
# EPOCH 5, starting from (0, 12) loss=-8.349169127782554
# EPOCH 5, starting from (0, 13) loss=-8.187928321521666
# EPOCH 5, starting from (0, 14) loss=-8.0539106726099
# EPOCH 5, starting from (0, 15) loss=-7.9398092468572425
# EPOCH 5, starting from (0, 16) loss=-7.839429891053982
# EPOCH 5, starting from (0, 17) loss=-7.753167569996652
# EPOCH 5, starting from (0, 18) loss=-7.673514187048415
# EPOCH 5, starting from (0, 19) loss=-7.611194729204862
# EPOCH 5, starting from (0, 20) loss=-7.54026721322473
# EPOCH 5, starting from (0, 21) loss=-7.533562090088317
# EPOCH 5, starting from (0, 22) loss=-7.428509708126721
# EPOCH 5, starting from (3, 0) loss=-11.252795391552386
# EPOCH 5, starting from (3, 1) loss=-11.286029702031744
# EPOCH 5, starting from (3, 2) loss=-11.218907138898656
# EPOCH 5, starting from (3, 3) loss=-10.847458426335976
# EPOCH 5, starting from (3, 4) loss=-9.316089980556132
# EPOCH 5, starting from (3, 5) loss=-8.998626657567455
# EPOCH 5, starting from (3, 6) loss=-8.830913406744981
# EPOCH 5, starting from (3, 7) loss=-8.714599289431328
# EPOCH 5, starting from (3, 8) loss=-8.629627689217559
# EPOCH 5, starting from (3, 9) loss=-8.5632018712923
# EPOCH 5, starting from (3, 10) loss=-8.310253636371847
# EPOCH 5, starting from (3, 11) loss=-8.151472941641062
# EPOCH 5, starting from (3, 12) loss=-8.032446958187155
# EPOCH 5, starting from (3, 13) loss=-7.935446278925263
# EPOCH 5, starting from (3, 14) loss=-7.854688866207626
# EPOCH 5, starting from (3, 15) loss=-7.785542249672153
# EPOCH 5, starting from (3, 16) loss=-7.723557808906925
# EPOCH 5, starting from (3, 17) loss=-7.671161659051952
# EPOCH 5, starting from (3, 18) loss=-7.618914802702054
# EPOCH 5, starting from (3, 19) loss=-7.592288366805784
# EPOCH 5, starting from (3, 20) loss=-7.532893592288322
# EPOCH 5, starting from (3, 21) loss=-7.616231506936091
# EPOCH 5, starting from (3, 22) loss=-7.605828288411861
# EPOCH 5, starting from (1, 0) loss=-11.271303967303723
# EPOCH 5, starting from (1, 1) loss=-11.236561655948286
# EPOCH 5, starting from (1, 2) loss=-11.6615621495638
# EPOCH 5, starting from (1, 3) loss=-12.3598516732788
# EPOCH 5, starting from (1, 4) loss=-9.969278342989757
# EPOCH 5, starting from (1, 5) loss=-9.610618468356215
# EPOCH 5, starting from (1, 6) loss=-9.387300958226918
# EPOCH 5, starting from (1, 7) loss=-9.221909258812133
# EPOCH 5, starting from (1, 8) loss=-9.097391140344534
# EPOCH 5, starting from (1, 9) loss=-9.000502518946128
# EPOCH 5, starting from (1, 10) loss=-8.654618426255325
# EPOCH 5, starting from (1, 11) loss=-8.445561724007295
# EPOCH 5, starting from (1, 12) loss=-8.27970599525958
# EPOCH 5, starting from (1, 13) loss=-8.142769260904155
# EPOCH 5, starting from (1, 14) loss=-8.021356491575212
# EPOCH 5, starting from (1, 15) loss=-7.918523009069498
# EPOCH 5, starting from (1, 16) loss=-7.823648143650767
# EPOCH 5, starting from (1, 17) loss=-7.743490290360983
# EPOCH 5, starting from (1, 18) loss=-7.6664430494967855
# EPOCH 5, starting from (1, 19) loss=-7.608337662439157
# EPOCH 5, starting from (1, 20) loss=-7.537860774485993
# EPOCH 5, starting from (1, 21) loss=-7.409076636651935
# EPOCH 5, starting from (1, 22) loss=-7.410148175495978
# EPOCH 5: loss=-821.2337706442349
# EPOCH 6, starting from (3, 0) loss=-11.253573203738531
# EPOCH 6, starting from (3, 1) loss=-11.288888174635968
# EPOCH 6, starting from (3, 2) loss=-11.223641573415692
# EPOCH 6, starting from (3, 3) loss=-10.850587760201892
# EPOCH 6, starting from (3, 4) loss=-9.317916744075406
# EPOCH 6, starting from (3, 5) loss=-9.001724797679373
# EPOCH 6, starting from (3, 6) loss=-8.835402747023098
# EPOCH 6, starting from (3, 7) loss=-8.72055269073659
# EPOCH 6, starting from (3, 8) loss=-8.637129599772047
# EPOCH 6, starting from (3, 9) loss=-8.572280258885833
# EPOCH 6, starting from (3, 10) loss=-8.329407322635788
# EPOCH 6, starting from (3, 11) loss=-8.178407192785892
# EPOCH 6, starting from (3, 12) loss=-8.062962846512107
# EPOCH 6, starting from (3, 13) loss=-7.968298443720339
# EPOCH 6, starting from (3, 14) loss=-7.887105050674895
# EPOCH 6, starting from (3, 15) loss=-7.817902515500335
# EPOCH 6, starting from (3, 16) loss=-7.7543346137778375
# EPOCH 6, starting from (3, 17) loss=-7.70115296535253
# EPOCH 6, starting from (3, 18) loss=-7.647331908604906
# EPOCH 6, starting from (3, 19) loss=-7.621303496168242
# EPOCH 6, starting from (3, 20) loss=-7.5598567192273665
# EPOCH 6, starting from (3, 21) loss=-7.660763955801591
# EPOCH 6, starting from (3, 22) loss=-7.654289936456759
# EPOCH 6, starting from (1, 0) loss=-11.272353941491758
# EPOCH 6, starting from (1, 1) loss=-11.240066475400123
# EPOCH 6, starting from (1, 2) loss=-11.68116927463119
# EPOCH 6, starting from (1, 3) loss=-12.550368997295543
# EPOCH 6, starting from (1, 4) loss=-9.97144188010201
# EPOCH 6, starting from (1, 5) loss=-9.61553205953028
# EPOCH 6, starting from (1, 6) loss=-9.394404933045905
# EPOCH 6, starting from (1, 7) loss=-9.230612670960507
# EPOCH 6, starting from (1, 8) loss=-9.107306366562195
# EPOCH 6, starting from (1, 9) loss=-9.011407958683176
# EPOCH 6, starting from (1, 10) loss=-8.666135596851346
# EPOCH 6, starting from (1, 11) loss=-8.45627978868984
# EPOCH 6, starting from (1, 12) loss=-8.288231469648647
# EPOCH 6, starting from (1, 13) loss=-8.150172801775954
# EPOCH 6, starting from (1, 14) loss=-8.027163762455158
# EPOCH 6, starting from (1, 15) loss=-7.923650569111616
# EPOCH 6, starting from (1, 16) loss=-7.827944569017599
# EPOCH 6, starting from (1, 17) loss=-7.747533057491604
# EPOCH 6, starting from (1, 18) loss=-7.67027050694157
# EPOCH 6, starting from (1, 19) loss=-7.612365352322087
# EPOCH 6, starting from (1, 20) loss=-7.541900880044169
# EPOCH 6, starting from (1, 21) loss=-7.41504667892207
# EPOCH 6, starting from (1, 22) loss=-7.417058426393857
# EPOCH 6, starting from (0, 0) loss=-11.128982937972546
# EPOCH 6, starting from (0, 1) loss=-11.015552203442681
# EPOCH 6, starting from (0, 2) loss=-11.326095971729904
# EPOCH 6, starting from (0, 3) loss=-11.487882822288732
# EPOCH 6, starting from (0, 4) loss=-10.076585596079472
# EPOCH 6, starting from (0, 5) loss=-9.8124849033878
# EPOCH 6, starting from (0, 6) loss=-9.62949240034074
# EPOCH 6, starting from (0, 7) loss=-9.461455659484994
# EPOCH 6, starting from (0, 8) loss=-9.330611778590706
# EPOCH 6, starting from (0, 9) loss=-9.227523021287919
# EPOCH 6, starting from (0, 10) loss=-8.815283369127224
# EPOCH 6, starting from (0, 11) loss=-8.549485152899209
# EPOCH 6, starting from (0, 12) loss=-8.348535557273882
# EPOCH 6, starting from (0, 13) loss=-8.186880691407552
# EPOCH 6, starting from (0, 14) loss=-8.052288372851107
# EPOCH 6, starting from (0, 15) loss=-7.938220624184158
# EPOCH 6, starting from (0, 16) loss=-7.83785455306359
# EPOCH 6, starting from (0, 17) loss=-7.751862948350626
# EPOCH 6, starting from (0, 18) loss=-7.6725389163121465
# EPOCH 6, starting from (0, 19) loss=-7.610612076499044
# EPOCH 6, starting from (0, 20) loss=-7.540140198856779
# EPOCH 6, starting from (0, 21) loss=-7.53429245315069
# EPOCH 6, starting from (0, 22) loss=-7.429583742173699
# EPOCH 6, starting from (2, 0) loss=-11.320791943411626
# EPOCH 6, starting from (2, 1) loss=-11.159284006658345
# EPOCH 6, starting from (2, 2) loss=-11.503469515115238
# EPOCH 6, starting from (2, 3) loss=-12.161363902963062
# EPOCH 6, starting from (2, 4) loss=-10.609702277117467
# EPOCH 6, starting from (2, 5) loss=-10.282595093241268
# EPOCH 6, starting from (2, 6) loss=-10.10827759490147
# EPOCH 6, starting from (2, 7) loss=-9.924808882767497
# EPOCH 6, starting from (2, 8) loss=-9.776686857232443
# EPOCH 6, starting from (2, 9) loss=-9.65848075719176
# EPOCH 6, starting from (2, 10) loss=-9.123880060524774
# EPOCH 6, starting from (2, 11) loss=-8.781659341468801
# EPOCH 6, starting from (2, 12) loss=-8.531556776375204
# EPOCH 6, starting from (2, 13) loss=-8.3392802755533
# EPOCH 6, starting from (2, 14) loss=-8.180215282548076
# EPOCH 6, starting from (2, 15) loss=-8.052592604613157
# EPOCH 6, starting from (2, 16) loss=-7.937952785858836
# EPOCH 6, starting from (2, 17) loss=-7.845663617655609
# EPOCH 6, starting from (2, 18) loss=-7.75736835065365
# EPOCH 6, starting from (2, 19) loss=-7.685889770100121
# EPOCH 6, starting from (2, 20) loss=-7.615647448110011
# EPOCH 6, starting from (2, 21) loss=-7.558147786018549
# EPOCH 6, starting from (2, 22) loss=-7.499977858444213
# New minimum achieved
# EPOCH 6: loss=-822.5427712740311
# EPOCH 7, starting from (2, 0) loss=-11.319608215600104
# EPOCH 7, starting from (2, 1) loss=-11.156110167989905
# EPOCH 7, starting from (2, 2) loss=-11.488026709473306
# EPOCH 7, starting from (2, 3) loss=-12.04938327966606
# EPOCH 7, starting from (2, 4) loss=-10.574878509321248
# EPOCH 7, starting from (2, 5) loss=-10.253897376364431
# EPOCH 7, starting from (2, 6) loss=-10.070967553350146
# EPOCH 7, starting from (2, 7) loss=-9.885395658676998
# EPOCH 7, starting from (2, 8) loss=-9.737222113637495
# EPOCH 7, starting from (2, 9) loss=-9.619647134079894
# EPOCH 7, starting from (2, 10) loss=-9.107090808137468
# EPOCH 7, starting from (2, 11) loss=-8.773792470950562
# EPOCH 7, starting from (2, 12) loss=-8.530331649275917
# EPOCH 7, starting from (2, 13) loss=-8.340611174952612
# EPOCH 7, starting from (2, 14) loss=-8.183387320193207
# EPOCH 7, starting from (2, 15) loss=-8.056048901928207
# EPOCH 7, starting from (2, 16) loss=-7.94083122580963
# EPOCH 7, starting from (2, 17) loss=-7.846731419839791
# EPOCH 7, starting from (2, 18) loss=-7.757099151975603
# EPOCH 7, starting from (2, 19) loss=-7.683222381640247
# EPOCH 7, starting from (2, 20) loss=-7.611595135287026
# EPOCH 7, starting from (2, 21) loss=-7.551834377753803
# EPOCH 7, starting from (2, 22) loss=-7.49270492137782
# EPOCH 7, starting from (1, 0) loss=-11.271497442834663
# EPOCH 7, starting from (1, 1) loss=-11.23718344763039
# EPOCH 7, starting from (1, 2) loss=-11.664763582492771
# EPOCH 7, starting from (1, 3) loss=-12.384427222182865
# EPOCH 7, starting from (1, 4) loss=-9.971163242061236
# EPOCH 7, starting from (1, 5) loss=-9.61304967984518
# EPOCH 7, starting from (1, 6) loss=-9.390142841953603
# EPOCH 7, starting from (1, 7) loss=-9.225053525392996
# EPOCH 7, starting from (1, 8) loss=-9.100781490067382
# EPOCH 7, starting from (1, 9) loss=-9.004113745335035
# EPOCH 7, starting from (1, 10) loss=-8.65861530072569
# EPOCH 7, starting from (1, 11) loss=-8.451416462343417
# EPOCH 7, starting from (1, 12) loss=-8.28644862991336
# EPOCH 7, starting from (1, 13) loss=-8.150661412115017
# EPOCH 7, starting from (1, 14) loss=-8.029835536252179
# EPOCH 7, starting from (1, 15) loss=-7.927451170672651
# EPOCH 7, starting from (1, 16) loss=-7.832917449372346
# EPOCH 7, starting from (1, 17) loss=-7.752751288539501
# EPOCH 7, starting from (1, 18) loss=-7.67593799235757
# EPOCH 7, starting from (1, 19) loss=-7.617875612806101
# EPOCH 7, starting from (1, 20) loss=-7.547429752686566
# EPOCH 7, starting from (1, 21) loss=-7.418181520274755
# EPOCH 7, starting from (1, 22) loss=-7.420743487732961
# EPOCH 7, starting from (0, 0) loss=-11.128819210598916
# EPOCH 7, starting from (0, 1) loss=-11.015134001201634
# EPOCH 7, starting from (0, 2) loss=-11.324483339796117
# EPOCH 7, starting from (0, 3) loss=-11.48428620252934
# EPOCH 7, starting from (0, 4) loss=-10.07730110647055
# EPOCH 7, starting from (0, 5) loss=-9.81475507373103
# EPOCH 7, starting from (0, 6) loss=-9.631936024929876
# EPOCH 7, starting from (0, 7) loss=-9.463766768566696
# EPOCH 7, starting from (0, 8) loss=-9.332828965843806
# EPOCH 7, starting from (0, 9) loss=-9.229733525625564
# EPOCH 7, starting from (0, 10) loss=-8.818175658587634
# EPOCH 7, starting from (0, 11) loss=-8.553436412049916
# EPOCH 7, starting from (0, 12) loss=-8.353237417298686
# EPOCH 7, starting from (0, 13) loss=-8.192096700504429
# EPOCH 7, starting from (0, 14) loss=-8.057901015219056
# EPOCH 7, starting from (0, 15) loss=-7.943985791614032
# EPOCH 7, starting from (0, 16) loss=-7.843819160371448
# EPOCH 7, starting from (0, 17) loss=-7.757754844835606
# EPOCH 7, starting from (0, 18) loss=-7.678437779858117
# EPOCH 7, starting from (0, 19) loss=-7.616395464349072
# EPOCH 7, starting from (0, 20) loss=-7.545760134924242
# EPOCH 7, starting from (0, 21) loss=-7.5398466806716185
# EPOCH 7, starting from (0, 22) loss=-7.4347495572851425
# EPOCH 7, starting from (3, 0) loss=-11.252863929747217
# EPOCH 7, starting from (3, 1) loss=-11.28624300619292
# EPOCH 7, starting from (3, 2) loss=-11.21921856161201
# EPOCH 7, starting from (3, 3) loss=-10.847663437105117
# EPOCH 7, starting from (3, 4) loss=-9.316660017852083
# EPOCH 7, starting from (3, 5) loss=-8.999859608500435
# EPOCH 7, starting from (3, 6) loss=-8.832838464180485
# EPOCH 7, starting from (3, 7) loss=-8.717189760112179
# EPOCH 7, starting from (3, 8) loss=-8.632873481256748
# EPOCH 7, starting from (3, 9) loss=-8.567098798382377
# EPOCH 7, starting from (3, 10) loss=-8.318256895072492
# EPOCH 7, starting from (3, 11) loss=-8.162802093371697
# EPOCH 7, starting from (3, 12) loss=-8.045837601692353
# EPOCH 7, starting from (3, 13) loss=-7.950532180953236
# EPOCH 7, starting from (3, 14) loss=-7.870139456076074
# EPOCH 7, starting from (3, 15) loss=-7.801725060792082
# EPOCH 7, starting from (3, 16) loss=-7.739491564562653
# EPOCH 7, starting from (3, 17) loss=-7.68738238087747
# EPOCH 7, starting from (3, 18) loss=-7.634749222959636
# EPOCH 7, starting from (3, 19) loss=-7.60897724281963
# EPOCH 7, starting from (3, 20) loss=-7.548729038344271
# EPOCH 7, starting from (3, 21) loss=-7.6381761151102445
# EPOCH 7, starting from (3, 22) loss=-7.63003946030918
# EPOCH 7: loss=-821.810847707615
# EPOCH 8, starting from (1, 0) loss=-11.271030849496682
# EPOCH 8, starting from (1, 1) loss=-11.235719059399845
# EPOCH 8, starting from (1, 2) loss=-11.657081888893618
# EPOCH 8, starting from (1, 3) loss=-12.326040146526795
# EPOCH 8, starting from (1, 4) loss=-9.972219115822242
# EPOCH 8, starting from (1, 5) loss=-9.614184599325881
# EPOCH 8, starting from (1, 6) loss=-9.391206337881385
# EPOCH 8, starting from (1, 7) loss=-9.226078545343006
# EPOCH 8, starting from (1, 8) loss=-9.101811254814278
# EPOCH 8, starting from (1, 9) loss=-9.005176761283114
# EPOCH 8, starting from (1, 10) loss=-8.65948111308029
# EPOCH 8, starting from (1, 11) loss=-8.45231356785912
# EPOCH 8, starting from (1, 12) loss=-8.286646932623617
# EPOCH 8, starting from (1, 13) loss=-8.15042304875366
# EPOCH 8, starting from (1, 14) loss=-8.02907665995421
# EPOCH 8, starting from (1, 15) loss=-7.926290659199562
# EPOCH 8, starting from (1, 16) loss=-7.831544291390608
# EPOCH 8, starting from (1, 17) loss=-7.751082610882962
# EPOCH 8, starting from (1, 18) loss=-7.6742815884986895
# EPOCH 8, starting from (1, 19) loss=-7.615960801981541
# EPOCH 8, starting from (1, 20) loss=-7.545671687999411
# EPOCH 8, starting from (1, 21) loss=-7.415870211993257
# EPOCH 8, starting from (1, 22) loss=-7.418378938239204
# EPOCH 8, starting from (0, 0) loss=-11.128737248928193
# EPOCH 8, starting from (0, 1) loss=-11.014943984879977
# EPOCH 8, starting from (0, 2) loss=-11.323842697470587
# EPOCH 8, starting from (0, 3) loss=-11.483042657354328
# EPOCH 8, starting from (0, 4) loss=-10.078226302962365
# EPOCH 8, starting from (0, 5) loss=-9.81706726292409
# EPOCH 8, starting from (0, 6) loss=-9.63458931110002
# EPOCH 8, starting from (0, 7) loss=-9.466307316742059
# EPOCH 8, starting from (0, 8) loss=-9.335216498020914
# EPOCH 8, starting from (0, 9) loss=-9.231991070015379
# EPOCH 8, starting from (0, 10) loss=-8.819395646839705
# EPOCH 8, starting from (0, 11) loss=-8.553983545928135
# EPOCH 8, starting from (0, 12) loss=-8.352992084030632
# EPOCH 8, starting from (0, 13) loss=-8.191439695099396
# EPOCH 8, starting from (0, 14) loss=-8.056789707863613
# EPOCH 8, starting from (0, 15) loss=-7.9426335297221335
# EPOCH 8, starting from (0, 16) loss=-7.842251290580018
# EPOCH 8, starting from (0, 17) loss=-7.756058583176384
# EPOCH 8, starting from (0, 18) loss=-7.676654681134817
# EPOCH 8, starting from (0, 19) loss=-7.61450646260497
# EPOCH 8, starting from (0, 20) loss=-7.543869196588983
# EPOCH 8, starting from (0, 21) loss=-7.537131531056335
# EPOCH 8, starting from (0, 22) loss=-7.4326802369020495
# EPOCH 8, starting from (2, 0) loss=-11.320773383754494
# EPOCH 8, starting from (2, 1) loss=-11.159270962944674
# EPOCH 8, starting from (2, 2) loss=-11.503505090248964
# EPOCH 8, starting from (2, 3) loss=-12.162136098968922
# EPOCH 8, starting from (2, 4) loss=-10.619215581979025
# EPOCH 8, starting from (2, 5) loss=-10.297032284941443
# EPOCH 8, starting from (2, 6) loss=-10.124649339855466
# EPOCH 8, starting from (2, 7) loss=-9.940895910541297
# EPOCH 8, starting from (2, 8) loss=-9.793034966703427
# EPOCH 8, starting from (2, 9) loss=-9.675479574081844
# EPOCH 8, starting from (2, 10) loss=-9.138848753756529
# EPOCH 8, starting from (2, 11) loss=-8.795790623138284
# EPOCH 8, starting from (2, 12) loss=-8.54524653620108
# EPOCH 8, starting from (2, 13) loss=-8.352186068169605
# EPOCH 8, starting from (2, 14) loss=-8.192645110623165
# EPOCH 8, starting from (2, 15) loss=-8.064311034688695
# EPOCH 8, starting from (2, 16) loss=-7.949143709023157
# EPOCH 8, starting from (2, 17) loss=-7.856084070967764
# EPOCH 8, starting from (2, 18) loss=-7.767704265791534
# EPOCH 8, starting from (2, 19) loss=-7.695563057239635
# EPOCH 8, starting from (2, 20) loss=-7.625699341548016
# EPOCH 8, starting from (2, 21) loss=-7.567653259502604
# EPOCH 8, starting from (2, 22) loss=-7.509879744517566
# EPOCH 8, starting from (3, 0) loss=-11.250176984923996
# EPOCH 8, starting from (3, 1) loss=-11.27591991056368
# EPOCH 8, starting from (3, 2) loss=-11.201425153509383
# EPOCH 8, starting from (3, 3) loss=-10.835280805081002
# EPOCH 8, starting from (3, 4) loss=-9.310526107804725
# EPOCH 8, starting from (3, 5) loss=-8.99140437589208
# EPOCH 8, starting from (3, 6) loss=-8.821783254720922
# EPOCH 8, starting from (3, 7) loss=-8.703266641398786
# EPOCH 8, starting from (3, 8) loss=-8.615844328929484
# EPOCH 8, starting from (3, 9) loss=-8.546922030263284
# EPOCH 8, starting from (3, 10) loss=-8.278273268177355
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7fcf04035dc0>>
# Traceback (most recent call last):
#   File "/home/tingkai/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# EPOCH 8, starting from (3, 11) loss=-8.10820530004748
# EPOCH 8, starting from (3, 12) loss=-7.985076678494951
# EPOCH 8, starting from (3, 13) loss=-7.886866765629875
# EPOCH 8, starting from (3, 14) loss=-7.808137128475026
# EPOCH 8, starting from (3, 15) loss=-7.742165956425141
# EPOCH 8, starting from (3, 16) loss=-7.684539619138645
# EPOCH 8, starting from (3, 17) loss=-7.636270684163582
