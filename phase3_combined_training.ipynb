# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     281             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     282         )
# --> 283       raise ValueError('mount failed' + extra_reason)
#     284     elif case == 4:
#     285       # Terminate the DriveFS binary before killing bash.
#
# ValueError: mount failed

# %%
import sys
sys.path.append('/content/drive/MyDrive/ARIA')

# %% [markdown]
# # Combined Training

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

import jax
import optax
from flax import linen as nn
from jax import numpy as jnp
from flax.training import train_state  # Useful dataclass to keep train state
import flax

from functools import partial
import pickle

from numerical_methods import physics

# %%
import os
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

# %%
dx, dy = 0.5, 0.5
ny, nx = 26, 49
dt=0.1

# %%
TIMES = jnp.load("/content/drive/MyDrive/ARIA/dataset/times.npy")

TERRAIN = jnp.load("/content/drive/MyDrive/ARIA/dataset/terrain.npy")

INFLOW_LOCS = jnp.load("/content/drive/MyDrive/ARIA/dataset/inflow_locations.npy")

rel_loc = [(0, -1), (0, 0), (1, -1), (1, 0)]
INFLOW_COEFFS = jnp.load("/content/drive/MyDrive/ARIA/dataset/inflow_poly_coeffs.npy")

TRAIN_SET = jnp.load("/content/drive/MyDrive/ARIA/dataset/train_smoke_grid.npy")

VELOCITY = jnp.load("/content/drive/MyDrive/ARIA/dataset/velocity_2d.npy")

# %%
with open('/content/drive/MyDrive/ARIA/ckpt/phase_2/unet/params_physics.pickle', 'rb') as handle:
    params_physics = pickle.load(handle)
with open('/content/drive/MyDrive/ARIA/ckpt/phase_2/unet/params_rcnn.pickle', 'rb') as handle:
    params_rcnn = pickle.load(handle)

# %% [markdown]
# ## Neural Networks

# %%
class UNet(nn.Module):
    features: int = 16

    def setup(self):
        self.encoder1 = self._conv_block(self.features)
        self.encoder2 = self._conv_block(self.features * 2)
        self.encoder3 = self._conv_block(self.features * 4)
        self.encoder4 = self._conv_block(self.features * 8)

        self.bottleneck = self._conv_block(self.features * 16)

        self.upconv4 = self._upconv_block(self.features * 8)
        self.upconv3 = self._upconv_block(self.features * 4)
        self.upconv2 = self._upconv_block(self.features * 2)
        self.upconv1 = self._upconv_block(self.features)

        self.final_conv = nn.Conv(
            features=1, kernel_size=(1, 1), kernel_init=nn.initializers.xavier_uniform(), use_bias=True
        )

    def _conv_block(self, features):
        return nn.Sequential([
            nn.Conv(features, kernel_size=(3, 3), padding='SAME', kernel_init=nn.initializers.xavier_uniform()),
            nn.relu,
            nn.Conv(features, kernel_size=(3, 3), padding='SAME', kernel_init=nn.initializers.xavier_uniform()),
            nn.relu
        ])

    def _upconv_block(self, features):
        return nn.Sequential([
            nn.ConvTranspose(features, kernel_size=(2, 2), strides=(2, 2), padding='VALID', kernel_init=nn.initializers.xavier_uniform()),
            nn.relu
        ])

    def __call__(self, x):
        # Encoder
        enc1 = self.encoder1(x)
        enc2 = self.encoder2(nn.max_pool(enc1, window_shape=(2, 3), strides=(2, 3)))
        enc3 = self.encoder3(nn.max_pool(enc2, window_shape=(2, 3), strides=(2, 3)))
        enc4 = self.encoder4(nn.max_pool(enc3, window_shape=(2, 2), strides=(2, 2)))

        # Bottleneck
        bottleneck = self.bottleneck(nn.max_pool(enc4, window_shape=(2, 2), strides=(2, 2)))
        # Decoder
        dec4 = self.upconv4(bottleneck)
        dec4 = jax.image.resize(dec4, shape=(1, enc4.shape[1], enc4.shape[2], dec4.shape[-1]), method='bilinear')
        dec4 = jnp.concatenate([dec4, enc4], axis=-1)

        dec3 = self.upconv3(dec4)
        dec3 = jax.image.resize(dec3, shape=(1, enc3.shape[1], enc3.shape[2], dec3.shape[-1]), method='bilinear')
        dec3 = jnp.concatenate([dec3, enc3], axis=-1)

        dec2 = self.upconv2(dec3)
        dec2 = jax.image.resize(dec2, shape=(1, enc2.shape[1], enc2.shape[2], dec2.shape[-1]), method='bilinear')
        dec2 = jnp.concatenate([dec2, enc2], axis=-1)

        dec1 = self.upconv1(dec2)
        dec1 = jax.image.resize(dec1, shape=(1, enc1.shape[1], enc1.shape[2], dec1.shape[-1]), method='bilinear')
        dec1 = jnp.concatenate([dec1, enc1], axis=-1)

        output = self.final_conv(dec1)

        return output

# %%
hidden_net = UNet(features=16)
closure_net = UNet(features=8)

# %% [markdown]
# ## Simulation Function

# %%
@jax.jit
def conv_diff_single_step(params,
                          smoke_initial: jnp.array,
                          hidden_state: jnp.array,
                          velocity: jnp.array,
                          time_curr: float,
                          inflow_loc: jnp.array,
                          inflow_poly_coeffs: jnp.array,
                          terrain: jnp.array,
                          dt: float):

    # set smoke at inflow locations
    y,x = inflow_loc
    for i in range(len(rel_loc)):
        rel_y, rel_x = rel_loc[i]
        c = jnp.polyval(inflow_poly_coeffs[i], time_curr)
        smoke_initial = smoke_initial.at[y+rel_y, x+rel_x].set(c)

    advection_term = physics.advect_corr_fvm(field=smoke_initial,
                                             velocity=velocity,
                                             u_corr=params['u_corr'],
                                             v_corr=params['v_corr'],
                                             dx=dx,
                                             dy=dy) * dt

    diffusion_term = physics.diffuse_2d_fvm(field=smoke_initial,
                                            diffusivity_x=params['diffusivity_x'],
                                            diffusivity_y=params['diffusivity_y'],
                                            dx=dx,
                                            dy=dy) * dt


    # compute closure term
    input = jnp.stack(((smoke_initial-jnp.mean(smoke_initial))/jnp.std(smoke_initial),
                        (advection_term-jnp.mean(advection_term))/jnp.std(advection_term),
                        (diffusion_term-jnp.mean(diffusion_term))/jnp.std(diffusion_term),
                        TERRAIN,
                        hidden_state), axis=-1)
    input = jnp.expand_dims(input, 0)

    output = closure_net.apply({'params': params['closure']}, input)
    closure_term = output * 1e-9        # a denormalization value, from previous tests

    smoke_pred = smoke_initial\
                    + advection_term\
                    + diffusion_term\
                    + closure_term.squeeze()

    time_next = time_curr + dt
    for i in range(len(rel_loc)):
        rel_y, rel_x = rel_loc[i]
        c = jnp.polyval(inflow_poly_coeffs[i], time_next)
        smoke_pred = smoke_pred.at[y+rel_y, x+rel_x].set(c)

    smoke_pred = smoke_pred * terrain
    smoke_pred = jnp.maximum(smoke_pred, 0.0)

    # update hidden state
    mean = jnp.mean(smoke_pred)
    std = jnp.std(smoke_pred)
    input = jnp.stack(((smoke_pred-mean)/std, hidden_state), axis=-1)
    input = jnp.expand_dims(input, 0)
    output = hidden_net.apply({'params': params['hidden']}, input)

    hidden_pred = output.squeeze()

    return (smoke_pred, hidden_pred, time_next, params, inflow_loc, inflow_poly_coeffs), None


step_for_loop = lambda carry, x: conv_diff_single_step(params=carry[3],
                                                        smoke_initial=carry[0],
                                                        hidden_state=carry[1],
                                                        velocity=VELOCITY,
                                                        time_curr=carry[2],
                                                        inflow_loc=carry[4],
                                                        inflow_poly_coeffs=carry[5],
                                                        terrain=TERRAIN,
                                                        dt=dt)

@partial(jax.jit, static_argnames=['nsteps'])
def conv_diff_nsteps(params,
                     smoke_initial: jnp.array,
                     hidden_initial: jnp.array,
                     time_initial,
                     inflow_loc,
                     inflow_poly_coeffs,
                     nsteps):
    (smoke_pred, hidden_pred, _, params, _, _), _ = jax.lax.scan(step_for_loop, (smoke_initial, hidden_initial, time_initial, params, inflow_loc, inflow_poly_coeffs), xs=None, length=nsteps)
    return smoke_pred, hidden_pred

# %% [markdown]
# ## Training

# %%
def create_train_state(params_rcnn, params_physics, learning_rate):
    params = {}
    params['closure'] = params_rcnn['closure']
    params['hidden'] = params_rcnn['hidden']
    params['diffusivity_x'] = params_physics['diffusivity_x']
    params['diffusivity_y'] = params_physics['diffusivity_y']
    params['u_corr'] = params_physics['u_corr']
    params['v_corr'] = params_physics['v_corr']


    tx = optax.adam(learning_rate)
    return train_state.TrainState.create(apply_fn=conv_diff_nsteps,
                                         params=params,
                                         tx=tx)

# @partial(jax.jit, static_argnames=['nsteps'])
def train_step(state,
                smoke_initial,
                hidden_initial,
                time_initial,
                inflow_loc,
                inflow_poly_coeffs,
                nsteps,
                smoke_target):

    def loss_fn(params):
        smoke_pred, hidden_pred = state.apply_fn(params,
                                         smoke_initial=smoke_initial,
                                         hidden_initial=hidden_initial,
                                         time_initial=time_initial,
                                         inflow_loc=inflow_loc,
                                         inflow_poly_coeffs=inflow_poly_coeffs,
                                         nsteps=nsteps)

        # L2 loss
        # loss = jnp.sum(optax.l2_loss(smoke_predicted, smoke_target))
        # cosine loss
        # loss = 1 - jnp.sum(smoke_predicted * smoke_target)/jnp.sqrt(jnp.sum(smoke_predicted**2)*jnp.sum(smoke_target**2))
        # relative loss
        # denom = jnp.maximum(smoke_predicted, smoke_target)
        # denom = jnp.where(denom<1e-8, 1.0, denom)
        # loss = jnp.mean(optax.l2_loss(smoke_predicted, smoke_target)/denom**2)
        # relative loss 2
        denom = smoke_target
        denom = jnp.where(denom<1e-8, 1.0, denom)
        loss = jnp.mean(optax.l2_loss(smoke_pred, smoke_target)/denom**2)
        return loss, (smoke_pred, hidden_pred)

    grad_fn = jax.value_and_grad(loss_fn, has_aux=True)
    (loss, (smoke_pred, hidden_pred)), grads = grad_fn(state.params)

    ## gradient clipping
    clipper = optax.clip_by_global_norm(0.5)
    clip_state = clipper.init(grads)
    new_grads, clip_state = clipper.update(grads, clip_state)

    state = state.apply_gradients(grads=new_grads)
    return state, loss, smoke_pred, hidden_pred

# %%
####################
#Using LR scheduler#
####################

max_epoch = 100
itr_per_epoch = len(TIMES)-1
max_iter = itr_per_epoch * max_epoch

# optimizer: ADAM learning rate scheduler
init_lr = 1e-4
peak_lr = 1e-3
lr_scheduler = optax.warmup_cosine_decay_schedule(init_value=init_lr,
                                                  peak_value=peak_lr,
                                                  warmup_steps=int(max_iter*.5),
                                                  decay_steps=max_iter,
                                                  end_value=1e-5)
####################
#Using LR scheduler#
####################

state = create_train_state(params_rcnn=params_rcnn,
                           params_physics=params_physics,
                           learning_rate=1e-4)

# %%
EPOCHS = 100

losses = []
min_loss = float('inf')

order = list(range(4))
np.random.seed(0)

for epoch in range(EPOCHS):
    random.shuffle(order)

    epoch_loss = 0.0
    for set_idx in order:
        hidden_curr = jnp.zeros((ny, nx))
        smoke_curr = TRAIN_SET[set_idx][0]
        for times_idx in range(len(TIMES)-1):
            nsteps = int((TIMES[times_idx+1]-TIMES[times_idx]+1e-3)/dt)
            state, loss, smoke_curr, hidden_curr = train_step(state,
                                                            smoke_initial=smoke_curr,
                                                            hidden_initial=hidden_curr,
                                                            time_initial=TIMES[times_idx],
                                                            inflow_loc=INFLOW_LOCS[set_idx],
                                                            inflow_poly_coeffs=INFLOW_COEFFS[set_idx],
                                                            nsteps=nsteps,
                                                            smoke_target=TRAIN_SET[set_idx][times_idx+1])

            print(f"EPOCH {epoch}, starting from {set_idx, times_idx} loss={loss}")
            epoch_loss += loss

    #v1_1: lr 1e-4 adam, gradient clipping 1., all 23 time steps
    if epoch_loss < min_loss:
        state_dict = flax.serialization.to_state_dict(state)
        with open('/content/drive/MyDrive/ARIA/v1_1_phase3_unet_min.pickle', 'wb') as handle:
            pickle.dump(state_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
        np.save("/content/drive/MyDrive/ARIA/v1_1_phase3_unet_min", losses)
        min_loss = epoch_loss
        print("New minimum achieved")

    losses.append(epoch_loss)
    print(f"EPOCH {epoch}: loss={epoch_loss}")
# Out:
# Streaming output truncated to the last 5000 lines.
# EPOCH 46, starting from (2, 1) loss=0.0015443362285962286
# EPOCH 46, starting from (2, 2) loss=0.0017194597539849246
# EPOCH 46, starting from (2, 3) loss=0.007986229659822205
# EPOCH 46, starting from (2, 4) loss=0.6651948807744463
# EPOCH 46, starting from (2, 5) loss=0.10797150324254322
# EPOCH 46, starting from (2, 6) loss=0.019372209041167692
# EPOCH 46, starting from (2, 7) loss=0.014305823386165982
# EPOCH 46, starting from (2, 8) loss=0.016258692847266998
# EPOCH 46, starting from (2, 9) loss=0.016476425997996213
# EPOCH 46, starting from (2, 10) loss=0.00756306781555201
# EPOCH 46, starting from (2, 11) loss=0.006521091687348004
# EPOCH 46, starting from (2, 12) loss=0.01043118009801319
# EPOCH 46, starting from (2, 13) loss=0.014379570273085097
# EPOCH 46, starting from (2, 14) loss=0.018320753260896012
# EPOCH 46, starting from (2, 15) loss=0.029700134924685605
# EPOCH 46, starting from (2, 16) loss=0.025939401431398456
# EPOCH 46, starting from (2, 17) loss=0.10037983036571463
# EPOCH 46, starting from (2, 18) loss=0.05838412301275099
# EPOCH 46, starting from (2, 19) loss=6.976606673773667
# EPOCH 46, starting from (2, 20) loss=6.068871990451718
# EPOCH 46, starting from (2, 21) loss=9837.194020125577
# EPOCH 46, starting from (2, 22) loss=37467.69228716887
# EPOCH 46, starting from (3, 0) loss=0.007366094237709045
# EPOCH 46, starting from (3, 1) loss=0.003830983635320584
# EPOCH 46, starting from (3, 2) loss=0.0043217412965412295
# EPOCH 46, starting from (3, 3) loss=0.0034690242321915726
# EPOCH 46, starting from (3, 4) loss=0.005509737333558384
# EPOCH 46, starting from (3, 5) loss=0.01060495278106888
# EPOCH 46, starting from (3, 6) loss=0.02223280638714084
# EPOCH 46, starting from (3, 7) loss=0.027109142876121622
# EPOCH 46, starting from (3, 8) loss=0.033692731228635746
# EPOCH 46, starting from (3, 9) loss=0.04201509036563408
# EPOCH 46, starting from (3, 10) loss=0.034436942301181564
# EPOCH 46, starting from (3, 11) loss=0.007303631870266739
# EPOCH 46, starting from (3, 12) loss=0.005444946373878198
# EPOCH 46, starting from (3, 13) loss=0.005468880988348847
# EPOCH 46, starting from (3, 14) loss=0.006480057982872446
# EPOCH 46, starting from (3, 15) loss=0.00786056257848607
# EPOCH 46, starting from (3, 16) loss=0.008115431339913168
# EPOCH 46, starting from (3, 17) loss=0.018571007660610633
# EPOCH 46, starting from (3, 18) loss=0.013594921256965592
# EPOCH 46, starting from (3, 19) loss=1.2944261641756054
# EPOCH 46, starting from (3, 20) loss=4.750238383389699
# EPOCH 46, starting from (3, 21) loss=1861.0960902294528
# EPOCH 46, starting from (3, 22) loss=86475.13746289333
# EPOCH 46, starting from (1, 0) loss=0.0008672642101058283
# EPOCH 46, starting from (1, 1) loss=0.0009068627019787465
# EPOCH 46, starting from (1, 2) loss=1.1560530399345013
# EPOCH 46, starting from (1, 3) loss=0.5095157850850666
# EPOCH 46, starting from (1, 4) loss=0.10305402120828212
# EPOCH 46, starting from (1, 5) loss=0.039105497075538447
# EPOCH 46, starting from (1, 6) loss=0.03251874252761822
# EPOCH 46, starting from (1, 7) loss=0.03088442555708301
# EPOCH 46, starting from (1, 8) loss=0.029728667895753978
# EPOCH 46, starting from (1, 9) loss=0.030355780212668795
# EPOCH 46, starting from (1, 10) loss=0.013216905790661797
# EPOCH 46, starting from (1, 11) loss=0.014899581477928855
# EPOCH 46, starting from (1, 12) loss=0.0075056632974640535
# EPOCH 46, starting from (1, 13) loss=0.008292695376102848
# EPOCH 46, starting from (1, 14) loss=0.007410754637453421
# EPOCH 46, starting from (1, 15) loss=0.006141893854077791
# EPOCH 46, starting from (1, 16) loss=0.00974778605225848
# EPOCH 46, starting from (1, 17) loss=0.050090157036691
# EPOCH 46, starting from (1, 18) loss=0.006286330079611195
# EPOCH 46, starting from (1, 19) loss=11.196771851826105
# EPOCH 46, starting from (1, 20) loss=3.4455841101982667
# EPOCH 46, starting from (1, 21) loss=23114.54450014559
# EPOCH 46, starting from (1, 22) loss=50984.27687380099
# New minimum achieved
# EPOCH 46: loss=256467.46387019192
# EPOCH 47, starting from (2, 0) loss=0.0006905183703153312
# EPOCH 47, starting from (2, 1) loss=0.002004798784944606
# EPOCH 47, starting from (2, 2) loss=0.0018107397359110042
# EPOCH 47, starting from (2, 3) loss=0.010147709204159944
# EPOCH 47, starting from (2, 4) loss=0.7807503951718309
# EPOCH 47, starting from (2, 5) loss=0.12220591218010673
# EPOCH 47, starting from (2, 6) loss=0.014020001177974067
# EPOCH 47, starting from (2, 7) loss=0.01106802452304985
# EPOCH 47, starting from (2, 8) loss=0.010028653183800708
# EPOCH 47, starting from (2, 9) loss=0.009422865146868086
# EPOCH 47, starting from (2, 10) loss=0.012054765559403628
# EPOCH 47, starting from (2, 11) loss=0.007562609497377824
# EPOCH 47, starting from (2, 12) loss=0.013374378215151899
# EPOCH 47, starting from (2, 13) loss=0.012495253509739833
# EPOCH 47, starting from (2, 14) loss=0.016203216072550954
# EPOCH 47, starting from (2, 15) loss=0.01962900240890809
# EPOCH 47, starting from (2, 16) loss=0.018491584149256324
# EPOCH 47, starting from (2, 17) loss=0.05211383023168625
# EPOCH 47, starting from (2, 18) loss=0.05715614655104448
# EPOCH 47, starting from (2, 19) loss=3.5850719849962975
# EPOCH 47, starting from (2, 20) loss=15.730559253938685
# EPOCH 47, starting from (2, 21) loss=5559.8630193243835
# EPOCH 47, starting from (2, 22) loss=183047.759275602
# EPOCH 47, starting from (3, 0) loss=0.012363222723097797
# EPOCH 47, starting from (3, 1) loss=0.003937706448535801
# EPOCH 47, starting from (3, 2) loss=0.004437459135043628
# EPOCH 47, starting from (3, 3) loss=0.003566686112838106
# EPOCH 47, starting from (3, 4) loss=0.005151743709426587
# EPOCH 47, starting from (3, 5) loss=0.010029774524870612
# EPOCH 47, starting from (3, 6) loss=0.028873861299368506
# EPOCH 47, starting from (3, 7) loss=0.030863948384064345
# EPOCH 47, starting from (3, 8) loss=0.03224614099227177
# EPOCH 47, starting from (3, 9) loss=0.027062264530741446
# EPOCH 47, starting from (3, 10) loss=0.022715427804991733
# EPOCH 47, starting from (3, 11) loss=0.009222269115862583
# EPOCH 47, starting from (3, 12) loss=0.006495887976181397
# EPOCH 47, starting from (3, 13) loss=0.005106243221672482
# EPOCH 47, starting from (3, 14) loss=0.005097554364751041
# EPOCH 47, starting from (3, 15) loss=0.005535977573709375
# EPOCH 47, starting from (3, 16) loss=0.00737163936230791
# EPOCH 47, starting from (3, 17) loss=0.011092471554317968
# EPOCH 47, starting from (3, 18) loss=0.02155491355111583
# EPOCH 47, starting from (3, 19) loss=0.3186083607713666
# EPOCH 47, starting from (3, 20) loss=4.3729657663747465
# EPOCH 47, starting from (3, 21) loss=784.5119496783046
# EPOCH 47, starting from (3, 22) loss=70761.11016621803
# EPOCH 47, starting from (1, 0) loss=0.0005972902869944855
# EPOCH 47, starting from (1, 1) loss=0.0005980918724452404
# EPOCH 47, starting from (1, 2) loss=1.0490267138147586
# EPOCH 47, starting from (1, 3) loss=0.46111699790113464
# EPOCH 47, starting from (1, 4) loss=0.05832706359898957
# EPOCH 47, starting from (1, 5) loss=0.06810482469219777
# EPOCH 47, starting from (1, 6) loss=0.08091953780367378
# EPOCH 47, starting from (1, 7) loss=0.06516117507746622
# EPOCH 47, starting from (1, 8) loss=0.054031181788890416
# EPOCH 47, starting from (1, 9) loss=0.048350683376806584
# EPOCH 47, starting from (1, 10) loss=0.015834773996619693
# EPOCH 47, starting from (1, 11) loss=0.014033840374853546
# EPOCH 47, starting from (1, 12) loss=0.0064380190912949045
# EPOCH 47, starting from (1, 13) loss=0.004520329797812266
# EPOCH 47, starting from (1, 14) loss=0.00531374988187294
# EPOCH 47, starting from (1, 15) loss=0.00516248100109768
# EPOCH 47, starting from (1, 16) loss=0.010007230699912028
# EPOCH 47, starting from (1, 17) loss=0.1164965526707084
# EPOCH 47, starting from (1, 18) loss=0.01603722791607507
# EPOCH 47, starting from (1, 19) loss=17.135548440327522
# EPOCH 47, starting from (1, 20) loss=2.9795359178245935
# EPOCH 47, starting from (1, 21) loss=28030.99655879254
# EPOCH 47, starting from (1, 22) loss=68148.07567571287
# EPOCH 47, starting from (0, 0) loss=0.0005369233807358177
# EPOCH 47, starting from (0, 1) loss=0.055777021841415156
# EPOCH 47, starting from (0, 2) loss=0.020346953548155227
# EPOCH 47, starting from (0, 3) loss=0.008682799830302044
# EPOCH 47, starting from (0, 4) loss=0.8735002928459762
# EPOCH 47, starting from (0, 5) loss=0.20882677660008298
# EPOCH 47, starting from (0, 6) loss=0.024832301058834157
# EPOCH 47, starting from (0, 7) loss=0.015533798009116506
# EPOCH 47, starting from (0, 8) loss=0.013080350195189983
# EPOCH 47, starting from (0, 9) loss=0.012241814178123681
# EPOCH 47, starting from (0, 10) loss=0.021876959377097542
# EPOCH 47, starting from (0, 11) loss=0.010961498358265872
# EPOCH 47, starting from (0, 12) loss=0.01834459972933963
# EPOCH 47, starting from (0, 13) loss=0.015081709639534235
# EPOCH 47, starting from (0, 14) loss=0.020007382991888718
# EPOCH 47, starting from (0, 15) loss=0.017250340651701654
# EPOCH 47, starting from (0, 16) loss=0.020148242819567758
# EPOCH 47, starting from (0, 17) loss=0.03940501152404948
# EPOCH 47, starting from (0, 18) loss=0.0783263631262039
# EPOCH 47, starting from (0, 19) loss=3.4003323247806168
# EPOCH 47, starting from (0, 20) loss=24.067716305416123
# EPOCH 47, starting from (0, 21) loss=3790.74137847064
# EPOCH 47, starting from (0, 22) loss=271810.6552888785
# EPOCH 47: loss=632010.2824455332
# EPOCH 48, starting from (0, 0) loss=0.0004653928443327508
# EPOCH 48, starting from (0, 1) loss=0.0017456810503889033
# EPOCH 48, starting from (0, 2) loss=0.003198082752897972
# EPOCH 48, starting from (0, 3) loss=0.0021720293938420356
# EPOCH 48, starting from (0, 4) loss=0.3496647412759793
# EPOCH 48, starting from (0, 5) loss=0.06996939925722574
# EPOCH 48, starting from (0, 6) loss=0.032745339481164426
# EPOCH 48, starting from (0, 7) loss=0.04144349330592039
# EPOCH 48, starting from (0, 8) loss=0.047430492668314304
# EPOCH 48, starting from (0, 9) loss=0.0522177115770524
# EPOCH 48, starting from (0, 10) loss=0.0308980996466533
# EPOCH 48, starting from (0, 11) loss=0.03146834084316757
# EPOCH 48, starting from (0, 12) loss=0.018315925694234316
# EPOCH 48, starting from (0, 13) loss=0.016683923207072026
# EPOCH 48, starting from (0, 14) loss=0.013372329895876809
# EPOCH 48, starting from (0, 15) loss=0.012052720111363885
# EPOCH 48, starting from (0, 16) loss=0.012933944052453577
# EPOCH 48, starting from (0, 17) loss=0.04569097144781138
# EPOCH 48, starting from (0, 18) loss=0.01180084494984292
# EPOCH 48, starting from (0, 19) loss=6.096271986638444
# EPOCH 48, starting from (0, 20) loss=2.710324796179926
# EPOCH 48, starting from (0, 21) loss=9042.319688760534
# EPOCH 48, starting from (0, 22) loss=33835.09469980361
# EPOCH 48, starting from (1, 0) loss=0.000993914754496686
# EPOCH 48, starting from (1, 1) loss=0.0010534056902660681
# EPOCH 48, starting from (1, 2) loss=0.9954933556461228
# EPOCH 48, starting from (1, 3) loss=0.44191379583829127
# EPOCH 48, starting from (1, 4) loss=0.26802512578122645
# EPOCH 48, starting from (1, 5) loss=0.13881371433367726
# EPOCH 48, starting from (1, 6) loss=0.050708899747264266
# EPOCH 48, starting from (1, 7) loss=0.03668552127605321
# EPOCH 48, starting from (1, 8) loss=0.029239244342425367
# EPOCH 48, starting from (1, 9) loss=0.02385819756685796
# EPOCH 48, starting from (1, 10) loss=0.022499461447266864
# EPOCH 48, starting from (1, 11) loss=0.010764880478976412
# EPOCH 48, starting from (1, 12) loss=0.008723520011801917
# EPOCH 48, starting from (1, 13) loss=0.008479957087962396
# EPOCH 48, starting from (1, 14) loss=0.00808830720043616
# EPOCH 48, starting from (1, 15) loss=0.00897778344849118
# EPOCH 48, starting from (1, 16) loss=0.008701102264037214
# EPOCH 48, starting from (1, 17) loss=0.016191480889600596
# EPOCH 48, starting from (1, 18) loss=0.033126657436151584
# EPOCH 48, starting from (1, 19) loss=3.7471462114600165
# EPOCH 48, starting from (1, 20) loss=25.133619069963103
# EPOCH 48, starting from (1, 21) loss=8351.815432751051
# EPOCH 48, starting from (1, 22) loss=448732.5552645693
# EPOCH 48, starting from (2, 0) loss=0.0009488287626506758
# EPOCH 48, starting from (2, 1) loss=0.0009408705271742419
# EPOCH 48, starting from (2, 2) loss=0.0014970123840024573
# EPOCH 48, starting from (2, 3) loss=0.003862723347928858
# EPOCH 48, starting from (2, 4) loss=0.21043336643612004
# EPOCH 48, starting from (2, 5) loss=0.05407442473458328
# EPOCH 48, starting from (2, 6) loss=0.07370158648688384
# EPOCH 48, starting from (2, 7) loss=0.07843095004587848
# EPOCH 48, starting from (2, 8) loss=0.07823479130095083
# EPOCH 48, starting from (2, 9) loss=0.07702107301687852
# EPOCH 48, starting from (2, 10) loss=0.036148370842799614
# EPOCH 48, starting from (2, 11) loss=0.035164125029517206
# EPOCH 48, starting from (2, 12) loss=0.020410546924578474
# EPOCH 48, starting from (2, 13) loss=0.019663357303984805
# EPOCH 48, starting from (2, 14) loss=0.013948958959475823
# EPOCH 48, starting from (2, 15) loss=0.017223756264779396
# EPOCH 48, starting from (2, 16) loss=0.01245983639296424
# EPOCH 48, starting from (2, 17) loss=0.10541379141601454
# EPOCH 48, starting from (2, 18) loss=0.022802764078365366
# EPOCH 48, starting from (2, 19) loss=11.420435806282343
# EPOCH 48, starting from (2, 20) loss=2.894390692026521
# EPOCH 48, starting from (2, 21) loss=17774.943345380787
# EPOCH 48, starting from (2, 22) loss=19433.52836134632
# EPOCH 48, starting from (3, 0) loss=0.03348325847786524
# EPOCH 48, starting from (3, 1) loss=0.012394279027803328
# EPOCH 48, starting from (3, 2) loss=0.00496422777189282
# EPOCH 48, starting from (3, 3) loss=0.0032604441268349067
# EPOCH 48, starting from (3, 4) loss=0.005636649257864267
# EPOCH 48, starting from (3, 5) loss=0.01081548069349523
# EPOCH 48, starting from (3, 6) loss=0.025473290772201337
# EPOCH 48, starting from (3, 7) loss=0.025646097724317595
# EPOCH 48, starting from (3, 8) loss=0.035327832502184485
# EPOCH 48, starting from (3, 9) loss=0.04859033910489757
# EPOCH 48, starting from (3, 10) loss=0.04139407084169722
# EPOCH 48, starting from (3, 11) loss=0.007446730924141695
# EPOCH 48, starting from (3, 12) loss=0.00890273640031875
# EPOCH 48, starting from (3, 13) loss=0.015233454683865512
# EPOCH 48, starting from (3, 14) loss=0.020635386076563435
# EPOCH 48, starting from (3, 15) loss=0.02428347724964441
# EPOCH 48, starting from (3, 16) loss=0.023241642857142468
# EPOCH 48, starting from (3, 17) loss=0.02292382704583962
# EPOCH 48, starting from (3, 18) loss=0.024571747540306305
# EPOCH 48, starting from (3, 19) loss=0.3567449945165708
# EPOCH 48, starting from (3, 20) loss=10.338183435381513
# EPOCH 48, starting from (3, 21) loss=726.4959297577328
# EPOCH 48, starting from (3, 22) loss=166336.60472653888
# EPOCH 48: loss=704300.2177797966
# EPOCH 49, starting from (3, 0) loss=0.007306096369454295
# EPOCH 49, starting from (3, 1) loss=0.0029978925255329065
# EPOCH 49, starting from (3, 2) loss=0.003569036700101025
# EPOCH 49, starting from (3, 3) loss=0.0032289084563393872
# EPOCH 49, starting from (3, 4) loss=0.005008127407407885
# EPOCH 49, starting from (3, 5) loss=0.01022966110325181
# EPOCH 49, starting from (3, 6) loss=0.029555870738822286
# EPOCH 49, starting from (3, 7) loss=0.026736196395047915
# EPOCH 49, starting from (3, 8) loss=0.030575519892766044
# EPOCH 49, starting from (3, 9) loss=0.03967448762329681
# EPOCH 49, starting from (3, 10) loss=0.023604232747894298
# EPOCH 49, starting from (3, 11) loss=0.00907065559637877
# EPOCH 49, starting from (3, 12) loss=0.005769644207275487
# EPOCH 49, starting from (3, 13) loss=0.004492643149923208
# EPOCH 49, starting from (3, 14) loss=0.004844475658072359
# EPOCH 49, starting from (3, 15) loss=0.006630281427545701
# EPOCH 49, starting from (3, 16) loss=0.008329772394983979
# EPOCH 49, starting from (3, 17) loss=0.0194604558626587
# EPOCH 49, starting from (3, 18) loss=0.020095894272041594
# EPOCH 49, starting from (3, 19) loss=1.8802143455094955
# EPOCH 49, starting from (3, 20) loss=7.479865275956166
# EPOCH 49, starting from (3, 21) loss=3456.2680681471875
# EPOCH 49, starting from (3, 22) loss=119414.50475547714
# EPOCH 49, starting from (1, 0) loss=0.0004902157981295016
# EPOCH 49, starting from (1, 1) loss=0.0005652075481639573
# EPOCH 49, starting from (1, 2) loss=0.8484694532759935
# EPOCH 49, starting from (1, 3) loss=0.3730621720307705
# EPOCH 49, starting from (1, 4) loss=0.0838819440750423
# EPOCH 49, starting from (1, 5) loss=0.040920261723537514
# EPOCH 49, starting from (1, 6) loss=0.04146730628453257
# EPOCH 49, starting from (1, 7) loss=0.03469229269053667
# EPOCH 49, starting from (1, 8) loss=0.029756153165842396
# EPOCH 49, starting from (1, 9) loss=0.026278176808436825
# EPOCH 49, starting from (1, 10) loss=0.01115019792935242
# EPOCH 49, starting from (1, 11) loss=0.007518270524273893
# EPOCH 49, starting from (1, 12) loss=0.004867066555641776
# EPOCH 49, starting from (1, 13) loss=0.003685381428094927
# EPOCH 49, starting from (1, 14) loss=0.005871118356535153
# EPOCH 49, starting from (1, 15) loss=0.0036447738095093207
# EPOCH 49, starting from (1, 16) loss=0.010881151913021555
# EPOCH 49, starting from (1, 17) loss=0.05570977200241291
# EPOCH 49, starting from (1, 18) loss=0.01186303418773874
# EPOCH 49, starting from (1, 19) loss=10.945959011272855
# EPOCH 49, starting from (1, 20) loss=5.494486020638659
# EPOCH 49, starting from (1, 21) loss=19499.082600293703
# EPOCH 49, starting from (1, 22) loss=101498.88479293241
# EPOCH 49, starting from (2, 0) loss=0.0008848642440321984
# EPOCH 49, starting from (2, 1) loss=0.0006755141124346905
# EPOCH 49, starting from (2, 2) loss=0.0010764238909462174
# EPOCH 49, starting from (2, 3) loss=0.022263420963600223
# EPOCH 49, starting from (2, 4) loss=1.2039161487537184
# EPOCH 49, starting from (2, 5) loss=0.27571923036678553
# EPOCH 49, starting from (2, 6) loss=0.03769976345466166
# EPOCH 49, starting from (2, 7) loss=0.020310365856017105
# EPOCH 49, starting from (2, 8) loss=0.014448674418590983
# EPOCH 49, starting from (2, 9) loss=0.011068619883718815
# EPOCH 49, starting from (2, 10) loss=0.021624704248914942
# EPOCH 49, starting from (2, 11) loss=0.010192377688315971
# EPOCH 49, starting from (2, 12) loss=0.011234993700517615
# EPOCH 49, starting from (2, 13) loss=0.005741698519340082
# EPOCH 49, starting from (2, 14) loss=0.006444550993631605
# EPOCH 49, starting from (2, 15) loss=0.0051741661590891
# EPOCH 49, starting from (2, 16) loss=0.0074188601854196816
# EPOCH 49, starting from (2, 17) loss=0.014847194278732049
# EPOCH 49, starting from (2, 18) loss=0.04960903840923704
# EPOCH 49, starting from (2, 19) loss=0.9237703362995814
# EPOCH 49, starting from (2, 20) loss=12.952594664492876
# EPOCH 49, starting from (2, 21) loss=1139.6056524124313
# EPOCH 49, starting from (2, 22) loss=165037.20407467638
# EPOCH 49, starting from (0, 0) loss=0.0004952832733577486
# EPOCH 49, starting from (0, 1) loss=0.015269752618480707
# EPOCH 49, starting from (0, 2) loss=0.01575343848167077
# EPOCH 49, starting from (0, 3) loss=0.006457856852576441
# EPOCH 49, starting from (0, 4) loss=0.2196186151692022
# EPOCH 49, starting from (0, 5) loss=0.058359424231908236
# EPOCH 49, starting from (0, 6) loss=0.06794602743106928
# EPOCH 49, starting from (0, 7) loss=0.07967943822029776
# EPOCH 49, starting from (0, 8) loss=0.08616996191749415
# EPOCH 49, starting from (0, 9) loss=0.09085517555234786
# EPOCH 49, starting from (0, 10) loss=0.06116480801301778
# EPOCH 49, starting from (0, 11) loss=0.06900049497955527
# EPOCH 49, starting from (0, 12) loss=0.04940756991929049
# EPOCH 49, starting from (0, 13) loss=0.051243969653777824
# EPOCH 49, starting from (0, 14) loss=0.046584588821565645
# EPOCH 49, starting from (0, 15) loss=0.04564956674444628
# EPOCH 49, starting from (0, 16) loss=0.04665638974281527
# EPOCH 49, starting from (0, 17) loss=0.07400840847878865
# EPOCH 49, starting from (0, 18) loss=0.03746289770619478
# EPOCH 49, starting from (0, 19) loss=7.954644518687632
# EPOCH 49, starting from (0, 20) loss=3.1696248742354136
# EPOCH 49, starting from (0, 21) loss=13964.210405218608
# EPOCH 49, starting from (0, 22) loss=44525.2454495558
# EPOCH 49: loss=468590.50504584116
# EPOCH 50, starting from (2, 0) loss=0.0021615226295212575
# EPOCH 50, starting from (2, 1) loss=0.001298472968364811
# EPOCH 50, starting from (2, 2) loss=0.004067479565476583
# EPOCH 50, starting from (2, 3) loss=0.005524032148132014
# EPOCH 50, starting from (2, 4) loss=0.22784587989375985
# EPOCH 50, starting from (2, 5) loss=0.05851024443050872
# EPOCH 50, starting from (2, 6) loss=0.06032898515789714
# EPOCH 50, starting from (2, 7) loss=0.0672213942759666
# EPOCH 50, starting from (2, 8) loss=0.06983861502250517
# EPOCH 50, starting from (2, 9) loss=0.07091642800372744
# EPOCH 50, starting from (2, 10) loss=0.03487116310524243
# EPOCH 50, starting from (2, 11) loss=0.031670610509695475
# EPOCH 50, starting from (2, 12) loss=0.016328848757687035
# EPOCH 50, starting from (2, 13) loss=0.018420685350718266
# EPOCH 50, starting from (2, 14) loss=0.012082370286898837
# EPOCH 50, starting from (2, 15) loss=0.014296765151946526
# EPOCH 50, starting from (2, 16) loss=0.010287163331408323
# EPOCH 50, starting from (2, 17) loss=0.022079788283319555
# EPOCH 50, starting from (2, 18) loss=0.015022239951213401
# EPOCH 50, starting from (2, 19) loss=1.9322903351030756
# EPOCH 50, starting from (2, 20) loss=6.957595222348923
# EPOCH 50, starting from (2, 21) loss=3073.610904605325
# EPOCH 50, starting from (2, 22) loss=127686.81557478075
# EPOCH 50, starting from (3, 0) loss=0.008774153516943531
# EPOCH 50, starting from (3, 1) loss=0.003531162603357003
# EPOCH 50, starting from (3, 2) loss=0.004316163615535897
# EPOCH 50, starting from (3, 3) loss=0.003938900667137287
# EPOCH 50, starting from (3, 4) loss=0.005296767482969176
# EPOCH 50, starting from (3, 5) loss=0.011082978796490632
# EPOCH 50, starting from (3, 6) loss=0.05584672019727093
# EPOCH 50, starting from (3, 7) loss=0.06030464929244127
# EPOCH 50, starting from (3, 8) loss=0.06349528970283218
# EPOCH 50, starting from (3, 9) loss=0.03162586942639136
# EPOCH 50, starting from (3, 10) loss=0.036252722250010055
# EPOCH 50, starting from (3, 11) loss=0.02131120775862965
# EPOCH 50, starting from (3, 12) loss=0.01777090354494456
# EPOCH 50, starting from (3, 13) loss=0.017770470032767775
# EPOCH 50, starting from (3, 14) loss=0.016221448640770027
# EPOCH 50, starting from (3, 15) loss=0.01314960577928622
# EPOCH 50, starting from (3, 16) loss=0.0098168167182517
# EPOCH 50, starting from (3, 17) loss=0.00958993744801318
# EPOCH 50, starting from (3, 18) loss=0.061952688101420676
# EPOCH 50, starting from (3, 19) loss=0.25403895410744937
# EPOCH 50, starting from (3, 20) loss=34.765310342243254
# EPOCH 50, starting from (3, 21) loss=619.1752577775316
# EPOCH 50, starting from (3, 22) loss=418498.3248488877
# EPOCH 50, starting from (0, 0) loss=0.0008248478708984788
# EPOCH 50, starting from (0, 1) loss=0.004391869501345324
# EPOCH 50, starting from (0, 2) loss=0.005158137351371945
# EPOCH 50, starting from (0, 3) loss=0.00246005089345
# EPOCH 50, starting from (0, 4) loss=0.3844080544848634
# EPOCH 50, starting from (0, 5) loss=0.07605701454847776
# EPOCH 50, starting from (0, 6) loss=0.02940694532924849
# EPOCH 50, starting from (0, 7) loss=0.03711673464001188
# EPOCH 50, starting from (0, 8) loss=0.0420588595657605
# EPOCH 50, starting from (0, 9) loss=0.04657031462544293
# EPOCH 50, starting from (0, 10) loss=0.028734674782500753
# EPOCH 50, starting from (0, 11) loss=0.036179515062341856
# EPOCH 50, starting from (0, 12) loss=0.024105859969787518
# EPOCH 50, starting from (0, 13) loss=0.026738881972923335
# EPOCH 50, starting from (0, 14) loss=0.025377454110679053
# EPOCH 50, starting from (0, 15) loss=0.02581965568742224
# EPOCH 50, starting from (0, 16) loss=0.026691298576671147
# EPOCH 50, starting from (0, 17) loss=0.04626983516861743
# EPOCH 50, starting from (0, 18) loss=0.026749654739994574
# EPOCH 50, starting from (0, 19) loss=6.363826411559684
# EPOCH 50, starting from (0, 20) loss=4.735772578268326
# EPOCH 50, starting from (0, 21) loss=13500.61700995468
# EPOCH 50, starting from (0, 22) loss=27179.021020458134
# EPOCH 50, starting from (1, 0) loss=0.0009456594695679078
# EPOCH 50, starting from (1, 1) loss=0.0009403518066530321
# EPOCH 50, starting from (1, 2) loss=0.7953634280202393
# EPOCH 50, starting from (1, 3) loss=0.34845811916845826
# EPOCH 50, starting from (1, 4) loss=0.06482823205659748
# EPOCH 50, starting from (1, 5) loss=0.05234196524797814
# EPOCH 50, starting from (1, 6) loss=0.06182557479592333
# EPOCH 50, starting from (1, 7) loss=0.050583882951337755
# EPOCH 50, starting from (1, 8) loss=0.03997393501419654
# EPOCH 50, starting from (1, 9) loss=0.03363298132808321
# EPOCH 50, starting from (1, 10) loss=0.011829577841153906
# EPOCH 50, starting from (1, 11) loss=0.009563264244764003
# EPOCH 50, starting from (1, 12) loss=0.007230532885868247
# EPOCH 50, starting from (1, 13) loss=0.007455519102482637
# EPOCH 50, starting from (1, 14) loss=0.010033725790815028
# EPOCH 50, starting from (1, 15) loss=0.010143400887522245
# EPOCH 50, starting from (1, 16) loss=0.013924876291341674
# EPOCH 50, starting from (1, 17) loss=0.07324559972890407
# EPOCH 50, starting from (1, 18) loss=0.019380211351062052
# EPOCH 50, starting from (1, 19) loss=11.533610893314652
# EPOCH 50, starting from (1, 20) loss=6.190081980988995
# EPOCH 50, starting from (1, 21) loss=20627.444800940186
# EPOCH 50, starting from (1, 22) loss=65305.31245824022
# EPOCH 50: loss=676566.756044004
# EPOCH 51, starting from (3, 0) loss=0.008546694240033651
# EPOCH 51, starting from (3, 1) loss=0.00220332427805426
# EPOCH 51, starting from (3, 2) loss=0.0017668606410094342
# EPOCH 51, starting from (3, 3) loss=0.001442492875499922
# EPOCH 51, starting from (3, 4) loss=0.007343394773608753
# EPOCH 51, starting from (3, 5) loss=0.01659517297958329
# EPOCH 51, starting from (3, 6) loss=0.03083100979276281
# EPOCH 51, starting from (3, 7) loss=0.040282021943600484
# EPOCH 51, starting from (3, 8) loss=0.06088573510555052
# EPOCH 51, starting from (3, 9) loss=0.08336809971788864
# EPOCH 51, starting from (3, 10) loss=0.0640808155725437
# EPOCH 51, starting from (3, 11) loss=0.025387794695974464
# EPOCH 51, starting from (3, 12) loss=0.012032620049031073
# EPOCH 51, starting from (3, 13) loss=0.0067312213840578766
# EPOCH 51, starting from (3, 14) loss=0.004737606513488806
# EPOCH 51, starting from (3, 15) loss=0.0055677854341553675
# EPOCH 51, starting from (3, 16) loss=0.00516927462470354
# EPOCH 51, starting from (3, 17) loss=0.017115792257929
# EPOCH 51, starting from (3, 18) loss=0.020586432274125193
# EPOCH 51, starting from (3, 19) loss=2.431980676889554
# EPOCH 51, starting from (3, 20) loss=13.074058218798521
# EPOCH 51, starting from (3, 21) loss=4676.128894503042
# EPOCH 51, starting from (3, 22) loss=198890.5620639753
# EPOCH 51, starting from (0, 0) loss=0.0010807043773739453
# EPOCH 51, starting from (0, 1) loss=0.03382254569623212
# EPOCH 51, starting from (0, 2) loss=0.017507053061679618
# EPOCH 51, starting from (0, 3) loss=0.00814917901626844
# EPOCH 51, starting from (0, 4) loss=2.021302103339126
# EPOCH 51, starting from (0, 5) loss=0.8153306919644276
# EPOCH 51, starting from (0, 6) loss=0.19259328319249788
# EPOCH 51, starting from (0, 7) loss=0.11186880788746897
# EPOCH 51, starting from (0, 8) loss=0.08129959364145417
# EPOCH 51, starting from (0, 9) loss=0.05989663386580326
# EPOCH 51, starting from (0, 10) loss=0.06027622667036646
# EPOCH 51, starting from (0, 11) loss=0.02908560217179003
# EPOCH 51, starting from (0, 12) loss=0.03122258917310066
# EPOCH 51, starting from (0, 13) loss=0.017425585012836448
# EPOCH 51, starting from (0, 14) loss=0.014809935310297758
# EPOCH 51, starting from (0, 15) loss=0.007472657458006133
# EPOCH 51, starting from (0, 16) loss=0.008034124429257324
# EPOCH 51, starting from (0, 17) loss=0.007359356902466354
# EPOCH 51, starting from (0, 18) loss=0.3085679341615922
# EPOCH 51, starting from (0, 19) loss=1.3238051309921763
# EPOCH 51, starting from (0, 20) loss=138.37617659899044
# EPOCH 51, starting from (0, 21) loss=2239.692499900099
# EPOCH 51, starting from (0, 22) loss=1687106.3046956968
# EPOCH 51, starting from (2, 0) loss=0.0005793787776132135
# EPOCH 51, starting from (2, 1) loss=0.0010032744977812736
# EPOCH 51, starting from (2, 2) loss=0.0015681613210055479
# EPOCH 51, starting from (2, 3) loss=0.004128596550107688
# EPOCH 51, starting from (2, 4) loss=0.18476406159534983
# EPOCH 51, starting from (2, 5) loss=0.05106410451343194
# EPOCH 51, starting from (2, 6) loss=0.07303142725838868
# EPOCH 51, starting from (2, 7) loss=0.08101963244760965
# EPOCH 51, starting from (2, 8) loss=0.08442630861160696
# EPOCH 51, starting from (2, 9) loss=0.08647142820071282
# EPOCH 51, starting from (2, 10) loss=0.058380202730106384
# EPOCH 51, starting from (2, 11) loss=0.06294928830945001
# EPOCH 51, starting from (2, 12) loss=0.04822865097616388
# EPOCH 51, starting from (2, 13) loss=0.05082574371883115
# EPOCH 51, starting from (2, 14) loss=0.047629877441857066
# EPOCH 51, starting from (2, 15) loss=0.04781067261216662
# EPOCH 51, starting from (2, 16) loss=0.04797772248022946
# EPOCH 51, starting from (2, 17) loss=0.15039069662027663
# EPOCH 51, starting from (2, 18) loss=0.03716311982965977
# EPOCH 51, starting from (2, 19) loss=18.63861631526977
# EPOCH 51, starting from (2, 20) loss=3.7530538305957393
# EPOCH 51, starting from (2, 21) loss=30532.99908558846
# EPOCH 51, starting from (2, 22) loss=32923.012988540126
# EPOCH 51, starting from (1, 0) loss=0.0009620964261501
# EPOCH 51, starting from (1, 1) loss=0.0008476355482150287
# EPOCH 51, starting from (1, 2) loss=0.7254883555866857
# EPOCH 51, starting from (1, 3) loss=0.31701259724063263
# EPOCH 51, starting from (1, 4) loss=0.06106466957148112
# EPOCH 51, starting from (1, 5) loss=0.05767309070013103
# EPOCH 51, starting from (1, 6) loss=0.068579154468784
# EPOCH 51, starting from (1, 7) loss=0.06354687984874595
# EPOCH 51, starting from (1, 8) loss=0.057908851231373834
# EPOCH 51, starting from (1, 9) loss=0.05452792100431239
# EPOCH 51, starting from (1, 10) loss=0.024788872051736306
# EPOCH 51, starting from (1, 11) loss=0.035124242830783026
# EPOCH 51, starting from (1, 12) loss=0.025442764522605306
# EPOCH 51, starting from (1, 13) loss=0.028211112832914834
# EPOCH 51, starting from (1, 14) loss=0.02687143103874817
# EPOCH 51, starting from (1, 15) loss=0.025457469276288044
# EPOCH 51, starting from (1, 16) loss=0.030701891985677233
# EPOCH 51, starting from (1, 17) loss=0.0833902744374445
# EPOCH 51, starting from (1, 18) loss=0.02978757672528043
# EPOCH 51, starting from (1, 19) loss=13.141446400418413
# EPOCH 51, starting from (1, 20) loss=1.4537484943338155
# EPOCH 51, starting from (1, 21) loss=23610.122400314765
# EPOCH 51, starting from (1, 22) loss=23657.689831017087
# EPOCH 51: loss=2003835.783923195
# EPOCH 52, starting from (3, 0) loss=0.017657494313008018
# EPOCH 52, starting from (3, 1) loss=0.007641424580424981
# EPOCH 52, starting from (3, 2) loss=0.006579521153007014
# EPOCH 52, starting from (3, 3) loss=0.005424521521021636
# EPOCH 52, starting from (3, 4) loss=0.006503514937859638
# EPOCH 52, starting from (3, 5) loss=0.011506105330343864
# EPOCH 52, starting from (3, 6) loss=0.042037684876865836
# EPOCH 52, starting from (3, 7) loss=0.037396111857010375
# EPOCH 52, starting from (3, 8) loss=0.04371878667401344
# EPOCH 52, starting from (3, 9) loss=0.026804657670485427
# EPOCH 52, starting from (3, 10) loss=0.03273315804641002
# EPOCH 52, starting from (3, 11) loss=0.012162833368745449
# EPOCH 52, starting from (3, 12) loss=0.012536813320770477
# EPOCH 52, starting from (3, 13) loss=0.012755222580313271
# EPOCH 52, starting from (3, 14) loss=0.012002028596436119
# EPOCH 52, starting from (3, 15) loss=0.008476347473005581
# EPOCH 52, starting from (3, 16) loss=0.0059952570825422425
# EPOCH 52, starting from (3, 17) loss=0.006330881446108154
# EPOCH 52, starting from (3, 18) loss=0.037978269829490624
# EPOCH 52, starting from (3, 19) loss=0.26021801513073617
# EPOCH 52, starting from (3, 20) loss=22.660120959178574
# EPOCH 52, starting from (3, 21) loss=788.4979853153986
# EPOCH 52, starting from (3, 22) loss=277374.86470616
# EPOCH 52, starting from (2, 0) loss=0.0008735554232835868
# EPOCH 52, starting from (2, 1) loss=0.000921692931873025
# EPOCH 52, starting from (2, 2) loss=0.0009910865651382365
# EPOCH 52, starting from (2, 3) loss=0.01192880436878981
# EPOCH 52, starting from (2, 4) loss=0.7423575539783316
# EPOCH 52, starting from (2, 5) loss=0.17487145599901663
# EPOCH 52, starting from (2, 6) loss=0.019556728232616095
# EPOCH 52, starting from (2, 7) loss=0.01269620735610636
# EPOCH 52, starting from (2, 8) loss=0.013054514292778138
# EPOCH 52, starting from (2, 9) loss=0.01427144348292891
# EPOCH 52, starting from (2, 10) loss=0.010357256017502894
# EPOCH 52, starting from (2, 11) loss=0.006060352474874585
# EPOCH 52, starting from (2, 12) loss=0.006243979183530776
# EPOCH 52, starting from (2, 13) loss=0.006149214978927496
# EPOCH 52, starting from (2, 14) loss=0.006455703904852538
# EPOCH 52, starting from (2, 15) loss=0.00845631054273043
# EPOCH 52, starting from (2, 16) loss=0.008975839873786058
# EPOCH 52, starting from (2, 17) loss=0.025551285446909704
# EPOCH 52, starting from (2, 18) loss=0.014478725725195844
# EPOCH 52, starting from (2, 19) loss=2.008076459571495
# EPOCH 52, starting from (2, 20) loss=7.720449967968205
# EPOCH 52, starting from (2, 21) loss=2080.862290729615
# EPOCH 52, starting from (2, 22) loss=110472.48863093281
# EPOCH 52, starting from (1, 0) loss=0.0009578420245739277
# EPOCH 52, starting from (1, 1) loss=0.0009955660014178656
# EPOCH 52, starting from (1, 2) loss=0.6741723012152915
# EPOCH 52, starting from (1, 3) loss=0.29615667227905557
# EPOCH 52, starting from (1, 4) loss=0.07668404540118477
# EPOCH 52, starting from (1, 5) loss=0.038570941506148045
# EPOCH 52, starting from (1, 6) loss=0.037554999973260256
# EPOCH 52, starting from (1, 7) loss=0.031808143178496076
# EPOCH 52, starting from (1, 8) loss=0.028413826063608684
# EPOCH 52, starting from (1, 9) loss=0.027574395686598918
# EPOCH 52, starting from (1, 10) loss=0.02030005394974313
# EPOCH 52, starting from (1, 11) loss=0.01808857478291403
# EPOCH 52, starting from (1, 12) loss=0.012658337626471623
# EPOCH 52, starting from (1, 13) loss=0.01277170700837339
# EPOCH 52, starting from (1, 14) loss=0.012174746411013812
# EPOCH 52, starting from (1, 15) loss=0.011944414730435367
# EPOCH 52, starting from (1, 16) loss=0.015676158790600792
# EPOCH 52, starting from (1, 17) loss=0.07362156363972885
# EPOCH 52, starting from (1, 18) loss=0.014034654948973433
# EPOCH 52, starting from (1, 19) loss=11.27307812135603
# EPOCH 52, starting from (1, 20) loss=3.191550258075707
# EPOCH 52, starting from (1, 21) loss=18068.28395623722
# EPOCH 52, starting from (1, 22) loss=71177.15714983278
# EPOCH 52, starting from (0, 0) loss=0.0005532559789577522
# EPOCH 52, starting from (0, 1) loss=0.006026391790656118
# EPOCH 52, starting from (0, 2) loss=0.015379079944708707
# EPOCH 52, starting from (0, 3) loss=0.008588632070078709
# EPOCH 52, starting from (0, 4) loss=0.6817817337670754
# EPOCH 52, starting from (0, 5) loss=0.12587882305630416
# EPOCH 52, starting from (0, 6) loss=0.022025105797954123
# EPOCH 52, starting from (0, 7) loss=0.02322987771016652
# EPOCH 52, starting from (0, 8) loss=0.02538341289806968
# EPOCH 52, starting from (0, 9) loss=0.027014535551162837
# EPOCH 52, starting from (0, 10) loss=0.014372449825699388
# EPOCH 52, starting from (0, 11) loss=0.007491870489666945
# EPOCH 52, starting from (0, 12) loss=0.00769508247939929
# EPOCH 52, starting from (0, 13) loss=0.004908603272757041
# EPOCH 52, starting from (0, 14) loss=0.008569156626281979
# EPOCH 52, starting from (0, 15) loss=0.0076937783412225
# EPOCH 52, starting from (0, 16) loss=0.010820532969198628
# EPOCH 52, starting from (0, 17) loss=0.04767247053830702
# EPOCH 52, starting from (0, 18) loss=0.020052902939025223
# EPOCH 52, starting from (0, 19) loss=5.082090632511125
# EPOCH 52, starting from (0, 20) loss=6.057157477513109
# EPOCH 52, starting from (0, 21) loss=7081.692947069688
# EPOCH 52, starting from (0, 22) loss=94081.61745454147
# EPOCH 52: loss=581187.6176516971
# EPOCH 53, starting from (1, 0) loss=0.0010212085709778752
# EPOCH 53, starting from (1, 1) loss=0.0010786440594272172
# EPOCH 53, starting from (1, 2) loss=0.6220696628365507
# EPOCH 53, starting from (1, 3) loss=0.27927297560871567
# EPOCH 53, starting from (1, 4) loss=0.4643407517775131
# EPOCH 53, starting from (1, 5) loss=0.3681308950288462
# EPOCH 53, starting from (1, 6) loss=0.12457228240061212
# EPOCH 53, starting from (1, 7) loss=0.08350071201760965
# EPOCH 53, starting from (1, 8) loss=0.06341333619211115
# EPOCH 53, starting from (1, 9) loss=0.04726650604786412
# EPOCH 53, starting from (1, 10) loss=0.03170505669286297
# EPOCH 53, starting from (1, 11) loss=0.009540144212153328
# EPOCH 53, starting from (1, 12) loss=0.006853803689903618
# EPOCH 53, starting from (1, 13) loss=0.007278630685409855
# EPOCH 53, starting from (1, 14) loss=0.006367418195520658
# EPOCH 53, starting from (1, 15) loss=0.01110412001389859
# EPOCH 53, starting from (1, 16) loss=0.010772971851997413
# EPOCH 53, starting from (1, 17) loss=0.019070454803722298
# EPOCH 53, starting from (1, 18) loss=0.03534243162053325
# EPOCH 53, starting from (1, 19) loss=2.510866953890364
# EPOCH 53, starting from (1, 20) loss=17.833307596083845
# EPOCH 53, starting from (1, 21) loss=6226.8002351396335
# EPOCH 53, starting from (1, 22) loss=270437.657580651
# EPOCH 53, starting from (2, 0) loss=0.0017580547138082965
# EPOCH 53, starting from (2, 1) loss=0.0017355271170669082
# EPOCH 53, starting from (2, 2) loss=0.0019174150079715434
# EPOCH 53, starting from (2, 3) loss=0.004000936563299046
# EPOCH 53, starting from (2, 4) loss=0.14993947253784543
# EPOCH 53, starting from (2, 5) loss=0.06366047606093625
# EPOCH 53, starting from (2, 6) loss=0.09118173248062061
# EPOCH 53, starting from (2, 7) loss=0.09572480237173066
# EPOCH 53, starting from (2, 8) loss=0.096839929960657
# EPOCH 53, starting from (2, 9) loss=0.09710478621182267
# EPOCH 53, starting from (2, 10) loss=0.05183209556777011
# EPOCH 53, starting from (2, 11) loss=0.05381732202217111
# EPOCH 53, starting from (2, 12) loss=0.03321096796055496
# EPOCH 53, starting from (2, 13) loss=0.03370874265122913
# EPOCH 53, starting from (2, 14) loss=0.026076239361349743
# EPOCH 53, starting from (2, 15) loss=0.025649487716980203
# EPOCH 53, starting from (2, 16) loss=0.024719322157935673
# EPOCH 53, starting from (2, 17) loss=0.05810457407423448
# EPOCH 53, starting from (2, 18) loss=0.01742861682287908
# EPOCH 53, starting from (2, 19) loss=6.719657335383679
# EPOCH 53, starting from (2, 20) loss=3.440635491929381
# EPOCH 53, starting from (2, 21) loss=11675.57932831441
# EPOCH 53, starting from (2, 22) loss=41406.5208859975
# EPOCH 53, starting from (0, 0) loss=0.0004733801303683946
# EPOCH 53, starting from (0, 1) loss=0.0019487176304922244
# EPOCH 53, starting from (0, 2) loss=0.0031106352276862497
# EPOCH 53, starting from (0, 3) loss=0.002059573284666493
# EPOCH 53, starting from (0, 4) loss=0.19347672374587518
# EPOCH 53, starting from (0, 5) loss=0.05269886278543606
# EPOCH 53, starting from (0, 6) loss=0.05730309184149425
# EPOCH 53, starting from (0, 7) loss=0.06761851109724852
# EPOCH 53, starting from (0, 8) loss=0.07258798827872655
# EPOCH 53, starting from (0, 9) loss=0.0762822052124448
# EPOCH 53, starting from (0, 10) loss=0.04717448157865445
# EPOCH 53, starting from (0, 11) loss=0.04909859289309164
# EPOCH 53, starting from (0, 12) loss=0.026153028751621208
# EPOCH 53, starting from (0, 13) loss=0.024511035925505742
# EPOCH 53, starting from (0, 14) loss=0.016762271703788613
# EPOCH 53, starting from (0, 15) loss=0.01526396395033835
# EPOCH 53, starting from (0, 16) loss=0.012060109078638062
# EPOCH 53, starting from (0, 17) loss=0.03535170983187288
# EPOCH 53, starting from (0, 18) loss=0.016786263817658388
# EPOCH 53, starting from (0, 19) loss=4.481942499731226
# EPOCH 53, starting from (0, 20) loss=3.521290658352658
# EPOCH 53, starting from (0, 21) loss=8534.340365044645
# EPOCH 53, starting from (0, 22) loss=33193.150016865715
# EPOCH 53, starting from (3, 0) loss=0.01008113972689952
# EPOCH 53, starting from (3, 1) loss=0.003264867792360079
# EPOCH 53, starting from (3, 2) loss=0.001616007862121554
# EPOCH 53, starting from (3, 3) loss=0.0011782366972755707
# EPOCH 53, starting from (3, 4) loss=0.006306146018811456
# EPOCH 53, starting from (3, 5) loss=0.013923133929945555
# EPOCH 53, starting from (3, 6) loss=0.02405890635131538
# EPOCH 53, starting from (3, 7) loss=0.039634040995919335
# EPOCH 53, starting from (3, 8) loss=0.06078346997498504
# EPOCH 53, starting from (3, 9) loss=0.08274121898862485
# EPOCH 53, starting from (3, 10) loss=0.058299866424819914
# EPOCH 53, starting from (3, 11) loss=0.019351900809016612
# EPOCH 53, starting from (3, 12) loss=0.0073636398952731125
# EPOCH 53, starting from (3, 13) loss=0.004843068920323161
# EPOCH 53, starting from (3, 14) loss=0.00673953373225042
# EPOCH 53, starting from (3, 15) loss=0.012353772908589612
# EPOCH 53, starting from (3, 16) loss=0.01494499722749075
# EPOCH 53, starting from (3, 17) loss=0.03125480164190409
# EPOCH 53, starting from (3, 18) loss=0.0279498676865171
# EPOCH 53, starting from (3, 19) loss=2.238500145143451
# EPOCH 53, starting from (3, 20) loss=5.932702644655739
# EPOCH 53, starting from (3, 21) loss=4326.783492953454
# EPOCH 53, starting from (3, 22) loss=87782.97009743795
# EPOCH 53: loss=463634.7994280017
# EPOCH 54, starting from (3, 0) loss=0.012361698547136897
# EPOCH 54, starting from (3, 1) loss=0.004734255644455808
# EPOCH 54, starting from (3, 2) loss=0.004865612826090283
# EPOCH 54, starting from (3, 3) loss=0.003942215593554511
# EPOCH 54, starting from (3, 4) loss=0.005644758796842258
# EPOCH 54, starting from (3, 5) loss=0.010855695282267836
# EPOCH 54, starting from (3, 6) loss=0.03954240383320568
# EPOCH 54, starting from (3, 7) loss=0.028065100968214126
# EPOCH 54, starting from (3, 8) loss=0.034007424815929346
# EPOCH 54, starting from (3, 9) loss=0.03086806520004965
# EPOCH 54, starting from (3, 10) loss=0.024332684551006907
# EPOCH 54, starting from (3, 11) loss=0.007551723831158132
# EPOCH 54, starting from (3, 12) loss=0.006769441958500791
# EPOCH 54, starting from (3, 13) loss=0.008953399742082941
# EPOCH 54, starting from (3, 14) loss=0.01008299319343213
# EPOCH 54, starting from (3, 15) loss=0.009833012294979524
# EPOCH 54, starting from (3, 16) loss=0.0073911531195012935
# EPOCH 54, starting from (3, 17) loss=0.007763917405330458
# EPOCH 54, starting from (3, 18) loss=0.009631428333046912
# EPOCH 54, starting from (3, 19) loss=0.36581239262563847
# EPOCH 54, starting from (3, 20) loss=9.12729466286281
# EPOCH 54, starting from (3, 21) loss=671.4517844858614
# EPOCH 54, starting from (3, 22) loss=140671.11423712157
# EPOCH 54, starting from (2, 0) loss=0.0010352334173510359
# EPOCH 54, starting from (2, 1) loss=0.0010094673927135006
# EPOCH 54, starting from (2, 2) loss=0.0012944700064603375
# EPOCH 54, starting from (2, 3) loss=0.017971630367326543
# EPOCH 54, starting from (2, 4) loss=1.1957749451505266
# EPOCH 54, starting from (2, 5) loss=0.30746709905978825
# EPOCH 54, starting from (2, 6) loss=0.03769026759269858
# EPOCH 54, starting from (2, 7) loss=0.01727554025539631
# EPOCH 54, starting from (2, 8) loss=0.012373441122566725
# EPOCH 54, starting from (2, 9) loss=0.009510817631891474
# EPOCH 54, starting from (2, 10) loss=0.015198185891992344
# EPOCH 54, starting from (2, 11) loss=0.007658121038152881
# EPOCH 54, starting from (2, 12) loss=0.009019519582090222
# EPOCH 54, starting from (2, 13) loss=0.005674299188743586
# EPOCH 54, starting from (2, 14) loss=0.006311993412225944
# EPOCH 54, starting from (2, 15) loss=0.006205201365590495
# EPOCH 54, starting from (2, 16) loss=0.006605491437654383
# EPOCH 54, starting from (2, 17) loss=0.01764657480408206
# EPOCH 54, starting from (2, 18) loss=0.01978761976683251
# EPOCH 54, starting from (2, 19) loss=1.8208805561185315
# EPOCH 54, starting from (2, 20) loss=4.329943347300411
# EPOCH 54, starting from (2, 21) loss=2630.3399988044907
# EPOCH 54, starting from (2, 22) loss=16416.648588635373
# EPOCH 54, starting from (0, 0) loss=0.0006445410648755781
# EPOCH 54, starting from (0, 1) loss=0.022550730822363446
# EPOCH 54, starting from (0, 2) loss=0.012602031569023122
# EPOCH 54, starting from (0, 3) loss=0.007051351271878609
# EPOCH 54, starting from (0, 4) loss=0.3268473121807212
# EPOCH 54, starting from (0, 5) loss=0.06163569771437256
# EPOCH 54, starting from (0, 6) loss=0.05650558433664405
# EPOCH 54, starting from (0, 7) loss=0.06753143958451438
# EPOCH 54, starting from (0, 8) loss=0.07406656373004697
# EPOCH 54, starting from (0, 9) loss=0.07895317594240149
# EPOCH 54, starting from (0, 10) loss=0.0578748000433968
# EPOCH 54, starting from (0, 11) loss=0.06386848385709379
# EPOCH 54, starting from (0, 12) loss=0.042602822993084925
# EPOCH 54, starting from (0, 13) loss=0.04458101403648815
# EPOCH 54, starting from (0, 14) loss=0.03845239630815551
# EPOCH 54, starting from (0, 15) loss=0.038212546220541155
# EPOCH 54, starting from (0, 16) loss=0.03643243813144895
# EPOCH 54, starting from (0, 17) loss=0.0841928750516294
# EPOCH 54, starting from (0, 18) loss=0.033872480956398957
# EPOCH 54, starting from (0, 19) loss=10.682623188866252
# EPOCH 54, starting from (0, 20) loss=3.0837624443729683
# EPOCH 54, starting from (0, 21) loss=20545.398236549674
# EPOCH 54, starting from (0, 22) loss=14655.238317319328
# EPOCH 54, starting from (1, 0) loss=0.00045477841822354626
# EPOCH 54, starting from (1, 1) loss=0.00043524822186563644
# EPOCH 54, starting from (1, 2) loss=0.5253917715004729
# EPOCH 54, starting from (1, 3) loss=0.23136312445429125
# EPOCH 54, starting from (1, 4) loss=0.08882663238596865
# EPOCH 54, starting from (1, 5) loss=0.041203428912226864
# EPOCH 54, starting from (1, 6) loss=0.036017720459367165
# EPOCH 54, starting from (1, 7) loss=0.03375336480294249
# EPOCH 54, starting from (1, 8) loss=0.031870035150157607
# EPOCH 54, starting from (1, 9) loss=0.030753212264975464
# EPOCH 54, starting from (1, 10) loss=0.013465166038719245
# EPOCH 54, starting from (1, 11) loss=0.013721878881664451
# EPOCH 54, starting from (1, 12) loss=0.0071024031041087045
# EPOCH 54, starting from (1, 13) loss=0.006793468315687784
# EPOCH 54, starting from (1, 14) loss=0.00660482916918318
# EPOCH 54, starting from (1, 15) loss=0.004599679869743866
# EPOCH 54, starting from (1, 16) loss=0.010947167265734664
# EPOCH 54, starting from (1, 17) loss=0.07058302555915984
# EPOCH 54, starting from (1, 18) loss=0.012005328304430542
# EPOCH 54, starting from (1, 19) loss=12.798829924647977
# EPOCH 54, starting from (1, 20) loss=4.529155254382045
# EPOCH 54, starting from (1, 21) loss=20528.07763784195
# EPOCH 54, starting from (1, 22) loss=93092.14274619232
# EPOCH 54: loss=309261.426926175
# EPOCH 55, starting from (1, 0) loss=0.0006718345627845968
# EPOCH 55, starting from (1, 1) loss=0.0006369514153309564
# EPOCH 55, starting from (1, 2) loss=0.48715151139310126
# EPOCH 55, starting from (1, 3) loss=0.21638561812055848
# EPOCH 55, starting from (1, 4) loss=0.11676740391618512
# EPOCH 55, starting from (1, 5) loss=0.03939978343020468
# EPOCH 55, starting from (1, 6) loss=0.020578481598853986
# EPOCH 55, starting from (1, 7) loss=0.018069038964356687
# EPOCH 55, starting from (1, 8) loss=0.016134073959155934
# EPOCH 55, starting from (1, 9) loss=0.014737510615720685
# EPOCH 55, starting from (1, 10) loss=0.0119963434731659
# EPOCH 55, starting from (1, 11) loss=0.006006442080155788
# EPOCH 55, starting from (1, 12) loss=0.003933820400798716
# EPOCH 55, starting from (1, 13) loss=0.0025171587942229346
# EPOCH 55, starting from (1, 14) loss=0.0037182449097357823
# EPOCH 55, starting from (1, 15) loss=0.0026725418842829265
# EPOCH 55, starting from (1, 16) loss=0.006958613794430811
# EPOCH 55, starting from (1, 17) loss=0.02688803657939718
# EPOCH 55, starting from (1, 18) loss=0.006343864594890933
# EPOCH 55, starting from (1, 19) loss=4.678942004973759
# EPOCH 55, starting from (1, 20) loss=5.189465505074345
# EPOCH 55, starting from (1, 21) loss=6565.105724632253
# EPOCH 55, starting from (1, 22) loss=183397.51362901917
# EPOCH 55, starting from (2, 0) loss=0.0030479863975463946
# EPOCH 55, starting from (2, 1) loss=0.003628530383422521
# EPOCH 55, starting from (2, 2) loss=0.014460209382652961
# EPOCH 55, starting from (2, 3) loss=0.014898250903235991
# EPOCH 55, starting from (2, 4) loss=0.40339156160798667
# EPOCH 55, starting from (2, 5) loss=0.04380614154197257
# EPOCH 55, starting from (2, 6) loss=0.04432871626075382
# EPOCH 55, starting from (2, 7) loss=0.04887842527440188
# EPOCH 55, starting from (2, 8) loss=0.04861786017191244
# EPOCH 55, starting from (2, 9) loss=0.047528350445054095
# EPOCH 55, starting from (2, 10) loss=0.015495239681624078
# ...
# EPOCH 96, starting from (0, 21) loss=13947.292854148873
# EPOCH 96, starting from (0, 22) loss=27446.984301411845
# EPOCH 96: loss=605323.6491413526
# EPOCH 97, starting from (2, 0) loss=0.0008603769688392967
# EPOCH 97, starting from (2, 1) loss=0.0063347589971157366
# EPOCH 97, starting from (2, 2) loss=0.003951359512877206
# EPOCH 97, starting from (2, 3) loss=0.00969195868894058
# EPOCH 97, starting from (2, 4) loss=0.4085099971672944
# EPOCH 97, starting from (2, 5) loss=0.035878157559202775
# EPOCH 97, starting from (2, 6) loss=0.01887457371900008
# EPOCH 97, starting from (2, 7) loss=0.01745444543320517
# EPOCH 97, starting from (2, 8) loss=0.014420363553787827
# EPOCH 97, starting from (2, 9) loss=0.012076763088270335
# EPOCH 97, starting from (2, 10) loss=0.009635495276958197
# EPOCH 97, starting from (2, 11) loss=0.006488795987071896
# EPOCH 97, starting from (2, 12) loss=0.008924314508771018
# EPOCH 97, starting from (2, 13) loss=0.008349244739338053
# EPOCH 97, starting from (2, 14) loss=0.009184138795041579
# EPOCH 97, starting from (2, 15) loss=0.012475847013301816
# EPOCH 97, starting from (2, 16) loss=0.00972795882640807
# EPOCH 97, starting from (2, 17) loss=0.04392786175125088
# EPOCH 97, starting from (2, 18) loss=0.03201095548274062
# EPOCH 97, starting from (2, 19) loss=3.8663314255915684
# EPOCH 97, starting from (2, 20) loss=15.080158482231163
# EPOCH 97, starting from (2, 21) loss=5523.62512289652
# EPOCH 97, starting from (2, 22) loss=216607.5523055225
# EPOCH 97, starting from (1, 0) loss=0.0006021855115951009
# EPOCH 97, starting from (1, 1) loss=0.0007590461081560759
# EPOCH 97, starting from (1, 2) loss=0.004108709848842762
# EPOCH 97, starting from (1, 3) loss=0.005072827798167761
# EPOCH 97, starting from (1, 4) loss=0.052107413764187045
# EPOCH 97, starting from (1, 5) loss=0.046523491885162485
# EPOCH 97, starting from (1, 6) loss=0.04816708763841595
# EPOCH 97, starting from (1, 7) loss=0.035588721574305815
# EPOCH 97, starting from (1, 8) loss=0.029089885655905093
# EPOCH 97, starting from (1, 9) loss=0.026383836334051707
# EPOCH 97, starting from (1, 10) loss=0.014176817863054634
# EPOCH 97, starting from (1, 11) loss=0.013089605933061117
# EPOCH 97, starting from (1, 12) loss=0.00906297700598912
# EPOCH 97, starting from (1, 13) loss=0.008339020759837524
# EPOCH 97, starting from (1, 14) loss=0.010007591524760743
# EPOCH 97, starting from (1, 15) loss=0.007561801866363808
# EPOCH 97, starting from (1, 16) loss=0.014166035197109439
# EPOCH 97, starting from (1, 17) loss=0.0775757073234237
# EPOCH 97, starting from (1, 18) loss=0.01310806927887233
# EPOCH 97, starting from (1, 19) loss=13.807708653883482
# EPOCH 97, starting from (1, 20) loss=3.313774640424574
# EPOCH 97, starting from (1, 21) loss=23361.14238517108
# EPOCH 97, starting from (1, 22) loss=53528.66506553462
# EPOCH 97, starting from (0, 0) loss=0.0007344409193652987
# EPOCH 97, starting from (0, 1) loss=0.004699131059702658
# EPOCH 97, starting from (0, 2) loss=0.004870861676721827
# EPOCH 97, starting from (0, 3) loss=0.003920446561293793
# EPOCH 97, starting from (0, 4) loss=0.8119124354592723
# EPOCH 97, starting from (0, 5) loss=0.2038105085952382
# EPOCH 97, starting from (0, 6) loss=0.02949043299814007
# EPOCH 97, starting from (0, 7) loss=0.015935035760360573
# EPOCH 97, starting from (0, 8) loss=0.0121578925002086
# EPOCH 97, starting from (0, 9) loss=0.010584637414197162
# EPOCH 97, starting from (0, 10) loss=0.011529802658223247
# EPOCH 97, starting from (0, 11) loss=0.005293637987296673
# EPOCH 97, starting from (0, 12) loss=0.007756324105798344
# EPOCH 97, starting from (0, 13) loss=0.004178243407576519
# EPOCH 97, starting from (0, 14) loss=0.0067258719163395255
# EPOCH 97, starting from (0, 15) loss=0.004587141722372203
# EPOCH 97, starting from (0, 16) loss=0.007677349540742821
# EPOCH 97, starting from (0, 17) loss=0.020220864998295424
# EPOCH 97, starting from (0, 18) loss=0.07639428415959008
# EPOCH 97, starting from (0, 19) loss=2.89719816868138
# EPOCH 97, starting from (0, 20) loss=25.315501700284965
# EPOCH 97, starting from (0, 21) loss=4563.811250005632
# EPOCH 97, starting from (0, 22) loss=232304.47982249976
# EPOCH 97, starting from (3, 0) loss=0.003318235730583817
# EPOCH 97, starting from (3, 1) loss=0.0007087053790538411
# EPOCH 97, starting from (3, 2) loss=0.0010316622075614555
# EPOCH 97, starting from (3, 3) loss=0.0010223840317040754
# EPOCH 97, starting from (3, 4) loss=0.006752270967785095
# EPOCH 97, starting from (3, 5) loss=0.01371148712156033
# EPOCH 97, starting from (3, 6) loss=0.02386393776565885
# EPOCH 97, starting from (3, 7) loss=0.0384671786232544
# EPOCH 97, starting from (3, 8) loss=0.05704710501305557
# EPOCH 97, starting from (3, 9) loss=0.07486202216929108
# EPOCH 97, starting from (3, 10) loss=0.056266095892357273
# EPOCH 97, starting from (3, 11) loss=0.034824458180081216
# EPOCH 97, starting from (3, 12) loss=0.02286134595098868
# EPOCH 97, starting from (3, 13) loss=0.016407011477781664
# EPOCH 97, starting from (3, 14) loss=0.013354692698535137
# EPOCH 97, starting from (3, 15) loss=0.012380970607474204
# EPOCH 97, starting from (3, 16) loss=0.012525367717482456
# EPOCH 97, starting from (3, 17) loss=0.024061000480029647
# EPOCH 97, starting from (3, 18) loss=0.029488570732447667
# EPOCH 97, starting from (3, 19) loss=2.9395115989459337
# EPOCH 97, starting from (3, 20) loss=14.55100799358239
# EPOCH 97, starting from (3, 21) loss=5787.41739046749
# EPOCH 97, starting from (3, 22) loss=227768.19543417153
# EPOCH 97: loss=769529.4296709788
# EPOCH 98, starting from (0, 0) loss=0.00044611077223201086
# EPOCH 98, starting from (0, 1) loss=0.0012152210718911825
# EPOCH 98, starting from (0, 2) loss=0.0062999867342703126
# EPOCH 98, starting from (0, 3) loss=0.0034314401888708023
# EPOCH 98, starting from (0, 4) loss=0.6979485962740601
# EPOCH 98, starting from (0, 5) loss=0.11158580638345618
# EPOCH 98, starting from (0, 6) loss=0.018069042476041443
# EPOCH 98, starting from (0, 7) loss=0.015271336038409022
# EPOCH 98, starting from (0, 8) loss=0.014813777461312645
# EPOCH 98, starting from (0, 9) loss=0.015392694527502047
# EPOCH 98, starting from (0, 10) loss=0.009242988401668853
# EPOCH 98, starting from (0, 11) loss=0.005758605540686958
# EPOCH 98, starting from (0, 12) loss=0.005222405260072182
# EPOCH 98, starting from (0, 13) loss=0.00623004195403157
# EPOCH 98, starting from (0, 14) loss=0.009223465959216635
# EPOCH 98, starting from (0, 15) loss=0.016052790750232037
# EPOCH 98, starting from (0, 16) loss=0.014818330336579465
# EPOCH 98, starting from (0, 17) loss=0.07679393564257896
# EPOCH 98, starting from (0, 18) loss=0.024336439840123188
# EPOCH 98, starting from (0, 19) loss=7.284802682292304
# EPOCH 98, starting from (0, 20) loss=1.725849402698098
# EPOCH 98, starting from (0, 21) loss=13790.730209823721
# EPOCH 98, starting from (0, 22) loss=11560.724253645236
# EPOCH 98, starting from (2, 0) loss=0.0006044473272698578
# EPOCH 98, starting from (2, 1) loss=0.001083463595024321
# EPOCH 98, starting from (2, 2) loss=0.0015931954358310433
# EPOCH 98, starting from (2, 3) loss=0.006800430192580276
# EPOCH 98, starting from (2, 4) loss=0.33385174133509143
# EPOCH 98, starting from (2, 5) loss=0.0362237630778068
# EPOCH 98, starting from (2, 6) loss=0.018544141179556543
# EPOCH 98, starting from (2, 7) loss=0.019991469888105275
# EPOCH 98, starting from (2, 8) loss=0.018945055814148626
# EPOCH 98, starting from (2, 9) loss=0.017487940767216336
# EPOCH 98, starting from (2, 10) loss=0.005492241834348835
# EPOCH 98, starting from (2, 11) loss=0.0044581797659583484
# EPOCH 98, starting from (2, 12) loss=0.0040801117179001195
# EPOCH 98, starting from (2, 13) loss=0.006003477631506627
# EPOCH 98, starting from (2, 14) loss=0.006837007927677775
# EPOCH 98, starting from (2, 15) loss=0.013074882954409244
# EPOCH 98, starting from (2, 16) loss=0.010387930007632244
# EPOCH 98, starting from (2, 17) loss=0.0533495532349328
# EPOCH 98, starting from (2, 18) loss=0.02008421444145671
# EPOCH 98, starting from (2, 19) loss=4.118025905949589
# EPOCH 98, starting from (2, 20) loss=1.3601389698220103
# EPOCH 98, starting from (2, 21) loss=6163.492679942819
# EPOCH 98, starting from (2, 22) loss=8173.8843265599235
# EPOCH 98, starting from (1, 0) loss=0.0006012243630778204
# EPOCH 98, starting from (1, 1) loss=0.000730834941020724
# EPOCH 98, starting from (1, 2) loss=0.00681749251372754
# EPOCH 98, starting from (1, 3) loss=0.008128210254847694
# EPOCH 98, starting from (1, 4) loss=0.09732492131141345
# EPOCH 98, starting from (1, 5) loss=0.04306992718910798
# EPOCH 98, starting from (1, 6) loss=0.022603696293635726
# EPOCH 98, starting from (1, 7) loss=0.01772751687430625
# EPOCH 98, starting from (1, 8) loss=0.014575226371069509
# EPOCH 98, starting from (1, 9) loss=0.012331202721236799
# EPOCH 98, starting from (1, 10) loss=0.012049244400610124
# EPOCH 98, starting from (1, 11) loss=0.009083329871128703
# EPOCH 98, starting from (1, 12) loss=0.007720053547770216
# EPOCH 98, starting from (1, 13) loss=0.009975449695164677
# EPOCH 98, starting from (1, 14) loss=0.00962985923953613
# EPOCH 98, starting from (1, 15) loss=0.011853753193266023
# EPOCH 98, starting from (1, 16) loss=0.012015438382626347
# EPOCH 98, starting from (1, 17) loss=0.01698289363005965
# EPOCH 98, starting from (1, 18) loss=0.014375375488154055
# EPOCH 98, starting from (1, 19) loss=1.2342219922595465
# EPOCH 98, starting from (1, 20) loss=9.350449173403788
# EPOCH 98, starting from (1, 21) loss=2214.36855286734
# EPOCH 98, starting from (1, 22) loss=176983.5871019709
# EPOCH 98, starting from (3, 0) loss=0.022435941928159155
# EPOCH 98, starting from (3, 1) loss=0.00848388191611979
# EPOCH 98, starting from (3, 2) loss=0.005697416465491123
# EPOCH 98, starting from (3, 3) loss=0.004048849391737629
# EPOCH 98, starting from (3, 4) loss=0.006169231023557547
# EPOCH 98, starting from (3, 5) loss=0.011256438783550411
# EPOCH 98, starting from (3, 6) loss=0.03768375908216319
# EPOCH 98, starting from (3, 7) loss=0.02496187138416739
# EPOCH 98, starting from (3, 8) loss=0.02323348503417076
# EPOCH 98, starting from (3, 9) loss=0.01376142444247366
# EPOCH 98, starting from (3, 10) loss=0.014338890607338946
# EPOCH 98, starting from (3, 11) loss=0.005979426965062333
# EPOCH 98, starting from (3, 12) loss=0.00575528098438004
# EPOCH 98, starting from (3, 13) loss=0.005852974884741607
# EPOCH 98, starting from (3, 14) loss=0.00617574549826956
# EPOCH 98, starting from (3, 15) loss=0.006123363120591075
# EPOCH 98, starting from (3, 16) loss=0.006461818977575678
# EPOCH 98, starting from (3, 17) loss=0.009571212355469098
# EPOCH 98, starting from (3, 18) loss=0.057660993747996804
# EPOCH 98, starting from (3, 19) loss=0.14258838846930338
# EPOCH 98, starting from (3, 20) loss=32.76989515306875
# EPOCH 98, starting from (3, 21) loss=477.1567490288011
# EPOCH 98, starting from (3, 22) loss=382234.4557181002
# EPOCH 98: loss=601658.6198575275
# EPOCH 99, starting from (0, 0) loss=0.00029068204968416716
# EPOCH 99, starting from (0, 1) loss=0.0085088598275799
# EPOCH 99, starting from (0, 2) loss=0.004473465351625289
# EPOCH 99, starting from (0, 3) loss=0.003053809858403263
# EPOCH 99, starting from (0, 4) loss=0.4279691088986482
# EPOCH 99, starting from (0, 5) loss=0.043961477028938205
# EPOCH 99, starting from (0, 6) loss=0.04313545539717109
# EPOCH 99, starting from (0, 7) loss=0.048963401995322
# EPOCH 99, starting from (0, 8) loss=0.05167110075331653
# EPOCH 99, starting from (0, 9) loss=0.05399699651631375
# EPOCH 99, starting from (0, 10) loss=0.02794408517394197
# EPOCH 99, starting from (0, 11) loss=0.027098607811950493
# EPOCH 99, starting from (0, 12) loss=0.013803462110552476
# EPOCH 99, starting from (0, 13) loss=0.011559828582783583
# EPOCH 99, starting from (0, 14) loss=0.009081598530971796
# EPOCH 99, starting from (0, 15) loss=0.007652418400845503
# EPOCH 99, starting from (0, 16) loss=0.007463001429848508
# EPOCH 99, starting from (0, 17) loss=0.05694518563465682
# EPOCH 99, starting from (0, 18) loss=0.03218784871437038
# EPOCH 99, starting from (0, 19) loss=7.83689281481816
# EPOCH 99, starting from (0, 20) loss=15.527789607472663
# EPOCH 99, starting from (0, 21) loss=12048.995839198024
# EPOCH 99, starting from (0, 22) loss=177077.4532407509
# EPOCH 99, starting from (2, 0) loss=0.0004801309810086936
# EPOCH 99, starting from (2, 1) loss=0.0011254306712038804
# EPOCH 99, starting from (2, 2) loss=0.007126179510897669
# EPOCH 99, starting from (2, 3) loss=0.014514456567122424
# EPOCH 99, starting from (2, 4) loss=0.465203016040485
# EPOCH 99, starting from (2, 5) loss=0.04412160310004009
# EPOCH 99, starting from (2, 6) loss=0.012740422942616562
# EPOCH 99, starting from (2, 7) loss=0.011313158420873612
# EPOCH 99, starting from (2, 8) loss=0.008661428260115137
# EPOCH 99, starting from (2, 9) loss=0.007103852516680314
# EPOCH 99, starting from (2, 10) loss=0.010792950673992018
# EPOCH 99, starting from (2, 11) loss=0.008712040708906816
# EPOCH 99, starting from (2, 12) loss=0.015425095077512817
# EPOCH 99, starting from (2, 13) loss=0.017395067756530293
# EPOCH 99, starting from (2, 14) loss=0.025412947853711135
# EPOCH 99, starting from (2, 15) loss=0.029107033268033145
# EPOCH 99, starting from (2, 16) loss=0.03830332167885685
# EPOCH 99, starting from (2, 17) loss=0.04517073276225259
# EPOCH 99, starting from (2, 18) loss=0.1004344863111483
# EPOCH 99, starting from (2, 19) loss=0.6857445240000212
# EPOCH 99, starting from (2, 20) loss=18.499608951159633
# EPOCH 99, starting from (2, 21) loss=638.6888566021298
# EPOCH 99, starting from (2, 22) loss=178604.70242349076
# EPOCH 99, starting from (3, 0) loss=0.0066525670194728295
# EPOCH 99, starting from (3, 1) loss=0.001808943317783756
# EPOCH 99, starting from (3, 2) loss=0.0010979138136049888
# EPOCH 99, starting from (3, 3) loss=0.0008088335207966984
# EPOCH 99, starting from (3, 4) loss=0.005712651264843883
# EPOCH 99, starting from (3, 5) loss=0.012992886205964886
# EPOCH 99, starting from (3, 6) loss=0.02202131030858672
# EPOCH 99, starting from (3, 7) loss=0.03861934527253406
# EPOCH 99, starting from (3, 8) loss=0.05923548141889722
# EPOCH 99, starting from (3, 9) loss=0.0794571947302823
# EPOCH 99, starting from (3, 10) loss=0.05281681437848986
# EPOCH 99, starting from (3, 11) loss=0.02541290949854034
# EPOCH 99, starting from (3, 12) loss=0.014045070865649193
# EPOCH 99, starting from (3, 13) loss=0.008622933656191585
# EPOCH 99, starting from (3, 14) loss=0.006973682240832179
# EPOCH 99, starting from (3, 15) loss=0.007264854776514153
# EPOCH 99, starting from (3, 16) loss=0.008301994644985674
# EPOCH 99, starting from (3, 17) loss=0.020520296264327532
# EPOCH 99, starting from (3, 18) loss=0.0156651103620795
# EPOCH 99, starting from (3, 19) loss=2.3037076980347773
# EPOCH 99, starting from (3, 20) loss=5.906650465429822
# EPOCH 99, starting from (3, 21) loss=4393.8222303263165
# EPOCH 99, starting from (3, 22) loss=96945.88761711097
# EPOCH 99, starting from (1, 0) loss=0.0005260076277284312
# EPOCH 99, starting from (1, 1) loss=0.0005161702504462414
# EPOCH 99, starting from (1, 2) loss=0.005774952217016178
# EPOCH 99, starting from (1, 3) loss=0.006451154152100308
# EPOCH 99, starting from (1, 4) loss=0.0577701771134737
# EPOCH 99, starting from (1, 5) loss=0.034541946130214815
# EPOCH 99, starting from (1, 6) loss=0.02802205415734349
# EPOCH 99, starting from (1, 7) loss=0.019477953564993513
# EPOCH 99, starting from (1, 8) loss=0.015566646397369007
# EPOCH 99, starting from (1, 9) loss=0.013058093635301915
# EPOCH 99, starting from (1, 10) loss=0.01611900668172472
# EPOCH 99, starting from (1, 11) loss=0.006745714139151613
# EPOCH 99, starting from (1, 12) loss=0.013901408076429308
# EPOCH 99, starting from (1, 13) loss=0.011075134967494463
# EPOCH 99, starting from (1, 14) loss=0.018014874650708813
# EPOCH 99, starting from (1, 15) loss=0.016166944643216535
# EPOCH 99, starting from (1, 16) loss=0.022465396772183163
# EPOCH 99, starting from (1, 17) loss=0.04615469674284517
# EPOCH 99, starting from (1, 18) loss=0.01958292162726927
# EPOCH 99, starting from (1, 19) loss=3.75906768867377
# EPOCH 99, starting from (1, 20) loss=1.9883697356408605
# EPOCH 99, starting from (1, 21) loss=2991.766436479249
# EPOCH 99, starting from (1, 22) loss=125204.87933970582
# EPOCH 99: loss=597965.1866809457

# %%
state_dict = flax.serialization.to_state_dict(state)
with open('/content/drive/MyDrive/ARIA/v1_1_phase3_unet_final.pickle', 'wb') as handle:
    pickle.dump(state_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
np.save("/content/drive/MyDrive/ARIA/v1_1_phase3_unet_final", losses)
